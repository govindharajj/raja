# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time
import csv
import pandas as pd

# %%
#Full 5 pages- code


driver = webdriver.Chrome()

driver.get("https://www.redbus.in/online-booking/tsrtc/?utm_source=rtchometile")

wait = WebDriverWait(driver, 20)

all_data = []

def scrape_page():
    # Locate elements
    routes = wait.until(EC.presence_of_all_elements_located((By.CLASS_NAME, "route_link")))

    # Loop through each route to extract details
    for route in routes:
        try:
            route_link = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("href")
            title = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("title")

            # Append extracted data to list
            all_data.append({
                "route_link": route_link,
                "title": title,
                
            })
        except Exception as e:
            print(f"An error occurred: {e}")
            continue
# Scrape data from the first 5 pages

for page_number in range(1, 6):
    scrape_page()
    if page_number < 5:  # Don't try to click next on the last page
        try:
            # Locate the pagination container
            pagination_container = wait.until(EC.presence_of_element_located(
                (By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')
            ))

            # Locate the next page button within the container
            next_page_button = pagination_container.find_element(
                By.XPATH, f'.//div[contains(@class, "DC_117_pageTabs") and text()="{page_number + 1}"]'
            )

            # Scroll the next page button into view
            driver.execute_script("arguments[0].scrollIntoView();", next_page_button)
            time.sleep(1)  # Wait for a bit after scrolling

            # Log the action
            print(f"Clicking on page {page_number + 1}")

            # Click the next page button
            next_page_button.click()

            # Wait for the page number to update to the next page
            wait.until(EC.text_to_be_present_in_element(
                (By.XPATH, '//div[contains(@class, "DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))

            # Log the successful page navigation
            print(f"Successfully navigated to page {page_number + 1}")

            # Wait for a short duration to ensure the next page loads completely
            time.sleep(3)
        except Exception as e:
            print(f"An error occurred while navigating to page {page_number + 1}: {e}")
            break

# Print the scraped data
for entry in all_data:
    print(entry)
# Out:
# Clicking on page 2
# An error occurred while navigating to page 2: Message: element click intercepted: Element is not clickable at point (489, 2092)
#   (Session info: chrome=134.0.6998.89)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF608C3FE65+26629]
# 	(No symbol) [0x00007FF608BA6030]
# 	(No symbol) [0x00007FF608A3931A]
# 	(No symbol) [0x00007FF608A977A9]
# 	(No symbol) [0x00007FF608A95162]
# 	(No symbol) [0x00007FF608A92201]
# 	(No symbol) [0x00007FF608A91108]
# 	(No symbol) [0x00007FF608A828A4]
# 	(No symbol) [0x00007FF608AB7AAA]
# 	(No symbol) [0x00007FF608A82156]
# 	(No symbol) [0x00007FF608AB7CC0]
# 	(No symbol) [0x00007FF608AE0169]
# 	(No symbol) [0x00007FF608AB7883]
# 	(No symbol) [0x00007FF608A80550]
# 	(No symbol) [0x00007FF608A81803]
# 	GetHandleVerifier [0x00007FF608F972DD+3529853]
# 	GetHandleVerifier [0x00007FF608FADA42+3621858]
# 	GetHandleVerifier [0x00007FF608FA24F3+3575443]
# 	GetHandleVerifier [0x00007FF608D0B79A+860474]
# 	(No symbol) [0x00007FF608BB08AF]
# 	(No symbol) [0x00007FF608BACBE4]
# 	(No symbol) [0x00007FF608BACD86]
# 	(No symbol) [0x00007FF608B9C2E9]
# 	BaseThreadInitThunk [0x00007FF9505EE8D7+23]
# 	RtlUserThreadStart [0x00007FF9514DBF6C+44]
#
# {'route_link': 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'title': 'Hyderabad to Vijayawada'}
# {'route_link': 'https://www.redbus.in/bus-tickets/hyderabad-to-khammam', 'title': 'Hyderabad to Khammam'}
# {'route_link': 'https://www.redbus.in/bus-tickets/khammam-to-hyderabad', 'title': 'Khammam to Hyderabad'}
# {'route_link': 'https://www.redbus.in/bus-tickets/hyderabad-to-srisailam', 'title': 'Hyderabad to Srisailam'}
# {'route_link': 'https://www.redbus.in/bus-tickets/hyderabad-to-karimnagar', 'title': 'Hyderabad to Karimnagar'}
# {'route_link': 'https://www.redbus.in/bus-tickets/hyderabad-to-mancherial', 'title': 'Hyderabad to Mancherial'}
# {'route_link': 'https://www.redbus.in/bus-tickets/hyderabad-to-sathupalli', 'title': 'Hyderabad to Sathupally'}
# {'route_link': 'https://www.redbus.in/bus-tickets/hyderabad-to-adilabad', 'title': 'Hyderabad to Adilabad'}
# {'route_link': 'https://www.redbus.in/bus-tickets/hyderabad-to-nirmal', 'title': 'Hyderabad to Nirmal'}
# {'route_link': 'https://www.redbus.in/bus-tickets/hyderabad-to-bhadrachalam', 'title': 'Hyderabad to Bhadrachalam'}

# %%
route_links=[(item['route_link'],item["title"]) for item in all_data]
route_links
# Out:
# [('https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada',
#   'Hyderabad to Vijayawada'),
#  ('https://www.redbus.in/bus-tickets/hyderabad-to-khammam',
#   'Hyderabad to Khammam'),
#  ('https://www.redbus.in/bus-tickets/khammam-to-hyderabad',
#   'Khammam to Hyderabad'),
#  ('https://www.redbus.in/bus-tickets/hyderabad-to-srisailam',
#   'Hyderabad to Srisailam'),
#  ('https://www.redbus.in/bus-tickets/hyderabad-to-karimnagar',
#   'Hyderabad to Karimnagar'),
#  ('https://www.redbus.in/bus-tickets/hyderabad-to-mancherial',
#   'Hyderabad to Mancherial'),
#  ('https://www.redbus.in/bus-tickets/hyderabad-to-sathupalli',
#   'Hyderabad to Sathupally'),
#  ('https://www.redbus.in/bus-tickets/hyderabad-to-adilabad',
#   'Hyderabad to Adilabad'),
#  ('https://www.redbus.in/bus-tickets/hyderabad-to-nirmal',
#   'Hyderabad to Nirmal'),
#  ('https://www.redbus.in/bus-tickets/hyderabad-to-bhadrachalam',
#   'Hyderabad to Bhadrachalam')]

# %%
driver = webdriver.Chrome()
time.sleep(5)

def  scroll():
   x=0
   l=[]
   while True:
        x=x+1
        driver.execute_script('scrollBy(0,100)')
        #time.sleep(5)
        if(x>1000):
         break
bus_data=[]
for i,j in route_links:
    driver.get(i)

    scroll()




    bus_box= driver.find_elements(By.XPATH, '//div[@class="clearfix bus-item  "]')

    for bus in bus_box:
                        
                    reaching_time=bus.find_element(By.XPATH,'//div[@class="bp-time f-19 d-color disp-Inline"]').text
                    duration_time = bus.find_element(By.XPATH,'//div[@class="dur l-color lh-24"]').text

                    seats_available=bus.find_element(By.CLASS_NAME,'seat-left').text

                    bus_type = bus.find_element(By.XPATH, '//div[@class="bus-type f-12 m-top-16 l-color evBus"]').text


                    bus_names = bus.find_element(By.XPATH, '//div[@class="travels lh-24 f-bold d-color"]').text

                    route_times =bus.find_element(By.XPATH,'//div[@class="dp-time f-19 d-color f-bold"]').text

                    star_ratings = bus.find_element(By.XPATH, '//i[@class="icon icon-ic-star d-block"]').text

                    ticket_rates =bus.find_element(By.XPATH, '//div[@class="seat-fare "]').text
                            
                    bus_data.append({'routename':j,'seat':seats_available,'bustypes':bus_type,'busnames':bus_names,'routetimes':route_times,'starratings':star_ratings,'tickets':ticket_rates,
                        "reaching":reaching_time," duration":duration_time,  })

# %%
bus_data
# Out:
# [{'routename': 'Hyderabad to Vijayawada',
#   'seat': '24 Seats available',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Hyderabad to Vijayawada',
#   'seat': '23 Seats available',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Hyderabad to Vijayawada',
#   'seat': '15 Seats available',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Hyderabad to Vijayawada',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Hyderabad to Vijayawada',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Hyderabad to Vijayawada',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Hyderabad to Vijayawada',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Hyderabad to Vijayawada',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Hyderabad to Vijayawada',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Hyderabad to Vijayawada',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Hyderabad to Khammam',
#   'seat': '48 Seats available',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'MAHABAHUSRIKVRTRAVELS',
#   'routetimes': '16:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 800 760',
#   'reaching': '22:30',
#   ' duration': '06h 30m'},
#  {'routename': 'Hyderabad to Khammam',
#   'seat': '40 Seats available',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'MAHABAHUSRIKVRTRAVELS',
#   'routetimes': '16:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 800 760',
#   'reaching': '22:30',
#   ' duration': '06h 30m'},
#  {'routename': 'Hyderabad to Khammam',
#   'seat': '17 Seats available',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'MAHABAHUSRIKVRTRAVELS',
#   'routetimes': '16:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 800 760',
#   'reaching': '22:30',
#   ' duration': '06h 30m'},
#  {'routename': 'Hyderabad to Khammam',
#   'seat': '',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'MAHABAHUSRIKVRTRAVELS',
#   'routetimes': '16:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 800 760',
#   'reaching': '22:30',
#   ' duration': '06h 30m'},
#  {'routename': 'Hyderabad to Khammam',
#   'seat': '',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'MAHABAHUSRIKVRTRAVELS',
#   'routetimes': '16:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 800 760',
#   'reaching': '22:30',
#   ' duration': '06h 30m'},
#  {'routename': 'Hyderabad to Khammam',
#   'seat': '',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'MAHABAHUSRIKVRTRAVELS',
#   'routetimes': '16:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 800 760',
#   'reaching': '22:30',
#   ' duration': '06h 30m'},
#  {'routename': 'Hyderabad to Khammam',
#   'seat': '',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'MAHABAHUSRIKVRTRAVELS',
#   'routetimes': '16:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 800 760',
#   'reaching': '22:30',
#   ' duration': '06h 30m'},
#  {'routename': 'Hyderabad to Khammam',
#   'seat': '',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'MAHABAHUSRIKVRTRAVELS',
#   'routetimes': '16:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 800 760',
#   'reaching': '22:30',
#   ' duration': '06h 30m'},
#  {'routename': 'Hyderabad to Khammam',
#   'seat': '',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'MAHABAHUSRIKVRTRAVELS',
#   'routetimes': '16:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 800 760',
#   'reaching': '22:30',
#   ' duration': '06h 30m'},
#  {'routename': 'Hyderabad to Khammam',
#   'seat': '',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'MAHABAHUSRIKVRTRAVELS',
#   'routetimes': '16:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 800 760',
#   'reaching': '22:30',
#   ' duration': '06h 30m'},
#  {'routename': 'Khammam to Hyderabad',
#   'seat': '25 Seats available',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'Bharathi Tours & Travels',
#   'routetimes': '23:40',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 500 450',
#   'reaching': '04:00',
#   ' duration': '04h 20m'},
#  {'routename': 'Khammam to Hyderabad',
#   'seat': '26 Seats available',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'Bharathi Tours & Travels',
#   'routetimes': '23:40',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 500 450',
#   'reaching': '04:00',
#   ' duration': '04h 20m'},
#  {'routename': 'Khammam to Hyderabad',
#   'seat': '37 Seats available',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'Bharathi Tours & Travels',
#   'routetimes': '23:40',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 500 450',
#   'reaching': '04:00',
#   ' duration': '04h 20m'},
#  {'routename': 'Khammam to Hyderabad',
#   'seat': '',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'Bharathi Tours & Travels',
#   'routetimes': '23:40',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 500 450',
#   'reaching': '04:00',
#   ' duration': '04h 20m'},
#  {'routename': 'Khammam to Hyderabad',
#   'seat': '',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'Bharathi Tours & Travels',
#   'routetimes': '23:40',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 500 450',
#   'reaching': '04:00',
#   ' duration': '04h 20m'},
#  {'routename': 'Hyderabad to Srisailam',
#   'seat': '16 Seats available',
#   'bustypes': 'RAJDHANI (A.C. Semi Sleeper)',
#   'busnames': 'TGSRTC - 1258',
#   'routetimes': '09:00',
#   'starratings': '',
#   'tickets': 'INR 524',
#   'reaching': '15:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Hyderabad to Srisailam',
#   'seat': '12 Seats available',
#   'bustypes': 'RAJDHANI (A.C. Semi Sleeper)',
#   'busnames': 'TGSRTC - 1258',
#   'routetimes': '09:00',
#   'starratings': '',
#   'tickets': 'INR 524',
#   'reaching': '15:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Hyderabad to Srisailam',
#   'seat': '29 Seats available',
#   'bustypes': 'RAJDHANI (A.C. Semi Sleeper)',
#   'busnames': 'TGSRTC - 1258',
#   'routetimes': '09:00',
#   'starratings': '',
#   'tickets': 'INR 524',
#   'reaching': '15:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Hyderabad to Srisailam',
#   'seat': '36 Seats available',
#   'bustypes': 'RAJDHANI (A.C. Semi Sleeper)',
#   'busnames': 'TGSRTC - 1258',
#   'routetimes': '09:00',
#   'starratings': '',
#   'tickets': 'INR 524',
#   'reaching': '15:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Hyderabad to Srisailam',
#   'seat': '31 Seats available',
#   'bustypes': 'RAJDHANI (A.C. Semi Sleeper)',
#   'busnames': 'TGSRTC - 1258',
#   'routetimes': '09:00',
#   'starratings': '',
#   'tickets': 'INR 524',
#   'reaching': '15:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Hyderabad to Srisailam',
#   'seat': '',
#   'bustypes': 'RAJDHANI (A.C. Semi Sleeper)',
#   'busnames': 'TGSRTC - 1258',
#   'routetimes': '09:00',
#   'starratings': '',
#   'tickets': 'INR 524',
#   'reaching': '15:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Hyderabad to Srisailam',
#   'seat': '',
#   'bustypes': 'RAJDHANI (A.C. Semi Sleeper)',
#   'busnames': 'TGSRTC - 1258',
#   'routetimes': '09:00',
#   'starratings': '',
#   'tickets': 'INR 524',
#   'reaching': '15:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Hyderabad to Srisailam',
#   'seat': '',
#   'bustypes': 'RAJDHANI (A.C. Semi Sleeper)',
#   'busnames': 'TGSRTC - 1258',
#   'routetimes': '09:00',
#   'starratings': '',
#   'tickets': 'INR 524',
#   'reaching': '15:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Hyderabad to Srisailam',
#   'seat': '',
#   'bustypes': 'RAJDHANI (A.C. Semi Sleeper)',
#   'busnames': 'TGSRTC - 1258',
#   'routetimes': '09:00',
#   'starratings': '',
#   'tickets': 'INR 524',
#   'reaching': '15:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Hyderabad to Srisailam',
#   'seat': '',
#   'bustypes': 'RAJDHANI (A.C. Semi Sleeper)',
#   'busnames': 'TGSRTC - 1258',
#   'routetimes': '09:00',
#   'starratings': '',
#   'tickets': 'INR 524',
#   'reaching': '15:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Hyderabad to Karimnagar',
#   'seat': '40 Seats available',
#   'bustypes': 'NON A/C Sleeper (2+2)',
#   'busnames': 'IPS Bus Service',
#   'routetimes': '15:30',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 1200',
#   'reaching': '18:40',
#   ' duration': '03h 10m'},
#  {'routename': 'Hyderabad to Karimnagar',
#   'seat': '20 Seats available',
#   'bustypes': 'NON A/C Sleeper (2+2)',
#   'busnames': 'IPS Bus Service',
#   'routetimes': '15:30',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 1200',
#   'reaching': '18:40',
#   ' duration': '03h 10m'},
#  {'routename': 'Hyderabad to Karimnagar',
#   'seat': '36 Seats available',
#   'bustypes': 'NON A/C Sleeper (2+2)',
#   'busnames': 'IPS Bus Service',
#   'routetimes': '15:30',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 1200',
#   'reaching': '18:40',
#   ' duration': '03h 10m'},
#  {'routename': 'Hyderabad to Karimnagar',
#   'seat': '42 Seats available',
#   'bustypes': 'NON A/C Sleeper (2+2)',
#   'busnames': 'IPS Bus Service',
#   'routetimes': '15:30',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 1200',
#   'reaching': '18:40',
#   ' duration': '03h 10m'},
#  {'routename': 'Hyderabad to Mancherial',
#   'seat': '29 Seats available',
#   'bustypes': 'AC Sleeper (2+1)',
#   'busnames': 'DNR Express',
#   'routetimes': '21:30',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 999',
#   'reaching': '02:00',
#   ' duration': '04h 30m'},
#  {'routename': 'Hyderabad to Mancherial',
#   'seat': '40 Seats available',
#   'bustypes': 'AC Sleeper (2+1)',
#   'busnames': 'DNR Express',
#   'routetimes': '21:30',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 999',
#   'reaching': '02:00',
#   ' duration': '04h 30m'},
#  {'routename': 'Hyderabad to Sathupally',
#   'seat': '33 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Mozo travels',
#   'routetimes': '22:40',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 585',
#   'reaching': '05:05',
#   ' duration': '06h 25m'},
#  {'routename': 'Hyderabad to Sathupally',
#   'seat': '20 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Mozo travels',
#   'routetimes': '22:40',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 585',
#   'reaching': '05:05',
#   ' duration': '06h 25m'},
#  {'routename': 'Hyderabad to Sathupally',
#   'seat': '25 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Mozo travels',
#   'routetimes': '22:40',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 585',
#   'reaching': '05:05',
#   ' duration': '06h 25m'},
#  {'routename': 'Hyderabad to Sathupally',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Mozo travels',
#   'routetimes': '22:40',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 585',
#   'reaching': '05:05',
#   ' duration': '06h 25m'},
#  {'routename': 'Hyderabad to Sathupally',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Mozo travels',
#   'routetimes': '22:40',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 585',
#   'reaching': '05:05',
#   ' duration': '06h 25m'},
#  {'routename': 'Hyderabad to Adilabad',
#   'seat': '38 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Sahara Tours and Travels',
#   'routetimes': '18:00',
#   'starratings': '',
#   'tickets': 'INR 600',
#   'reaching': '23:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Hyderabad to Adilabad',
#   'seat': '46 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Sahara Tours and Travels',
#   'routetimes': '18:00',
#   'starratings': '',
#   'tickets': 'INR 600',
#   'reaching': '23:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Hyderabad to Adilabad',
#   'seat': '17 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Sahara Tours and Travels',
#   'routetimes': '18:00',
#   'starratings': '',
#   'tickets': 'INR 600',
#   'reaching': '23:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Hyderabad to Adilabad',
#   'seat': '20 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Sahara Tours and Travels',
#   'routetimes': '18:00',
#   'starratings': '',
#   'tickets': 'INR 600',
#   'reaching': '23:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Hyderabad to Adilabad',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Sahara Tours and Travels',
#   'routetimes': '18:00',
#   'starratings': '',
#   'tickets': 'INR 600',
#   'reaching': '23:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Hyderabad to Adilabad',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Sahara Tours and Travels',
#   'routetimes': '18:00',
#   'starratings': '',
#   'tickets': 'INR 600',
#   'reaching': '23:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Hyderabad to Adilabad',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Sahara Tours and Travels',
#   'routetimes': '18:00',
#   'starratings': '',
#   'tickets': 'INR 600',
#   'reaching': '23:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Hyderabad to Adilabad',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Sahara Tours and Travels',
#   'routetimes': '18:00',
#   'starratings': '',
#   'tickets': 'INR 600',
#   'reaching': '23:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Hyderabad to Adilabad',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Sahara Tours and Travels',
#   'routetimes': '18:00',
#   'starratings': '',
#   'tickets': 'INR 600',
#   'reaching': '23:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Hyderabad to Adilabad',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Sahara Tours and Travels',
#   'routetimes': '18:00',
#   'starratings': '',
#   'tickets': 'INR 600',
#   'reaching': '23:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Hyderabad to Nirmal',
#   'seat': '24 Seats available',
#   'bustypes': 'NON A/C Seater (2+2)',
#   'busnames': 'Pooja Travels',
#   'routetimes': '21:00',
#   'starratings': '',
#   'tickets': 'INR 500 475',
#   'reaching': '02:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Hyderabad to Nirmal',
#   'seat': '30 Seats available',
#   'bustypes': 'NON A/C Seater (2+2)',
#   'busnames': 'Pooja Travels',
#   'routetimes': '21:00',
#   'starratings': '',
#   'tickets': 'INR 500 475',
#   'reaching': '02:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Hyderabad to Nirmal',
#   'seat': '24 Seats available',
#   'bustypes': 'NON A/C Seater (2+2)',
#   'busnames': 'Pooja Travels',
#   'routetimes': '21:00',
#   'starratings': '',
#   'tickets': 'INR 500 475',
#   'reaching': '02:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Hyderabad to Nirmal',
#   'seat': '20 Seats available',
#   'bustypes': 'NON A/C Seater (2+2)',
#   'busnames': 'Pooja Travels',
#   'routetimes': '21:00',
#   'starratings': '',
#   'tickets': 'INR 500 475',
#   'reaching': '02:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Hyderabad to Nirmal',
#   'seat': '',
#   'bustypes': 'NON A/C Seater (2+2)',
#   'busnames': 'Pooja Travels',
#   'routetimes': '21:00',
#   'starratings': '',
#   'tickets': 'INR 500 475',
#   'reaching': '02:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Hyderabad to Nirmal',
#   'seat': '',
#   'bustypes': 'NON A/C Seater (2+2)',
#   'busnames': 'Pooja Travels',
#   'routetimes': '21:00',
#   'starratings': '',
#   'tickets': 'INR 500 475',
#   'reaching': '02:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Hyderabad to Nirmal',
#   'seat': '',
#   'bustypes': 'NON A/C Seater (2+2)',
#   'busnames': 'Pooja Travels',
#   'routetimes': '21:00',
#   'starratings': '',
#   'tickets': 'INR 500 475',
#   'reaching': '02:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Hyderabad to Nirmal',
#   'seat': '',
#   'bustypes': 'NON A/C Seater (2+2)',
#   'busnames': 'Pooja Travels',
#   'routetimes': '21:00',
#   'starratings': '',
#   'tickets': 'INR 500 475',
#   'reaching': '02:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Hyderabad to Nirmal',
#   'seat': '',
#   'bustypes': 'NON A/C Seater (2+2)',
#   'busnames': 'Pooja Travels',
#   'routetimes': '21:00',
#   'starratings': '',
#   'tickets': 'INR 500 475',
#   'reaching': '02:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Hyderabad to Nirmal',
#   'seat': '',
#   'bustypes': 'NON A/C Seater (2+2)',
#   'busnames': 'Pooja Travels',
#   'routetimes': '21:00',
#   'starratings': '',
#   'tickets': 'INR 500 475',
#   'reaching': '02:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Hyderabad to Bhadrachalam',
#   'seat': '20 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'BSR Tours And Travels',
#   'routetimes': '22:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 680',
#   'reaching': '05:30',
#   ' duration': '07h 30m'},
#  {'routename': 'Hyderabad to Bhadrachalam',
#   'seat': '11 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'BSR Tours And Travels',
#   'routetimes': '22:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 680',
#   'reaching': '05:30',
#   ' duration': '07h 30m'},
#  {'routename': 'Hyderabad to Bhadrachalam',
#   'seat': '12 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'BSR Tours And Travels',
#   'routetimes': '22:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 680',
#   'reaching': '05:30',
#   ' duration': '07h 30m'},
#  {'routename': 'Hyderabad to Bhadrachalam',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'BSR Tours And Travels',
#   'routetimes': '22:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 680',
#   'reaching': '05:30',
#   ' duration': '07h 30m'},
#  {'routename': 'Hyderabad to Bhadrachalam',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'BSR Tours And Travels',
#   'routetimes': '22:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 680',
#   'reaching': '05:30',
#   ' duration': '07h 30m'},
#  {'routename': 'Hyderabad to Bhadrachalam',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'BSR Tours And Travels',
#   'routetimes': '22:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 680',
#   'reaching': '05:30',
#   ' duration': '07h 30m'},
#  {'routename': 'Hyderabad to Bhadrachalam',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'BSR Tours And Travels',
#   'routetimes': '22:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 680',
#   'reaching': '05:30',
#   ' duration': '07h 30m'},
#  {'routename': 'Hyderabad to Bhadrachalam',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'BSR Tours And Travels',
#   'routetimes': '22:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 680',
#   'reaching': '05:30',
#   ' duration': '07h 30m'},
#  {'routename': 'Hyderabad to Bhadrachalam',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'BSR Tours And Travels',
#   'routetimes': '22:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 680',
#   'reaching': '05:30',
#   ' duration': '07h 30m'},
#  {'routename': 'Hyderabad to Bhadrachalam',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'BSR Tours And Travels',
#   'routetimes': '22:00',
#   'starratings': '',
#   'tickets': 'Starts from\nINR 680',
#   'reaching': '05:30',
#   ' duration': '07h 30m'}]

# %%
df=pd.DataFrame(bus_data)

# %%
df["STATE"]='telungana'

# %%
df
# Out:
#                     routename                seat                    bustypes  \
# 0     Hyderabad to Vijayawada  24 Seats available   Electric A/C Seater (2+2)
# 1     Hyderabad to Vijayawada  23 Seats available   Electric A/C Seater (2+2)
# 2     Hyderabad to Vijayawada  15 Seats available   Electric A/C Seater (2+2)
# 3     Hyderabad to Vijayawada                       Electric A/C Seater (2+2)
# 4     Hyderabad to Vijayawada                       Electric A/C Seater (2+2)
# ..                        ...                 ...                         ...
# 71  Hyderabad to Bhadrachalam                      A/C Seater / Sleeper (2+1)
# 72  Hyderabad to Bhadrachalam                      A/C Seater / Sleeper (2+1)
# 73  Hyderabad to Bhadrachalam                      A/C Seater / Sleeper (2+1)
# 74  Hyderabad to Bhadrachalam                      A/C Seater / Sleeper (2+1)
# 75  Hyderabad to Bhadrachalam                      A/C Seater / Sleeper (2+1)
#
#                  busnames routetimes starratings                   tickets  \
# 0                FRESHBUS      12:50              Starts from\nINR 349 249
# 1                FRESHBUS      12:50              Starts from\nINR 349 249
# 2                FRESHBUS      12:50              Starts from\nINR 349 249
# 3                FRESHBUS      12:50              Starts from\nINR 349 249
# 4                FRESHBUS      12:50              Starts from\nINR 349 249
# ..                    ...        ...         ...                       ...
# 71  BSR Tours And Travels      22:00                  Starts from\nINR 680
# 72  BSR Tours And Travels      22:00                  Starts from\nINR 680
# 73  BSR Tours And Travels      22:00                  Starts from\nINR 680
# 74  BSR Tours And Travels      22:00                  Starts from\nINR 680
# 75  BSR Tours And Travels      22:00                  Starts from\nINR 680
#
#    reaching  duration      STATE
# 0     19:30   06h 40m  telungana
# 1     19:30   06h 40m  telungana
# 2     19:30   06h 40m  telungana
# 3     19:30   06h 40m  telungana
# 4     19:30   06h 40m  telungana
# ..      ...       ...        ...
# 71    05:30   07h 30m  telungana
# 72    05:30   07h 30m  telungana
# 73    05:30   07h 30m  telungana
# 74    05:30   07h 30m  telungana
# 75    05:30   07h 30m  telungana
#
# [76 rows x 10 columns]

# %%
df.to_csv("telungana.csv",index=False)
