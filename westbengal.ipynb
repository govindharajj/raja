# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time
import csv
import pandas as pd

# %%
#Full 5 pages- code


driver = webdriver.Chrome()

driver.get("https://www.redbus.in/online-booking/wbtc-ctc/?utm_source=rtchometile")

wait = WebDriverWait(driver, 20)

all_data = []

def scrape_page():
    # Locate elements
    routes = wait.until(EC.presence_of_all_elements_located((By.CLASS_NAME, "route_link")))

    # Loop through each route to extract details
    for route in routes:
        try:
            route_link = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("href")
            title = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("title")

            # Append extracted data to list
            all_data.append({
                "route_link": route_link,
                "title": title,
                
            })
        except Exception as e:
            print(f"An error occurred: {e}")
            continue
# Scrape data from the first 5 pages

for page_number in range(1, 6):
    scrape_page()
    if page_number < 5:  # Don't try to click next on the last page
        try:
            # Locate the pagination container
            pagination_container = wait.until(EC.presence_of_element_located(
                (By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')
            ))

            # Locate the next page button within the container
            next_page_button = pagination_container.find_element(
                By.XPATH, f'.//div[contains(@class, "DC_117_pageTabs") and text()="{page_number + 1}"]'
            )

            # Scroll the next page button into view
            driver.execute_script("arguments[0].scrollIntoView();", next_page_button)
            time.sleep(1)  # Wait for a bit after scrolling

            # Log the action
            print(f"Clicking on page {page_number + 1}")

            # Click the next page button
            next_page_button.click()

            # Wait for the page number to update to the next page
            wait.until(EC.text_to_be_present_in_element(
                (By.XPATH, '//div[contains(@class, "DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))

            # Log the successful page navigation
            print(f"Successfully navigated to page {page_number + 1}")

            # Wait for a short duration to ensure the next page loads completely
            time.sleep(3)
        except Exception as e:
            print(f"An error occurred while navigating to page {page_number + 1}: {e}")
            break

# Print the scraped data
for entry in all_data:
    print(entry)
# Out:
# Clicking on page 2
# An error occurred while navigating to page 2: Message: element click intercepted: Element is not clickable at point (489, 2092)
#   (Session info: chrome=134.0.6998.89)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF68314FE45+26629]
# 	(No symbol) [0x00007FF6830B6010]
# 	(No symbol) [0x00007FF682F4931A]
# 	(No symbol) [0x00007FF682FA77A9]
# 	(No symbol) [0x00007FF682FA5162]
# 	(No symbol) [0x00007FF682FA2201]
# 	(No symbol) [0x00007FF682FA1108]
# 	(No symbol) [0x00007FF682F928A4]
# 	(No symbol) [0x00007FF682FC7AAA]
# 	(No symbol) [0x00007FF682F92156]
# 	(No symbol) [0x00007FF682FC7CC0]
# 	(No symbol) [0x00007FF682FF0169]
# 	(No symbol) [0x00007FF682FC7883]
# 	(No symbol) [0x00007FF682F90550]
# 	(No symbol) [0x00007FF682F91803]
# 	GetHandleVerifier [0x00007FF6834A72BD+3529853]
# 	GetHandleVerifier [0x00007FF6834BDA22+3621858]
# 	GetHandleVerifier [0x00007FF6834B24D3+3575443]
# 	GetHandleVerifier [0x00007FF68321B77A+860474]
# 	(No symbol) [0x00007FF6830C088F]
# 	(No symbol) [0x00007FF6830BCBC4]
# 	(No symbol) [0x00007FF6830BCD66]
# 	(No symbol) [0x00007FF6830AC2C9]
# 	BaseThreadInitThunk [0x00007FFF9577E8D7+23]
# 	RtlUserThreadStart [0x00007FFF9657BF6C+44]
#
# {'route_link': 'https://www.redbus.in/bus-tickets/kolkata-to-digha', 'title': 'Kolkata to Digha'}
# {'route_link': 'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal', 'title': 'Digha to Barasat (West Bengal)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'title': 'Digha to Kolkata'}
# {'route_link': 'https://www.redbus.in/bus-tickets/kolkata-to-bolpur-west-bengal', 'title': 'Kolkata to Bolpur (West Bengal)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/midnapore-to-kolkata', 'title': 'Midnapore to Kolkata'}
# {'route_link': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-midnapore', 'title': 'Barasat (West Bengal) to Midnapore'}
# {'route_link': 'https://www.redbus.in/bus-tickets/durgapur-to-kolkata', 'title': 'Durgapur (West Bengal) to Kolkata'}
# {'route_link': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-digha', 'title': 'Barasat (West Bengal) to Digha'}
# {'route_link': 'https://www.redbus.in/bus-tickets/midnapore-to-barasat-west-bengal', 'title': 'Midnapore to Barasat (West Bengal)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-nandakumar', 'title': 'Barasat (West Bengal) to Nandakumar (west bengal)'}

# %%
route_links=[item['route_link'] for item in all_data]
route_links
# Out:
# ['https://www.redbus.in/bus-tickets/kolkata-to-digha',
#  'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal',
#  'https://www.redbus.in/bus-tickets/digha-to-kolkata',
#  'https://www.redbus.in/bus-tickets/kolkata-to-bolpur-west-bengal',
#  'https://www.redbus.in/bus-tickets/midnapore-to-kolkata',
#  'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-midnapore',
#  'https://www.redbus.in/bus-tickets/durgapur-to-kolkata',
#  'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-digha',
#  'https://www.redbus.in/bus-tickets/midnapore-to-barasat-west-bengal',
#  'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-nandakumar']

# %%
driver = webdriver.Chrome()
time.sleep(5)

def  scroll():
   x=0
   l=[]
   while True:
        x=x+1
        driver.execute_script('scrollBy(0,100)')
        #time.sleep(5)
        if(x>1000):
         break
bus_data=[]
for i in route_links:
    driver.get(i)

    scroll()




    bus_box= driver.find_elements(By.XPATH, '//div[@class="clearfix bus-item  "]')

    for bus in bus_box:
                        
                    reaching_time=bus.find_element(By.XPATH,'//div[@class="bp-time f-19 d-color disp-Inline"]').text
                    duration_time = bus.find_element(By.XPATH,'//div[@class="dur l-color lh-24"]').text

                    seats_available=bus.find_element(By.XPATH,'//span[@class="l-color"]').text


                    bus_type = bus.find_element(By.XPATH, '//div[@class="bus-type f-12 m-top-16 l-color evBus"]').text


                    bus_names = bus.find_element(By.XPATH, '//div[@class="travels lh-24 f-bold d-color"]').text

                    route_times =bus.find_element(By.XPATH,'//div[@class="dp-time f-19 d-color f-bold"]').text

                    star_ratings = bus.find_element(By.XPATH, '//div[@class="rating-sec lh-24"]').text

                    ticket_rates =bus.find_element(By.XPATH, '//div[@class="seat-fare "]').text
                            
                    bus_data.append({'seat':seats_available,'bustypes':bus_type,'busnames':bus_names,'routetimes':route_times,'starratings':star_ratings,'tickets':ticket_rates,
                        "reaching":reaching_time," duration":duration_time,  })

# %%
bus_data
# Out:
# [{'seat': 'Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'SANTOSH BUS SERVICE',
#   'routetimes': '10:20',
#   'starratings': '3.5',
#   'tickets': 'Starts from\nINR 789 671',
#   'reaching': '16:30',
#   ' duration': '06h 10m'},
#  {'seat': 'Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'SANTOSH BUS SERVICE',
#   'routetimes': '10:20',
#   'starratings': '3.5',
#   'tickets': 'Starts from\nINR 789 671',
#   'reaching': '16:30',
#   ' duration': '06h 10m'},
#  {'seat': 'Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'SANTOSH BUS SERVICE',
#   'routetimes': '10:20',
#   'starratings': '3.5',
#   'tickets': 'Starts from\nINR 789 671',
#   'reaching': '16:30',
#   ' duration': '06h 10m'},
#  {'seat': 'Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'SANTOSH BUS SERVICE',
#   'routetimes': '10:20',
#   'starratings': '3.5',
#   'tickets': 'Starts from\nINR 789 671',
#   'reaching': '16:30',
#   ' duration': '06h 10m'},
#  {'seat': 'Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'SANTOSH BUS SERVICE',
#   'routetimes': '10:20',
#   'starratings': '3.5',
#   'tickets': 'Starts from\nINR 789 671',
#   'reaching': '16:30',
#   ' duration': '06h 10m'},
#  {'seat': 'Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'SANTOSH BUS SERVICE',
#   'routetimes': '10:20',
#   'starratings': '3.5',
#   'tickets': 'Starts from\nINR 789 671',
#   'reaching': '16:30',
#   ' duration': '06h 10m'},
#  {'seat': 'Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'SANTOSH BUS SERVICE',
#   'routetimes': '10:20',
#   'starratings': '3.5',
#   'tickets': 'Starts from\nINR 789 671',
#   'reaching': '16:30',
#   ' duration': '06h 10m'},
#  {'seat': 'Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'SANTOSH BUS SERVICE',
#   'routetimes': '10:20',
#   'starratings': '3.5',
#   'tickets': 'Starts from\nINR 789 671',
#   'reaching': '16:30',
#   ' duration': '06h 10m'},
#  {'seat': 'Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'SANTOSH BUS SERVICE',
#   'routetimes': '10:20',
#   'starratings': '3.5',
#   'tickets': 'Starts from\nINR 789 671',
#   'reaching': '16:30',
#   ' duration': '06h 10m'},
#  {'seat': 'Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'SANTOSH BUS SERVICE',
#   'routetimes': '10:20',
#   'starratings': '3.5',
#   'tickets': 'Starts from\nINR 789 671',
#   'reaching': '16:30',
#   ' duration': '06h 10m'},
#  {'seat': 'Seats available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '13:40',
#   'starratings': '4.5',
#   'tickets': 'INR 900',
#   'reaching': '18:25',
#   ' duration': '04h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '13:40',
#   'starratings': '4.5',
#   'tickets': 'INR 900',
#   'reaching': '18:25',
#   ' duration': '04h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '13:40',
#   'starratings': '4.5',
#   'tickets': 'INR 900',
#   'reaching': '18:25',
#   ' duration': '04h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '13:40',
#   'starratings': '4.5',
#   'tickets': 'INR 900',
#   'reaching': '18:25',
#   ' duration': '04h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '13:40',
#   'starratings': '4.5',
#   'tickets': 'INR 900',
#   'reaching': '18:25',
#   ' duration': '04h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'WBTC (CTC) Barasat-Bolpur-Suri (AC VOLVO) - 212|06:40',
#   'routetimes': '06:40',
#   'starratings': '3.1',
#   'tickets': 'INR 340',
#   'reaching': '09:25',
#   ' duration': '02h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'WBTC (CTC) Barasat-Bolpur-Suri (AC VOLVO) - 212|06:40',
#   'routetimes': '06:40',
#   'starratings': '3.1',
#   'tickets': 'INR 340',
#   'reaching': '09:25',
#   ' duration': '02h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'WBTC (CTC) Barasat-Bolpur-Suri (AC VOLVO) - 212|06:40',
#   'routetimes': '06:40',
#   'starratings': '3.1',
#   'tickets': 'INR 340',
#   'reaching': '09:25',
#   ' duration': '02h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'WBTC (CTC) Barasat-Bolpur-Suri (AC VOLVO) - 212|06:40',
#   'routetimes': '06:40',
#   'starratings': '3.1',
#   'tickets': 'INR 340',
#   'reaching': '09:25',
#   ' duration': '02h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'WBTC (CTC) Barasat-Bolpur-Suri (AC VOLVO) - 212|06:40',
#   'routetimes': '06:40',
#   'starratings': '3.1',
#   'tickets': 'INR 340',
#   'reaching': '09:25',
#   ' duration': '02h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'Maa Bhabani Travels',
#   'routetimes': '07:05',
#   'starratings': '1.0',
#   'tickets': 'INR 130',
#   'reaching': '10:30',
#   ' duration': '03h 25m'},
#  {'seat': 'Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-BARASAT - MIDNAPUR - 08:30 (MID DEPOT) - 1194',
#   'routetimes': '08:30',
#   'starratings': '3.9',
#   'tickets': 'INR 125',
#   'reaching': '13:00',
#   ' duration': '04h 30m'},
#  {'seat': 'Seat available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '12:30',
#   'starratings': '4.7',
#   'tickets': 'INR 736',
#   'reaching': '16:20',
#   ' duration': '03h 50m'},
#  {'seat': 'Seat available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '12:30',
#   'starratings': '4.7',
#   'tickets': 'INR 736',
#   'reaching': '16:20',
#   ' duration': '03h 50m'},
#  {'seat': 'Seat available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '12:30',
#   'starratings': '4.7',
#   'tickets': 'INR 736',
#   'reaching': '16:20',
#   ' duration': '03h 50m'},
#  {'seat': 'Seat available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '12:30',
#   'starratings': '4.7',
#   'tickets': 'INR 736',
#   'reaching': '16:20',
#   ' duration': '03h 50m'},
#  {'seat': 'Seat available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '12:30',
#   'starratings': '4.7',
#   'tickets': 'INR 736',
#   'reaching': '16:20',
#   ' duration': '03h 50m'},
#  {'seat': 'Seat available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '12:30',
#   'starratings': '4.7',
#   'tickets': 'INR 736',
#   'reaching': '16:20',
#   ' duration': '03h 50m'},
#  {'seat': 'Seat available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '12:30',
#   'starratings': '4.7',
#   'tickets': 'INR 736',
#   'reaching': '16:20',
#   ' duration': '03h 50m'},
#  {'seat': 'Seat available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '12:30',
#   'starratings': '4.7',
#   'tickets': 'INR 736',
#   'reaching': '16:20',
#   ' duration': '03h 50m'},
#  {'seat': 'Seats available',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Snemita Paribahan',
#   'routetimes': '05:35',
#   'starratings': '3.9',
#   'tickets': 'INR 370',
#   'reaching': '10:20',
#   ' duration': '04h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Snemita Paribahan',
#   'routetimes': '05:35',
#   'starratings': '3.9',
#   'tickets': 'INR 370',
#   'reaching': '10:20',
#   ' duration': '04h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Snemita Paribahan',
#   'routetimes': '05:35',
#   'starratings': '3.9',
#   'tickets': 'INR 370',
#   'reaching': '10:20',
#   ' duration': '04h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Snemita Paribahan',
#   'routetimes': '05:35',
#   'starratings': '3.9',
#   'tickets': 'INR 370',
#   'reaching': '10:20',
#   ' duration': '04h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Snemita Paribahan',
#   'routetimes': '05:35',
#   'starratings': '3.9',
#   'tickets': 'INR 370',
#   'reaching': '10:20',
#   ' duration': '04h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Snemita Paribahan',
#   'routetimes': '05:35',
#   'starratings': '3.9',
#   'tickets': 'INR 370',
#   'reaching': '10:20',
#   ' duration': '04h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Snemita Paribahan',
#   'routetimes': '05:35',
#   'starratings': '3.9',
#   'tickets': 'INR 370',
#   'reaching': '10:20',
#   ' duration': '04h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Snemita Paribahan',
#   'routetimes': '05:35',
#   'starratings': '3.9',
#   'tickets': 'INR 370',
#   'reaching': '10:20',
#   ' duration': '04h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Snemita Paribahan',
#   'routetimes': '05:35',
#   'starratings': '3.9',
#   'tickets': 'INR 370',
#   'reaching': '10:20',
#   ' duration': '04h 45m'},
#  {'seat': 'Seats available',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Snemita Paribahan',
#   'routetimes': '05:35',
#   'starratings': '3.9',
#   'tickets': 'INR 370',
#   'reaching': '10:20',
#   ' duration': '04h 45m'}]

# %%
df=pd.DataFrame(bus_data)

# %%
df
# Out:
#                seat                    bustypes  \
# 0   Seats available  A/C Seater / Sleeper (2+2)
# 1   Seats available  A/C Seater / Sleeper (2+2)
# 2   Seats available  A/C Seater / Sleeper (2+2)
# 3   Seats available  A/C Seater / Sleeper (2+2)
# 4   Seats available  A/C Seater / Sleeper (2+2)
# 5   Seats available  A/C Seater / Sleeper (2+2)
# 6   Seats available  A/C Seater / Sleeper (2+2)
# 7   Seats available  A/C Seater / Sleeper (2+2)
# 8   Seats available  A/C Seater / Sleeper (2+2)
# 9   Seats available  A/C Seater / Sleeper (2+2)
# 10  Seats available      Volvo A/C Seater (2+2)
# 11  Seats available      Volvo A/C Seater (2+2)
# 12  Seats available      Volvo A/C Seater (2+2)
# 13  Seats available      Volvo A/C Seater (2+2)
# 14  Seats available      Volvo A/C Seater (2+2)
# 15  Seats available            A/C Seater (2+2)
# 16  Seats available            A/C Seater (2+2)
# 17  Seats available            A/C Seater (2+2)
# 18  Seats available            A/C Seater (2+2)
# 19  Seats available            A/C Seater (2+2)
# 20  Seats available         Non AC Seater (2+3)
# 21  Seats available         Non AC Seater (2+3)
# 22   Seat available      Volvo A/C Seater (2+2)
# 23   Seat available      Volvo A/C Seater (2+2)
# 24   Seat available      Volvo A/C Seater (2+2)
# 25   Seat available      Volvo A/C Seater (2+2)
# 26   Seat available      Volvo A/C Seater (2+2)
# 27   Seat available      Volvo A/C Seater (2+2)
# 28   Seat available      Volvo A/C Seater (2+2)
# 29   Seat available      Volvo A/C Seater (2+2)
# 30  Seats available             AC Seater (2+3)
# 31  Seats available             AC Seater (2+3)
# 32  Seats available             AC Seater (2+3)
# 33  Seats available             AC Seater (2+3)
# 34  Seats available             AC Seater (2+3)
# 35  Seats available             AC Seater (2+3)
# 36  Seats available             AC Seater (2+3)
# 37  Seats available             AC Seater (2+3)
# 38  Seats available             AC Seater (2+3)
# 39  Seats available             AC Seater (2+3)
#
#                                              busnames routetimes starratings  \
# 0                                 SANTOSH BUS SERVICE      10:20         3.5
# 1                                 SANTOSH BUS SERVICE      10:20         3.5
# 2                                 SANTOSH BUS SERVICE      10:20         3.5
# 3                                 SANTOSH BUS SERVICE      10:20         3.5
# 4                                 SANTOSH BUS SERVICE      10:20         3.5
# 5                                 SANTOSH BUS SERVICE      10:20         3.5
# 6                                 SANTOSH BUS SERVICE      10:20         3.5
# 7                                 SANTOSH BUS SERVICE      10:20         3.5
# 8                                 SANTOSH BUS SERVICE      10:20         3.5
# 9                                 SANTOSH BUS SERVICE      10:20         3.5
# 10                                          Greenline      13:40         4.5
# 11                                          Greenline      13:40         4.5
# 12                                          Greenline      13:40         4.5
# 13                                          Greenline      13:40         4.5
# 14                                          Greenline      13:40         4.5
# 15  WBTC (CTC) Barasat-Bolpur-Suri (AC VOLVO) - 21...      06:40         3.1
# 16  WBTC (CTC) Barasat-Bolpur-Suri (AC VOLVO) - 21...      06:40         3.1
# 17  WBTC (CTC) Barasat-Bolpur-Suri (AC VOLVO) - 21...      06:40         3.1
# 18  WBTC (CTC) Barasat-Bolpur-Suri (AC VOLVO) - 21...      06:40         3.1
# 19  WBTC (CTC) Barasat-Bolpur-Suri (AC VOLVO) - 21...      06:40         3.1
# 20                                Maa Bhabani Travels      07:05         1.0
# 21  SBSTC-BARASAT - MIDNAPUR - 08:30 (MID DEPOT) -...      08:30         3.9
# 22                                          Greenline      12:30         4.7
# 23                                          Greenline      12:30         4.7
# 24                                          Greenline      12:30         4.7
# 25                                          Greenline      12:30         4.7
# 26                                          Greenline      12:30         4.7
# 27                                          Greenline      12:30         4.7
# 28                                          Greenline      12:30         4.7
# 29                                          Greenline      12:30         4.7
# 30                                  Snemita Paribahan      05:35         3.9
# 31                                  Snemita Paribahan      05:35         3.9
# 32                                  Snemita Paribahan      05:35         3.9
# 33                                  Snemita Paribahan      05:35         3.9
# 34                                  Snemita Paribahan      05:35         3.9
# 35                                  Snemita Paribahan      05:35         3.9
# 36                                  Snemita Paribahan      05:35         3.9
# 37                                  Snemita Paribahan      05:35         3.9
# 38                                  Snemita Paribahan      05:35         3.9
# 39                                  Snemita Paribahan      05:35         3.9
#
#                      tickets reaching  duration
# 0   Starts from\nINR 789 671    16:30   06h 10m
# 1   Starts from\nINR 789 671    16:30   06h 10m
# 2   Starts from\nINR 789 671    16:30   06h 10m
# 3   Starts from\nINR 789 671    16:30   06h 10m
# 4   Starts from\nINR 789 671    16:30   06h 10m
# 5   Starts from\nINR 789 671    16:30   06h 10m
# 6   Starts from\nINR 789 671    16:30   06h 10m
# 7   Starts from\nINR 789 671    16:30   06h 10m
# 8   Starts from\nINR 789 671    16:30   06h 10m
# 9   Starts from\nINR 789 671    16:30   06h 10m
# 10                   INR 900    18:25   04h 45m
# 11                   INR 900    18:25   04h 45m
# 12                   INR 900    18:25   04h 45m
# 13                   INR 900    18:25   04h 45m
# 14                   INR 900    18:25   04h 45m
# 15                   INR 340    09:25   02h 45m
# 16                   INR 340    09:25   02h 45m
# 17                   INR 340    09:25   02h 45m
# 18                   INR 340    09:25   02h 45m
# 19                   INR 340    09:25   02h 45m
# 20                   INR 130    10:30   03h 25m
# 21                   INR 125    13:00   04h 30m
# 22                   INR 736    16:20   03h 50m
# 23                   INR 736    16:20   03h 50m
# 24                   INR 736    16:20   03h 50m
# 25                   INR 736    16:20   03h 50m
# 26                   INR 736    16:20   03h 50m
# 27                   INR 736    16:20   03h 50m
# 28                   INR 736    16:20   03h 50m
# 29                   INR 736    16:20   03h 50m
# 30                   INR 370    10:20   04h 45m
# 31                   INR 370    10:20   04h 45m
# 32                   INR 370    10:20   04h 45m
# 33                   INR 370    10:20   04h 45m
# 34                   INR 370    10:20   04h 45m
# 35                   INR 370    10:20   04h 45m
# 36                   INR 370    10:20   04h 45m
# 37                   INR 370    10:20   04h 45m
# 38                   INR 370    10:20   04h 45m
# 39                   INR 370    10:20   04h 45m
