# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time
import csv
import pandas as pd

# %%
#Full 5 pages- code


driver = webdriver.Chrome()

driver.get("https://www.redbus.in/online-booking/astc/?utm_source=rtchometile")

wait = WebDriverWait(driver, 20)

all_data = []

def scrape_page():
    # Locate elements
    routes = wait.until(EC.presence_of_all_elements_located((By.CLASS_NAME, "route_link")))

    # Loop through each route to extract details
    for route in routes:
        try:
            route_link = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("href")
            title = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("title")

            # Append extracted data to list
            all_data.append({
                "route_link": route_link,
                "title": title,
                
            })
        except Exception as e:
            print(f"An error occurred: {e}")
            continue
# Scrape data from the first 5 pages

for page_number in range(1, 6):
    scrape_page()
    if page_number < 5:  # Don't try to click next on the last page
        try:
            # Locate the pagination container
            pagination_container = wait.until(EC.presence_of_element_located(
                (By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')
            ))

            # Locate the next page button within the container
            next_page_button = pagination_container.find_element(
                By.XPATH, f'.//div[contains(@class, "DC_117_pageTabs") and text()="{page_number + 1}"]'
            )

            # Scroll the next page button into view
            driver.execute_script("arguments[0].scrollIntoView();", next_page_button)
            time.sleep(1)  # Wait for a bit after scrolling

            # Log the action
            print(f"Clicking on page {page_number + 1}")

            # Click the next page button
            next_page_button.click()

            # Wait for the page number to update to the next page
            wait.until(EC.text_to_be_present_in_element(
                (By.XPATH, '//div[contains(@class, "DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))

            # Log the successful page navigation
            print(f"Successfully navigated to page {page_number + 1}")

            # Wait for a short duration to ensure the next page loads completely
            time.sleep(3)
        except Exception as e:
            print(f"An error occurred while navigating to page {page_number + 1}: {e}")
            break

# Print the scraped data
for entry in all_data:
    print(entry)
# Out:
# Clicking on page 2
# An error occurred while navigating to page 2: Message: element click intercepted: Element is not clickable at point (489, 2092)
#   (Session info: chrome=134.0.6998.89)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF608C3FE65+26629]
# 	(No symbol) [0x00007FF608BA6030]
# 	(No symbol) [0x00007FF608A3931A]
# 	(No symbol) [0x00007FF608A977A9]
# 	(No symbol) [0x00007FF608A95162]
# 	(No symbol) [0x00007FF608A92201]
# 	(No symbol) [0x00007FF608A91108]
# 	(No symbol) [0x00007FF608A828A4]
# 	(No symbol) [0x00007FF608AB7AAA]
# 	(No symbol) [0x00007FF608A82156]
# 	(No symbol) [0x00007FF608AB7CC0]
# 	(No symbol) [0x00007FF608AE0169]
# 	(No symbol) [0x00007FF608AB7883]
# 	(No symbol) [0x00007FF608A80550]
# 	(No symbol) [0x00007FF608A81803]
# 	GetHandleVerifier [0x00007FF608F972DD+3529853]
# 	GetHandleVerifier [0x00007FF608FADA42+3621858]
# 	GetHandleVerifier [0x00007FF608FA24F3+3575443]
# 	GetHandleVerifier [0x00007FF608D0B79A+860474]
# 	(No symbol) [0x00007FF608BB08AF]
# 	(No symbol) [0x00007FF608BACBE4]
# 	(No symbol) [0x00007FF608BACD86]
# 	(No symbol) [0x00007FF608B9C2E9]
# 	BaseThreadInitThunk [0x00007FF9505EE8D7+23]
# 	RtlUserThreadStart [0x00007FF9514DBF6C+44]
#
# {'route_link': 'https://www.redbus.in/bus-tickets/guwahati-to-tezpur', 'title': 'Guwahati to Tezpur'}
# {'route_link': 'https://www.redbus.in/bus-tickets/guwahati-to-nagaon', 'title': 'Guwahati to Nagaon (Assam)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/guwahati-to-dhubri', 'title': 'Guwahati to Dhubri'}
# {'route_link': 'https://www.redbus.in/bus-tickets/jorhat-to-north-lakhimpur', 'title': 'Jorhat to North Lakhimpur'}
# {'route_link': 'https://www.redbus.in/bus-tickets/north-lakhimpur-to-sibsagar', 'title': 'North Lakhimpur to Sibsagar (Assam)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/dhubri-to-guwahati', 'title': 'Dhubri to Guwahati'}
# {'route_link': 'https://www.redbus.in/bus-tickets/north-lakhimpur-to-jorhat', 'title': 'North Lakhimpur to Jorhat'}
# {'route_link': 'https://www.redbus.in/bus-tickets/goalpara-to-guwahati', 'title': 'Goalpara to Guwahati'}
# {'route_link': 'https://www.redbus.in/bus-tickets/sibsagar-to-north-lakhimpur', 'title': 'Sibsagar (Assam) to North Lakhimpur'}
# {'route_link': 'https://www.redbus.in/bus-tickets/jorhat-to-dibrugarh', 'title': 'Jorhat to Dibrugarh'}

# %%
route_links=[(item['route_link'],item["title"]) for item in all_data]
route_links
# Out:
# [('https://www.redbus.in/bus-tickets/guwahati-to-tezpur',
#   'Guwahati to Tezpur'),
#  ('https://www.redbus.in/bus-tickets/guwahati-to-nagaon',
#   'Guwahati to Nagaon (Assam)'),
#  ('https://www.redbus.in/bus-tickets/guwahati-to-dhubri',
#   'Guwahati to Dhubri'),
#  ('https://www.redbus.in/bus-tickets/jorhat-to-north-lakhimpur',
#   'Jorhat to North Lakhimpur'),
#  ('https://www.redbus.in/bus-tickets/north-lakhimpur-to-sibsagar',
#   'North Lakhimpur to Sibsagar (Assam)'),
#  ('https://www.redbus.in/bus-tickets/dhubri-to-guwahati',
#   'Dhubri to Guwahati'),
#  ('https://www.redbus.in/bus-tickets/north-lakhimpur-to-jorhat',
#   'North Lakhimpur to Jorhat'),
#  ('https://www.redbus.in/bus-tickets/goalpara-to-guwahati',
#   'Goalpara to Guwahati'),
#  ('https://www.redbus.in/bus-tickets/sibsagar-to-north-lakhimpur',
#   'Sibsagar (Assam) to North Lakhimpur'),
#  ('https://www.redbus.in/bus-tickets/jorhat-to-dibrugarh',
#   'Jorhat to Dibrugarh')]

# %%
driver = webdriver.Chrome()
time.sleep(5)

def  scroll():
   x=0
   l=[]
   while True:
        x=x+1
        driver.execute_script('scrollBy(0,100)')
        #time.sleep(5)
        if(x>1000):
         break
bus_data=[]
for i,j in route_links:
    driver.get(i)

    scroll()




    bus_box= driver.find_elements(By.XPATH, '//div[@class="clearfix bus-item  "]')

    for bus in bus_box:
                        
                    reaching_time=bus.find_element(By.XPATH,'//div[@class="bp-time f-19 d-color disp-Inline"]').text
                    duration_time = bus.find_element(By.XPATH,'//div[@class="dur l-color lh-24"]').text

                    seats_available=bus.find_element(By.CLASS_NAME,'seat-left').text


                    bus_type = bus.find_element(By.XPATH, '//div[@class="bus-type f-12 m-top-16 l-color evBus"]').text


                    bus_names = bus.find_element(By.XPATH, '//div[@class="travels lh-24 f-bold d-color"]').text

                    route_times =bus.find_element(By.XPATH,'//div[@class="dp-time f-19 d-color f-bold"]').text

                    star_ratings = bus.find_element(By.XPATH, '//div[@class="rating-sec lh-24"]').text

                    ticket_rates =bus.find_element(By.XPATH, '//div[@class="seat-fare "]').text
                            
                    bus_data.append({'routename':j,'seat':seats_available,'bustypes':bus_type,'busnames':bus_names,'routetimes':route_times,'starratings':star_ratings,'tickets':ticket_rates,
                        "reaching":reaching_time," duration":duration_time,  })

# %%
bus_data
# Out:
# [{'routename': 'Guwahati to Tezpur',
#   'seat': '26 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '16 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '9 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '19 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '23 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '31 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '19 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '31 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '25 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '32 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '19 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '37 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '19 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '31 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '26 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '29 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '33 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '32 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '1 Seat available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '20 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '26 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '20 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '35 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '27 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '20 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '21 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '29 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '45 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '27 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '27 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Tezpur',
#   'seat': '28 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:30',
#   'starratings': '3.4',
#   'tickets': 'INR 396 356',
#   'reaching': '14:55',
#   ' duration': '04h 25m'},
#  {'routename': 'Guwahati to Nagaon (Assam)',
#   'seat': '16 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:50',
#   'starratings': '4.2',
#   'tickets': 'INR 341 307',
#   'reaching': '13:00',
#   ' duration': '02h 10m'},
#  {'routename': 'Guwahati to Nagaon (Assam)',
#   'seat': '9 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:50',
#   'starratings': '4.2',
#   'tickets': 'INR 341 307',
#   'reaching': '13:00',
#   ' duration': '02h 10m'},
#  {'routename': 'Guwahati to Nagaon (Assam)',
#   'seat': '16 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:50',
#   'starratings': '4.2',
#   'tickets': 'INR 341 307',
#   'reaching': '13:00',
#   ' duration': '02h 10m'},
#  {'routename': 'Guwahati to Nagaon (Assam)',
#   'seat': '32 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:50',
#   'starratings': '4.2',
#   'tickets': 'INR 341 307',
#   'reaching': '13:00',
#   ' duration': '02h 10m'},
#  {'routename': 'Guwahati to Nagaon (Assam)',
#   'seat': '',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:50',
#   'starratings': '4.2',
#   'tickets': 'INR 341 307',
#   'reaching': '13:00',
#   ' duration': '02h 10m'},
#  {'routename': 'Guwahati to Nagaon (Assam)',
#   'seat': '',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:50',
#   'starratings': '4.2',
#   'tickets': 'INR 341 307',
#   'reaching': '13:00',
#   ' duration': '02h 10m'},
#  {'routename': 'Guwahati to Nagaon (Assam)',
#   'seat': '',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:50',
#   'starratings': '4.2',
#   'tickets': 'INR 341 307',
#   'reaching': '13:00',
#   ' duration': '02h 10m'},
#  {'routename': 'Guwahati to Nagaon (Assam)',
#   'seat': '',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:50',
#   'starratings': '4.2',
#   'tickets': 'INR 341 307',
#   'reaching': '13:00',
#   ' duration': '02h 10m'},
#  {'routename': 'Guwahati to Nagaon (Assam)',
#   'seat': '',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:50',
#   'starratings': '4.2',
#   'tickets': 'INR 341 307',
#   'reaching': '13:00',
#   ' duration': '02h 10m'},
#  {'routename': 'Guwahati to Nagaon (Assam)',
#   'seat': '',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'Mahi Travels(Under ASTC)',
#   'routetimes': '10:50',
#   'starratings': '4.2',
#   'tickets': 'INR 341 307',
#   'reaching': '13:00',
#   ' duration': '02h 10m'},
#  {'routename': 'Guwahati to Dhubri',
#   'seat': '11 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater (2+2)',
#   'busnames': 'Assam State Transport Corporation (ASTC) - 150574',
#   'routetimes': '12:00',
#   'starratings': '3.7',
#   'tickets': 'INR 410',
#   'reaching': '19:00',
#   ' duration': '07h 00m'},
#  {'routename': 'Jorhat to North Lakhimpur',
#   'seat': '4 Seats available',
#   'bustypes': 'Non AC Seater (2+1)',
#   'busnames': 'Sylvan DEE Transport',
#   'routetimes': '19:30',
#   'starratings': '2.3',
#   'tickets': 'INR 560',
#   'reaching': '06:00',
#   ' duration': '10h 30m'},
#  {'routename': 'North Lakhimpur to Sibsagar (Assam)',
#   'seat': '19 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Assam State Transport Corporation (ASTC) - 173044',
#   'routetimes': '13:00',
#   'starratings': '3.0',
#   'tickets': 'INR 220',
#   'reaching': '18:30',
#   ' duration': '05h 30m'},
#  {'routename': 'Dhubri to Guwahati',
#   'seat': '40 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Yatra',
#   'routetimes': '20:15',
#   'starratings': '1.8',
#   'tickets': 'INR 350',
#   'reaching': '03:30',
#   ' duration': '07h 15m'},
#  {'routename': 'Dhubri to Guwahati',
#   'seat': '45 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Yatra',
#   'routetimes': '20:15',
#   'starratings': '1.8',
#   'tickets': 'INR 350',
#   'reaching': '03:30',
#   ' duration': '07h 15m'},
#  {'routename': 'Dhubri to Guwahati',
#   'seat': '45 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Yatra',
#   'routetimes': '20:15',
#   'starratings': '1.8',
#   'tickets': 'INR 350',
#   'reaching': '03:30',
#   ' duration': '07h 15m'},
#  {'routename': 'Dhubri to Guwahati',
#   'seat': '41 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Yatra',
#   'routetimes': '20:15',
#   'starratings': '1.8',
#   'tickets': 'INR 350',
#   'reaching': '03:30',
#   ' duration': '07h 15m'},
#  {'routename': 'Dhubri to Guwahati',
#   'seat': '41 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Yatra',
#   'routetimes': '20:15',
#   'starratings': '1.8',
#   'tickets': 'INR 350',
#   'reaching': '03:30',
#   ' duration': '07h 15m'},
#  {'routename': 'Dhubri to Guwahati',
#   'seat': '41 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Yatra',
#   'routetimes': '20:15',
#   'starratings': '1.8',
#   'tickets': 'INR 350',
#   'reaching': '03:30',
#   ' duration': '07h 15m'},
#  {'routename': 'Dhubri to Guwahati',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Yatra',
#   'routetimes': '20:15',
#   'starratings': '1.8',
#   'tickets': 'INR 350',
#   'reaching': '03:30',
#   ' duration': '07h 15m'},
#  {'routename': 'North Lakhimpur to Jorhat',
#   'seat': '26 Seats available',
#   'bustypes': 'Non AC Seater (2+1)',
#   'busnames': 'Priyanka',
#   'routetimes': '17:30',
#   'starratings': '3.9',
#   'tickets': 'INR 600',
#   'reaching': '05:00',
#   ' duration': '11h 30m'},
#  {'routename': 'Goalpara to Guwahati',
#   'seat': '33 Seats available',
#   'bustypes': 'NON A/C Seater (2+2)',
#   'busnames': 'Balaji Tours And Travels',
#   'routetimes': '10:45',
#   'starratings': '1.0',
#   'tickets': 'INR 162',
#   'reaching': '14:45',
#   ' duration': '04h 00m'},
#  {'routename': 'Goalpara to Guwahati',
#   'seat': '41 Seats available',
#   'bustypes': 'NON A/C Seater (2+2)',
#   'busnames': 'Balaji Tours And Travels',
#   'routetimes': '10:45',
#   'starratings': '1.0',
#   'tickets': 'INR 162',
#   'reaching': '14:45',
#   ' duration': '04h 00m'},
#  {'routename': 'Sibsagar (Assam) to North Lakhimpur',
#   'seat': '5 Seats available',
#   'bustypes': 'Non AC Seater (2+1)',
#   'busnames': 'Sylvan DEE Transport',
#   'routetimes': '17:30',
#   'starratings': '3.3',
#   'tickets': 'INR 660',
#   'reaching': '06:00',
#   ' duration': '12h 30m'},
#  {'routename': 'Jorhat to Dibrugarh',
#   'seat': '34 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Aroti Travels',
#   'routetimes': '12:15',
#   'starratings': '3.0',
#   'tickets': 'INR 275',
#   'reaching': '16:00',
#   ' duration': '03h 45m'},
#  {'routename': 'Jorhat to Dibrugarh',
#   'seat': '12 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Aroti Travels',
#   'routetimes': '12:15',
#   'starratings': '3.0',
#   'tickets': 'INR 275',
#   'reaching': '16:00',
#   ' duration': '03h 45m'},
#  {'routename': 'Jorhat to Dibrugarh',
#   'seat': '24 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Aroti Travels',
#   'routetimes': '12:15',
#   'starratings': '3.0',
#   'tickets': 'INR 275',
#   'reaching': '16:00',
#   ' duration': '03h 45m'},
#  {'routename': 'Jorhat to Dibrugarh',
#   'seat': '6 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Aroti Travels',
#   'routetimes': '12:15',
#   'starratings': '3.0',
#   'tickets': 'INR 275',
#   'reaching': '16:00',
#   ' duration': '03h 45m'},
#  {'routename': 'Jorhat to Dibrugarh',
#   'seat': '22 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Aroti Travels',
#   'routetimes': '12:15',
#   'starratings': '3.0',
#   'tickets': 'INR 275',
#   'reaching': '16:00',
#   ' duration': '03h 45m'},
#  {'routename': 'Jorhat to Dibrugarh',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Aroti Travels',
#   'routetimes': '12:15',
#   'starratings': '3.0',
#   'tickets': 'INR 275',
#   'reaching': '16:00',
#   ' duration': '03h 45m'},
#  {'routename': 'Jorhat to Dibrugarh',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Aroti Travels',
#   'routetimes': '12:15',
#   'starratings': '3.0',
#   'tickets': 'INR 275',
#   'reaching': '16:00',
#   ' duration': '03h 45m'},
#  {'routename': 'Jorhat to Dibrugarh',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Aroti Travels',
#   'routetimes': '12:15',
#   'starratings': '3.0',
#   'tickets': 'INR 275',
#   'reaching': '16:00',
#   ' duration': '03h 45m'}]

# %%
df=pd.DataFrame(bus_data)

# %%
df["STATE"]='assam'

# %%
df
# Out:
#               routename                seat                      bustypes  \
# 0    Guwahati to Tezpur  26 Seats available  Bharat Benz A/C Seater (2+2)
# 1    Guwahati to Tezpur  16 Seats available  Bharat Benz A/C Seater (2+2)
# 2    Guwahati to Tezpur   9 Seats available  Bharat Benz A/C Seater (2+2)
# 3    Guwahati to Tezpur  19 Seats available  Bharat Benz A/C Seater (2+2)
# 4    Guwahati to Tezpur  23 Seats available  Bharat Benz A/C Seater (2+2)
# ..                  ...                 ...                           ...
# 58  Jorhat to Dibrugarh   6 Seats available           Non AC Seater (2+2)
# 59  Jorhat to Dibrugarh  22 Seats available           Non AC Seater (2+2)
# 60  Jorhat to Dibrugarh                               Non AC Seater (2+2)
# 61  Jorhat to Dibrugarh                               Non AC Seater (2+2)
# 62  Jorhat to Dibrugarh                               Non AC Seater (2+2)
#
#                     busnames routetimes starratings      tickets reaching  \
# 0   Mahi Travels(Under ASTC)      10:30         3.4  INR 396 356    14:55
# 1   Mahi Travels(Under ASTC)      10:30         3.4  INR 396 356    14:55
# 2   Mahi Travels(Under ASTC)      10:30         3.4  INR 396 356    14:55
# 3   Mahi Travels(Under ASTC)      10:30         3.4  INR 396 356    14:55
# 4   Mahi Travels(Under ASTC)      10:30         3.4  INR 396 356    14:55
# ..                       ...        ...         ...          ...      ...
# 58             Aroti Travels      12:15         3.0      INR 275    16:00
# 59             Aroti Travels      12:15         3.0      INR 275    16:00
# 60             Aroti Travels      12:15         3.0      INR 275    16:00
# 61             Aroti Travels      12:15         3.0      INR 275    16:00
# 62             Aroti Travels      12:15         3.0      INR 275    16:00
#
#     duration  STATE
# 0    04h 25m  assam
# 1    04h 25m  assam
# 2    04h 25m  assam
# 3    04h 25m  assam
# 4    04h 25m  assam
# ..       ...    ...
# 58   03h 45m  assam
# 59   03h 45m  assam
# 60   03h 45m  assam
# 61   03h 45m  assam
# 62   03h 45m  assam
#
# [63 rows x 10 columns]

# %%
df.to_csv("assam.csv",index=False)
