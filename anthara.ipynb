# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time
import csv
import pandas as pd

# %%
import pandas as pd

# %%
#Full 5 pages- code


driver = webdriver.Chrome()

driver.get("https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile")

wait = WebDriverWait(driver, 20)

all_data = []

def scrape_page():
    # Locate elements
    routes = wait.until(EC.presence_of_all_elements_located((By.CLASS_NAME, "route_link")))

    # Loop through each route to extract details
    for route in routes:
        try:
            route_link = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("href")
            title = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("title")

            # Append extracted data to list
            all_data.append({
                "route_link": route_link,
                "title": title,
                
            })
        except Exception as e:
            print(f"An error occurred: {e}")
            continue
# Scrape data from the first 5 pages

for page_number in range(1, 6):
    scrape_page()
    if page_number < 5:  # Don't try to click next on the last page
        try:
            # Locate the pagination container
            pagination_container = wait.until(EC.presence_of_element_located(
                (By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')
            ))

            # Locate the next page button within the container
            next_page_button = pagination_container.find_element(
                By.XPATH, f'.//div[contains(@class, "DC_117_pageTabs") and text()="{page_number + 1}"]'
            )

            # Scroll the next page button into view
            driver.execute_script("arguments[0].scrollIntoView();", next_page_button)
            time.sleep(1)  # Wait for a bit after scrolling

            # Log the action
            print(f"Clicking on page {page_number + 1}")

            # Click the next page button
            next_page_button.click()

            # Wait for the page number to update to the next page
            wait.until(EC.text_to_be_present_in_element(
                (By.XPATH, '//div[contains(@class, "DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))

            # Log the successful page navigation
            print(f"Successfully navigated to page {page_number + 1}")

            # Wait for a short duration to ensure the next page loads completely
            time.sleep(3)
        except Exception as e:
            print(f"An error occurred while navigating to page {page_number + 1}: {e}")
            break

# Print the scraped data
for entry in all_data:
    print(entry)
# Out:
# Clicking on page 2
# An error occurred while navigating to page 2: Message: element click intercepted: Element is not clickable at point (469, 2092)
#   (Session info: chrome=134.0.6998.89)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF608C3FE65+26629]
# 	(No symbol) [0x00007FF608BA6030]
# 	(No symbol) [0x00007FF608A3931A]
# 	(No symbol) [0x00007FF608A977A9]
# 	(No symbol) [0x00007FF608A95162]
# 	(No symbol) [0x00007FF608A92201]
# 	(No symbol) [0x00007FF608A91108]
# 	(No symbol) [0x00007FF608A828A4]
# 	(No symbol) [0x00007FF608AB7AAA]
# 	(No symbol) [0x00007FF608A82156]
# 	(No symbol) [0x00007FF608AB7CC0]
# 	(No symbol) [0x00007FF608AE0169]
# 	(No symbol) [0x00007FF608AB7883]
# 	(No symbol) [0x00007FF608A80550]
# 	(No symbol) [0x00007FF608A81803]
# 	GetHandleVerifier [0x00007FF608F972DD+3529853]
# 	GetHandleVerifier [0x00007FF608FADA42+3621858]
# 	GetHandleVerifier [0x00007FF608FA24F3+3575443]
# 	GetHandleVerifier [0x00007FF608D0B79A+860474]
# 	(No symbol) [0x00007FF608BB08AF]
# 	(No symbol) [0x00007FF608BACBE4]
# 	(No symbol) [0x00007FF608BACD86]
# 	(No symbol) [0x00007FF608B9C2E9]
# 	BaseThreadInitThunk [0x00007FF9505EE8D7+23]
# 	RtlUserThreadStart [0x00007FF9514DBF6C+44]
#
# {'route_link': 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada', 'title': 'Hyderabad to Vijayawada'}
# {'route_link': 'https://www.redbus.in/bus-tickets/vijayawada-to-hyderabad', 'title': 'Vijayawada to Hyderabad'}
# {'route_link': 'https://www.redbus.in/bus-tickets/bangalore-to-tirupathi', 'title': 'Bangalore to Tirupati'}
# {'route_link': 'https://www.redbus.in/bus-tickets/bangalore-to-kadapa', 'title': 'Bangalore to Kadapa'}
# {'route_link': 'https://www.redbus.in/bus-tickets/kakinada-to-visakhapatnam', 'title': 'Kakinada to Visakhapatnam'}
# {'route_link': 'https://www.redbus.in/bus-tickets/hyderabad-to-ongole', 'title': 'Hyderabad to Ongole'}
# {'route_link': 'https://www.redbus.in/bus-tickets/ongole-to-hyderabad', 'title': 'Ongole to Hyderabad'}
# {'route_link': 'https://www.redbus.in/bus-tickets/bangalore-to-ananthapur', 'title': 'Bangalore to Anantapur (andhra pradesh)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/bangalore-to-chittoor-andhra-pradesh', 'title': 'Bangalore to Chittoor (Andhra Pradesh)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/chittoor-andhra-pradesh-to-bangalore', 'title': 'Chittoor (Andhra Pradesh) to Bangalore'}

# %%
route_links=[(item['route_link'],item["title"]) for item in all_data]
route_links
# Out:
# [('https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada',
#   'Hyderabad to Vijayawada'),
#  ('https://www.redbus.in/bus-tickets/vijayawada-to-hyderabad',
#   'Vijayawada to Hyderabad'),
#  ('https://www.redbus.in/bus-tickets/bangalore-to-tirupathi',
#   'Bangalore to Tirupati'),
#  ('https://www.redbus.in/bus-tickets/bangalore-to-kadapa',
#   'Bangalore to Kadapa'),
#  ('https://www.redbus.in/bus-tickets/kakinada-to-visakhapatnam',
#   'Kakinada to Visakhapatnam'),
#  ('https://www.redbus.in/bus-tickets/hyderabad-to-ongole',
#   'Hyderabad to Ongole'),
#  ('https://www.redbus.in/bus-tickets/ongole-to-hyderabad',
#   'Ongole to Hyderabad'),
#  ('https://www.redbus.in/bus-tickets/bangalore-to-ananthapur',
#   'Bangalore to Anantapur (andhra pradesh)'),
#  ('https://www.redbus.in/bus-tickets/bangalore-to-chittoor-andhra-pradesh',
#   'Bangalore to Chittoor (Andhra Pradesh)'),
#  ('https://www.redbus.in/bus-tickets/chittoor-andhra-pradesh-to-bangalore',
#   'Chittoor (Andhra Pradesh) to Bangalore')]

# %%
driver = webdriver.Chrome()
time.sleep(5)

def  scroll():
   x=0
   l=[]
   while True:
        x=x+1
        driver.execute_script('scrollBy(0,100)')
        #time.sleep(5)
        if(x>1000):
         break
bus_data=[]
for i, j in route_links:
    driver.get(i)

    scroll()




    bus_box= driver.find_elements(By.XPATH, '//div[@class="clearfix bus-item  "]')

    for bus in bus_box:
                        
                    reaching_time=bus.find_element(By.XPATH,'//div[@class="bp-time f-19 d-color disp-Inline"]').text
                    duration_time = bus.find_element(By.XPATH,'//div[@class="dur l-color lh-24"]').text
                     
                    seats_available=bus.find_element(By.CLASS_NAME,'seat-left').text
                    

                    bus_type = bus.find_element(By.XPATH, '//div[@class="bus-type f-12 m-top-16 l-color evBus"]').text


                    bus_names = bus.find_element(By.XPATH, '//div[@class="travels lh-24 f-bold d-color"]').text

                    route_times =bus.find_element(By.XPATH,'//div[@class="dp-time f-19 d-color f-bold"]').text
                    try:
                        star_ratings = bus.find_element(By.XPATH, '//div[@class="lh-18 rating rat-green "]').text
                    except:
                          star_ratings="na"
                    try:
                       ticket_rates =bus.find_element(By.XPATH, '//div[@class="seat-fare "]').text
                    except:
                         ticket_rates="na"   
                         
                    bus_data.append({'routename':j,'seat':seats_available,'bustypes':bus_type,'busnames':bus_names,'routetimes':route_times,'starratings':star_ratings,'tickets':ticket_rates,
                        "reaching":reaching_time," duration":duration_time,  })

# %%
bus_data
# Out:
# [{'routename': 'Hyderabad to Vijayawada',
#   'seat': '22 Seats available',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Hyderabad to Vijayawada',
#   'seat': '23 Seats available',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Hyderabad to Vijayawada',
#   'seat': '16 Seats available',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Hyderabad to Vijayawada',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Hyderabad to Vijayawada',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '12:50',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 349 249',
#   'reaching': '19:30',
#   ' duration': '06h 40m'},
#  {'routename': 'Vijayawada to Hyderabad',
#   'seat': '18 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'IntrCity SmartBus',
#   'routetimes': '22:45',
#   'starratings': '4.6',
#   'tickets': 'Starts from\nINR 349',
#   'reaching': '05:40',
#   ' duration': '06h 55m'},
#  {'routename': 'Vijayawada to Hyderabad',
#   'seat': '18 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'IntrCity SmartBus',
#   'routetimes': '22:45',
#   'starratings': '4.6',
#   'tickets': 'Starts from\nINR 349',
#   'reaching': '05:40',
#   ' duration': '06h 55m'},
#  {'routename': 'Vijayawada to Hyderabad',
#   'seat': '17 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'IntrCity SmartBus',
#   'routetimes': '22:45',
#   'starratings': '4.6',
#   'tickets': 'Starts from\nINR 349',
#   'reaching': '05:40',
#   ' duration': '06h 55m'},
#  {'routename': 'Vijayawada to Hyderabad',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'IntrCity SmartBus',
#   'routetimes': '22:45',
#   'starratings': '4.6',
#   'tickets': 'Starts from\nINR 349',
#   'reaching': '05:40',
#   ' duration': '06h 55m'},
#  {'routename': 'Vijayawada to Hyderabad',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'IntrCity SmartBus',
#   'routetimes': '22:45',
#   'starratings': '4.6',
#   'tickets': 'Starts from\nINR 349',
#   'reaching': '05:40',
#   ' duration': '06h 55m'},
#  {'routename': 'Bangalore to Tirupati',
#   'seat': '2 Seats available',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:05',
#   'starratings': '4.5',
#   'tickets': 'INR 349 249',
#   'reaching': '14:30',
#   ' duration': '05h 25m'},
#  {'routename': 'Bangalore to Tirupati',
#   'seat': '8 Seats available',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:05',
#   'starratings': '4.5',
#   'tickets': 'INR 349 249',
#   'reaching': '14:30',
#   ' duration': '05h 25m'},
#  {'routename': 'Bangalore to Tirupati',
#   'seat': '2 Seats available',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:05',
#   'starratings': '4.5',
#   'tickets': 'INR 349 249',
#   'reaching': '14:30',
#   ' duration': '05h 25m'},
#  {'routename': 'Bangalore to Tirupati',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:05',
#   'starratings': '4.5',
#   'tickets': 'INR 349 249',
#   'reaching': '14:30',
#   ' duration': '05h 25m'},
#  {'routename': 'Bangalore to Tirupati',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:05',
#   'starratings': '4.5',
#   'tickets': 'INR 349 249',
#   'reaching': '14:30',
#   ' duration': '05h 25m'},
#  {'routename': 'Bangalore to Kadapa',
#   'seat': '23 Seats available',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'Shiva Parvathi Tours And Travels',
#   'routetimes': '19:00',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 800',
#   'reaching': '02:30',
#   ' duration': '07h 30m'},
#  {'routename': 'Bangalore to Kadapa',
#   'seat': '20 Seats available',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'Shiva Parvathi Tours And Travels',
#   'routetimes': '19:00',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 800',
#   'reaching': '02:30',
#   ' duration': '07h 30m'},
#  {'routename': 'Bangalore to Kadapa',
#   'seat': '19 Seats available',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'Shiva Parvathi Tours And Travels',
#   'routetimes': '19:00',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 800',
#   'reaching': '02:30',
#   ' duration': '07h 30m'},
#  {'routename': 'Bangalore to Kadapa',
#   'seat': '28 Seats available',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'Shiva Parvathi Tours And Travels',
#   'routetimes': '19:00',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 800',
#   'reaching': '02:30',
#   ' duration': '07h 30m'},
#  {'routename': 'Bangalore to Kadapa',
#   'seat': '',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'Shiva Parvathi Tours And Travels',
#   'routetimes': '19:00',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 800',
#   'reaching': '02:30',
#   ' duration': '07h 30m'},
#  {'routename': 'Kakinada to Visakhapatnam',
#   'seat': '35 Seats available',
#   'bustypes': 'Non A/C Seater / Sleeper (2+1)',
#   'busnames': 'SRI VIJAYA KRISHNA TOURS and TRAVELS',
#   'routetimes': '23:59',
#   'starratings': 'na',
#   'tickets': 'Starts from\nINR 499',
#   'reaching': '04:30',
#   ' duration': '04h 31m'},
#  {'routename': 'Hyderabad to Ongole',
#   'seat': '19 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Sri Vengamamba Bus Transport (SVBT)',
#   'routetimes': '21:45',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 672',
#   'reaching': '06:15',
#   ' duration': '08h 30m'},
#  {'routename': 'Hyderabad to Ongole',
#   'seat': '33 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Sri Vengamamba Bus Transport (SVBT)',
#   'routetimes': '21:45',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 672',
#   'reaching': '06:15',
#   ' duration': '08h 30m'},
#  {'routename': 'Hyderabad to Ongole',
#   'seat': '27 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Sri Vengamamba Bus Transport (SVBT)',
#   'routetimes': '21:45',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 672',
#   'reaching': '06:15',
#   ' duration': '08h 30m'},
#  {'routename': 'Hyderabad to Ongole',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Sri Vengamamba Bus Transport (SVBT)',
#   'routetimes': '21:45',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 672',
#   'reaching': '06:15',
#   ' duration': '08h 30m'},
#  {'routename': 'Hyderabad to Ongole',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Sri Vengamamba Bus Transport (SVBT)',
#   'routetimes': '21:45',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 672',
#   'reaching': '06:15',
#   ' duration': '08h 30m'},
#  {'routename': 'Ongole to Hyderabad',
#   'seat': '34 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Vikram Travels',
#   'routetimes': '23:15',
#   'starratings': '4.6',
#   'tickets': 'Starts from\nINR 499',
#   'reaching': '06:18',
#   ' duration': '07h 03m'},
#  {'routename': 'Ongole to Hyderabad',
#   'seat': '14 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Vikram Travels',
#   'routetimes': '23:15',
#   'starratings': '4.6',
#   'tickets': 'Starts from\nINR 499',
#   'reaching': '06:18',
#   ' duration': '07h 03m'},
#  {'routename': 'Ongole to Hyderabad',
#   'seat': '22 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Vikram Travels',
#   'routetimes': '23:15',
#   'starratings': '4.6',
#   'tickets': 'Starts from\nINR 499',
#   'reaching': '06:18',
#   ' duration': '07h 03m'},
#  {'routename': 'Ongole to Hyderabad',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Vikram Travels',
#   'routetimes': '23:15',
#   'starratings': '4.6',
#   'tickets': 'Starts from\nINR 499',
#   'reaching': '06:18',
#   ' duration': '07h 03m'},
#  {'routename': 'Ongole to Hyderabad',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'Vikram Travels',
#   'routetimes': '23:15',
#   'starratings': '4.6',
#   'tickets': 'Starts from\nINR 499',
#   'reaching': '06:18',
#   ' duration': '07h 03m'},
#  {'routename': 'Bangalore to Anantapur (andhra pradesh)',
#   'seat': '25 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'IntrCity SmartBus',
#   'routetimes': '18:50',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 949',
#   'reaching': '22:45',
#   ' duration': '03h 55m'},
#  {'routename': 'Bangalore to Anantapur (andhra pradesh)',
#   'seat': '24 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'IntrCity SmartBus',
#   'routetimes': '18:50',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 949',
#   'reaching': '22:45',
#   ' duration': '03h 55m'},
#  {'routename': 'Bangalore to Anantapur (andhra pradesh)',
#   'seat': '24 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'IntrCity SmartBus',
#   'routetimes': '18:50',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 949',
#   'reaching': '22:45',
#   ' duration': '03h 55m'},
#  {'routename': 'Bangalore to Anantapur (andhra pradesh)',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'IntrCity SmartBus',
#   'routetimes': '18:50',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 949',
#   'reaching': '22:45',
#   ' duration': '03h 55m'},
#  {'routename': 'Bangalore to Anantapur (andhra pradesh)',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'IntrCity SmartBus',
#   'routetimes': '18:50',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 949',
#   'reaching': '22:45',
#   ' duration': '03h 55m'},
#  {'routename': 'Bangalore to Chittoor (Andhra Pradesh)',
#   'seat': '1 Seat available',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:20',
#   'starratings': '4.2',
#   'tickets': 'INR 349 249',
#   'reaching': '13:00',
#   ' duration': '03h 40m'},
#  {'routename': 'Bangalore to Chittoor (Andhra Pradesh)',
#   'seat': '8 Seats available',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:20',
#   'starratings': '4.2',
#   'tickets': 'INR 349 249',
#   'reaching': '13:00',
#   ' duration': '03h 40m'},
#  {'routename': 'Bangalore to Chittoor (Andhra Pradesh)',
#   'seat': '5 Seats available',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:20',
#   'starratings': '4.2',
#   'tickets': 'INR 349 249',
#   'reaching': '13:00',
#   ' duration': '03h 40m'},
#  {'routename': 'Bangalore to Chittoor (Andhra Pradesh)',
#   'seat': '14 Seats available',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:20',
#   'starratings': '4.2',
#   'tickets': 'INR 349 249',
#   'reaching': '13:00',
#   ' duration': '03h 40m'},
#  {'routename': 'Bangalore to Chittoor (Andhra Pradesh)',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:20',
#   'starratings': '4.2',
#   'tickets': 'INR 349 249',
#   'reaching': '13:00',
#   ' duration': '03h 40m'},
#  {'routename': 'Bangalore to Chittoor (Andhra Pradesh)',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:20',
#   'starratings': '4.2',
#   'tickets': 'INR 349 249',
#   'reaching': '13:00',
#   ' duration': '03h 40m'},
#  {'routename': 'Bangalore to Chittoor (Andhra Pradesh)',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:20',
#   'starratings': '4.2',
#   'tickets': 'INR 349 249',
#   'reaching': '13:00',
#   ' duration': '03h 40m'},
#  {'routename': 'Bangalore to Chittoor (Andhra Pradesh)',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:20',
#   'starratings': '4.2',
#   'tickets': 'INR 349 249',
#   'reaching': '13:00',
#   ' duration': '03h 40m'},
#  {'routename': 'Bangalore to Chittoor (Andhra Pradesh)',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:20',
#   'starratings': '4.2',
#   'tickets': 'INR 349 249',
#   'reaching': '13:00',
#   ' duration': '03h 40m'},
#  {'routename': 'Bangalore to Chittoor (Andhra Pradesh)',
#   'seat': '',
#   'bustypes': 'Electric A/C Seater (2+2)',
#   'busnames': 'FRESHBUS',
#   'routetimes': '09:20',
#   'starratings': '4.2',
#   'tickets': 'INR 349 249',
#   'reaching': '13:00',
#   ' duration': '03h 40m'},
#  {'routename': 'Chittoor (Andhra Pradesh) to Bangalore',
#   'seat': '21 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Yolo Bus',
#   'routetimes': '09:22',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 250 125',
#   'reaching': '13:59',
#   ' duration': '04h 37m'},
#  {'routename': 'Chittoor (Andhra Pradesh) to Bangalore',
#   'seat': '15 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Yolo Bus',
#   'routetimes': '09:22',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 250 125',
#   'reaching': '13:59',
#   ' duration': '04h 37m'},
#  {'routename': 'Chittoor (Andhra Pradesh) to Bangalore',
#   'seat': '20 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Yolo Bus',
#   'routetimes': '09:22',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 250 125',
#   'reaching': '13:59',
#   ' duration': '04h 37m'},
#  {'routename': 'Chittoor (Andhra Pradesh) to Bangalore',
#   'seat': '58 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Yolo Bus',
#   'routetimes': '09:22',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 250 125',
#   'reaching': '13:59',
#   ' duration': '04h 37m'},
#  {'routename': 'Chittoor (Andhra Pradesh) to Bangalore',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Yolo Bus',
#   'routetimes': '09:22',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 250 125',
#   'reaching': '13:59',
#   ' duration': '04h 37m'},
#  {'routename': 'Chittoor (Andhra Pradesh) to Bangalore',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Yolo Bus',
#   'routetimes': '09:22',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 250 125',
#   'reaching': '13:59',
#   ' duration': '04h 37m'},
#  {'routename': 'Chittoor (Andhra Pradesh) to Bangalore',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Yolo Bus',
#   'routetimes': '09:22',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 250 125',
#   'reaching': '13:59',
#   ' duration': '04h 37m'},
#  {'routename': 'Chittoor (Andhra Pradesh) to Bangalore',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Yolo Bus',
#   'routetimes': '09:22',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 250 125',
#   'reaching': '13:59',
#   ' duration': '04h 37m'},
#  {'routename': 'Chittoor (Andhra Pradesh) to Bangalore',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Yolo Bus',
#   'routetimes': '09:22',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 250 125',
#   'reaching': '13:59',
#   ' duration': '04h 37m'},
#  {'routename': 'Chittoor (Andhra Pradesh) to Bangalore',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Yolo Bus',
#   'routetimes': '09:22',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 250 125',
#   'reaching': '13:59',
#   ' duration': '04h 37m'}]

# %%
df=pd.DataFrame(bus_data)

# %%
df['STATE']="anthara"

# %%
df
# Out:
#                                   routename                seat  \
# 0                   Hyderabad to Vijayawada  22 Seats available
# 1                   Hyderabad to Vijayawada  23 Seats available
# 2                   Hyderabad to Vijayawada  16 Seats available
# 3                   Hyderabad to Vijayawada
# 4                   Hyderabad to Vijayawada
# 5                   Vijayawada to Hyderabad  18 Seats available
# 6                   Vijayawada to Hyderabad  18 Seats available
# 7                   Vijayawada to Hyderabad  17 Seats available
# 8                   Vijayawada to Hyderabad
# 9                   Vijayawada to Hyderabad
# 10                    Bangalore to Tirupati   2 Seats available
# 11                    Bangalore to Tirupati   8 Seats available
# 12                    Bangalore to Tirupati   2 Seats available
# 13                    Bangalore to Tirupati
# 14                    Bangalore to Tirupati
# 15                      Bangalore to Kadapa  23 Seats available
# 16                      Bangalore to Kadapa  20 Seats available
# 17                      Bangalore to Kadapa  19 Seats available
# 18                      Bangalore to Kadapa  28 Seats available
# 19                      Bangalore to Kadapa
# 20                Kakinada to Visakhapatnam  35 Seats available
# 21                      Hyderabad to Ongole  19 Seats available
# 22                      Hyderabad to Ongole  33 Seats available
# 23                      Hyderabad to Ongole  27 Seats available
# 24                      Hyderabad to Ongole
# 25                      Hyderabad to Ongole
# 26                      Ongole to Hyderabad  34 Seats available
# 27                      Ongole to Hyderabad  14 Seats available
# 28                      Ongole to Hyderabad  22 Seats available
# 29                      Ongole to Hyderabad
# 30                      Ongole to Hyderabad
# 31  Bangalore to Anantapur (andhra pradesh)  25 Seats available
# 32  Bangalore to Anantapur (andhra pradesh)  24 Seats available
# 33  Bangalore to Anantapur (andhra pradesh)  24 Seats available
# 34  Bangalore to Anantapur (andhra pradesh)
# 35  Bangalore to Anantapur (andhra pradesh)
# 36   Bangalore to Chittoor (Andhra Pradesh)    1 Seat available
# 37   Bangalore to Chittoor (Andhra Pradesh)   8 Seats available
# 38   Bangalore to Chittoor (Andhra Pradesh)   5 Seats available
# 39   Bangalore to Chittoor (Andhra Pradesh)  14 Seats available
# 40   Bangalore to Chittoor (Andhra Pradesh)
# 41   Bangalore to Chittoor (Andhra Pradesh)
# 42   Bangalore to Chittoor (Andhra Pradesh)
# 43   Bangalore to Chittoor (Andhra Pradesh)
# 44   Bangalore to Chittoor (Andhra Pradesh)
# 45   Bangalore to Chittoor (Andhra Pradesh)
# 46   Chittoor (Andhra Pradesh) to Bangalore  21 Seats available
# 47   Chittoor (Andhra Pradesh) to Bangalore  15 Seats available
# 48   Chittoor (Andhra Pradesh) to Bangalore  20 Seats available
# 49   Chittoor (Andhra Pradesh) to Bangalore  58 Seats available
# 50   Chittoor (Andhra Pradesh) to Bangalore
# 51   Chittoor (Andhra Pradesh) to Bangalore
# 52   Chittoor (Andhra Pradesh) to Bangalore
# 53   Chittoor (Andhra Pradesh) to Bangalore
# 54   Chittoor (Andhra Pradesh) to Bangalore
# 55   Chittoor (Andhra Pradesh) to Bangalore
#
#                                  bustypes  \
# 0               Electric A/C Seater (2+2)
# 1               Electric A/C Seater (2+2)
# 2               Electric A/C Seater (2+2)
# 3               Electric A/C Seater (2+2)
# 4               Electric A/C Seater (2+2)
# 5              A/C Seater / Sleeper (2+1)
# 6              A/C Seater / Sleeper (2+1)
# 7              A/C Seater / Sleeper (2+1)
# 8              A/C Seater / Sleeper (2+1)
# 9              A/C Seater / Sleeper (2+1)
# 10              Electric A/C Seater (2+2)
# 11              Electric A/C Seater (2+2)
# 12              Electric A/C Seater (2+2)
# 13              Electric A/C Seater (2+2)
# 14              Electric A/C Seater (2+2)
# 15         Non A/C Seater / Sleeper (2+1)
# 16         Non A/C Seater / Sleeper (2+1)
# 17         Non A/C Seater / Sleeper (2+1)
# 18         Non A/C Seater / Sleeper (2+1)
# 19         Non A/C Seater / Sleeper (2+1)
# 20         Non A/C Seater / Sleeper (2+1)
# 21             A/C Seater / Sleeper (2+1)
# 22             A/C Seater / Sleeper (2+1)
# 23             A/C Seater / Sleeper (2+1)
# 24             A/C Seater / Sleeper (2+1)
# 25             A/C Seater / Sleeper (2+1)
# 26             A/C Seater / Sleeper (2+1)
# 27             A/C Seater / Sleeper (2+1)
# 28             A/C Seater / Sleeper (2+1)
# 29             A/C Seater / Sleeper (2+1)
# 30             A/C Seater / Sleeper (2+1)
# 31             A/C Seater / Sleeper (2+1)
# 32             A/C Seater / Sleeper (2+1)
# 33             A/C Seater / Sleeper (2+1)
# 34             A/C Seater / Sleeper (2+1)
# 35             A/C Seater / Sleeper (2+1)
# 36              Electric A/C Seater (2+2)
# 37              Electric A/C Seater (2+2)
# 38              Electric A/C Seater (2+2)
# 39              Electric A/C Seater (2+2)
# 40              Electric A/C Seater (2+2)
# 41              Electric A/C Seater (2+2)
# 42              Electric A/C Seater (2+2)
# 43              Electric A/C Seater (2+2)
# 44              Electric A/C Seater (2+2)
# 45              Electric A/C Seater (2+2)
# 46  Bharat Benz A/C Seater /Sleeper (2+1)
# 47  Bharat Benz A/C Seater /Sleeper (2+1)
# 48  Bharat Benz A/C Seater /Sleeper (2+1)
# 49  Bharat Benz A/C Seater /Sleeper (2+1)
# 50  Bharat Benz A/C Seater /Sleeper (2+1)
# 51  Bharat Benz A/C Seater /Sleeper (2+1)
# 52  Bharat Benz A/C Seater /Sleeper (2+1)
# 53  Bharat Benz A/C Seater /Sleeper (2+1)
# 54  Bharat Benz A/C Seater /Sleeper (2+1)
# 55  Bharat Benz A/C Seater /Sleeper (2+1)
#
#                                 busnames routetimes starratings  \
# 0                               FRESHBUS      12:50         4.7
# 1                               FRESHBUS      12:50         4.7
# 2                               FRESHBUS      12:50         4.7
# 3                               FRESHBUS      12:50         4.7
# 4                               FRESHBUS      12:50         4.7
# 5                      IntrCity SmartBus      22:45         4.6
# 6                      IntrCity SmartBus      22:45         4.6
# 7                      IntrCity SmartBus      22:45         4.6
# 8                      IntrCity SmartBus      22:45         4.6
# 9                      IntrCity SmartBus      22:45         4.6
# 10                              FRESHBUS      09:05         4.5
# 11                              FRESHBUS      09:05         4.5
# 12                              FRESHBUS      09:05         4.5
# 13                              FRESHBUS      09:05         4.5
# 14                              FRESHBUS      09:05         4.5
# 15      Shiva Parvathi Tours And Travels      19:00         4.3
# 16      Shiva Parvathi Tours And Travels      19:00         4.3
# 17      Shiva Parvathi Tours And Travels      19:00         4.3
# 18      Shiva Parvathi Tours And Travels      19:00         4.3
# 19      Shiva Parvathi Tours And Travels      19:00         4.3
# 20  SRI VIJAYA KRISHNA TOURS and TRAVELS      23:59          na
# 21   Sri Vengamamba Bus Transport (SVBT)      21:45         4.4
# 22   Sri Vengamamba Bus Transport (SVBT)      21:45         4.4
# 23   Sri Vengamamba Bus Transport (SVBT)      21:45         4.4
# 24   Sri Vengamamba Bus Transport (SVBT)      21:45         4.4
# 25   Sri Vengamamba Bus Transport (SVBT)      21:45         4.4
# 26                        Vikram Travels      23:15         4.6
# 27                        Vikram Travels      23:15         4.6
# 28                        Vikram Travels      23:15         4.6
# 29                        Vikram Travels      23:15         4.6
# 30                        Vikram Travels      23:15         4.6
# 31                     IntrCity SmartBus      18:50         4.7
# 32                     IntrCity SmartBus      18:50         4.7
# 33                     IntrCity SmartBus      18:50         4.7
# 34                     IntrCity SmartBus      18:50         4.7
# 35                     IntrCity SmartBus      18:50         4.7
# 36                              FRESHBUS      09:20         4.2
# 37                              FRESHBUS      09:20         4.2
# 38                              FRESHBUS      09:20         4.2
# 39                              FRESHBUS      09:20         4.2
# 40                              FRESHBUS      09:20         4.2
# 41                              FRESHBUS      09:20         4.2
# 42                              FRESHBUS      09:20         4.2
# 43                              FRESHBUS      09:20         4.2
# 44                              FRESHBUS      09:20         4.2
# 45                              FRESHBUS      09:20         4.2
# 46                              Yolo Bus      09:22         4.3
# 47                              Yolo Bus      09:22         4.3
# 48                              Yolo Bus      09:22         4.3
# 49                              Yolo Bus      09:22         4.3
# 50                              Yolo Bus      09:22         4.3
# 51                              Yolo Bus      09:22         4.3
# 52                              Yolo Bus      09:22         4.3
# 53                              Yolo Bus      09:22         4.3
# 54                              Yolo Bus      09:22         4.3
# 55                              Yolo Bus      09:22         4.3
#
#                      tickets reaching  duration    STATE
# 0   Starts from\nINR 349 249    19:30   06h 40m  anthara
# 1   Starts from\nINR 349 249    19:30   06h 40m  anthara
# 2   Starts from\nINR 349 249    19:30   06h 40m  anthara
# 3   Starts from\nINR 349 249    19:30   06h 40m  anthara
# 4   Starts from\nINR 349 249    19:30   06h 40m  anthara
# 5       Starts from\nINR 349    05:40   06h 55m  anthara
# 6       Starts from\nINR 349    05:40   06h 55m  anthara
# 7       Starts from\nINR 349    05:40   06h 55m  anthara
# 8       Starts from\nINR 349    05:40   06h 55m  anthara
# 9       Starts from\nINR 349    05:40   06h 55m  anthara
# 10               INR 349 249    14:30   05h 25m  anthara
# 11               INR 349 249    14:30   05h 25m  anthara
# 12               INR 349 249    14:30   05h 25m  anthara
# 13               INR 349 249    14:30   05h 25m  anthara
# 14               INR 349 249    14:30   05h 25m  anthara
# 15      Starts from\nINR 800    02:30   07h 30m  anthara
# 16      Starts from\nINR 800    02:30   07h 30m  anthara
# 17      Starts from\nINR 800    02:30   07h 30m  anthara
# 18      Starts from\nINR 800    02:30   07h 30m  anthara
# 19      Starts from\nINR 800    02:30   07h 30m  anthara
# 20      Starts from\nINR 499    04:30   04h 31m  anthara
# 21      Starts from\nINR 672    06:15   08h 30m  anthara
# 22      Starts from\nINR 672    06:15   08h 30m  anthara
# 23      Starts from\nINR 672    06:15   08h 30m  anthara
# 24      Starts from\nINR 672    06:15   08h 30m  anthara
# 25      Starts from\nINR 672    06:15   08h 30m  anthara
# 26      Starts from\nINR 499    06:18   07h 03m  anthara
# 27      Starts from\nINR 499    06:18   07h 03m  anthara
# 28      Starts from\nINR 499    06:18   07h 03m  anthara
# 29      Starts from\nINR 499    06:18   07h 03m  anthara
# 30      Starts from\nINR 499    06:18   07h 03m  anthara
# 31      Starts from\nINR 949    22:45   03h 55m  anthara
# 32      Starts from\nINR 949    22:45   03h 55m  anthara
# 33      Starts from\nINR 949    22:45   03h 55m  anthara
# 34      Starts from\nINR 949    22:45   03h 55m  anthara
# 35      Starts from\nINR 949    22:45   03h 55m  anthara
# 36               INR 349 249    13:00   03h 40m  anthara
# 37               INR 349 249    13:00   03h 40m  anthara
# 38               INR 349 249    13:00   03h 40m  anthara
# 39               INR 349 249    13:00   03h 40m  anthara
# 40               INR 349 249    13:00   03h 40m  anthara
# 41               INR 349 249    13:00   03h 40m  anthara
# 42               INR 349 249    13:00   03h 40m  anthara
# 43               INR 349 249    13:00   03h 40m  anthara
# 44               INR 349 249    13:00   03h 40m  anthara
# 45               INR 349 249    13:00   03h 40m  anthara
# 46  Starts from\nINR 250 125    13:59   04h 37m  anthara
# 47  Starts from\nINR 250 125    13:59   04h 37m  anthara
# 48  Starts from\nINR 250 125    13:59   04h 37m  anthara
# 49  Starts from\nINR 250 125    13:59   04h 37m  anthara
# 50  Starts from\nINR 250 125    13:59   04h 37m  anthara
# 51  Starts from\nINR 250 125    13:59   04h 37m  anthara
# 52  Starts from\nINR 250 125    13:59   04h 37m  anthara
# 53  Starts from\nINR 250 125    13:59   04h 37m  anthara
# 54  Starts from\nINR 250 125    13:59   04h 37m  anthara
# 55  Starts from\nINR 250 125    13:59   04h 37m  anthara

# %%
df.to_csv("anthara.csv",index=False)
