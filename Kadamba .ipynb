# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time
import csv
import pandas as pd

# %%
#Full 5 pages- code


driver = webdriver.Chrome()

driver.get("https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile")

wait = WebDriverWait(driver, 20)

all_data = []

def scrape_page():
    # Locate elements
    routes = wait.until(EC.presence_of_all_elements_located((By.CLASS_NAME, "route_link")))

    # Loop through each route to extract details
    for route in routes:
        try:
            route_link = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("href")
            title = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("title")

            # Append extracted data to list
            all_data.append({
                "route_link": route_link,
                "title": title,
                
            })
        except Exception as e:
            print(f"An error occurred: {e}")
            continue
# Scrape data from the first 5 pages

for page_number in range(1, 6):
    scrape_page()
    if page_number < 5:  # Don't try to click next on the last page
        try:
            # Locate the pagination container
            pagination_container = wait.until(EC.presence_of_element_located(
                (By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')
            ))

            # Locate the next page button within the container
            next_page_button = pagination_container.find_element(
                By.XPATH, f'.//div[contains(@class, "DC_117_pageTabs") and text()="{page_number + 1}"]'
            )

            # Scroll the next page button into view
            driver.execute_script("arguments[0].scrollIntoView();", next_page_button)
            time.sleep(1)  # Wait for a bit after scrolling

            # Log the action
            print(f"Clicking on page {page_number + 1}")

            # Click the next page button
            next_page_button.click()

            # Wait for the page number to update to the next page
            wait.until(EC.text_to_be_present_in_element(
                (By.XPATH, '//div[contains(@class, "DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))

            # Log the successful page navigation
            print(f"Successfully navigated to page {page_number + 1}")

            # Wait for a short duration to ensure the next page loads completely
            time.sleep(3)
        except Exception as e:
            print(f"An error occurred while navigating to page {page_number + 1}: {e}")
            break

# Print the scraped data
for entry in all_data:
    print(entry)
# Out:
# Clicking on page 2
# An error occurred while navigating to page 2: Message: element click intercepted: Element is not clickable at point (469, 2092)
#   (Session info: chrome=134.0.6998.89)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF608C3FE65+26629]
# 	(No symbol) [0x00007FF608BA6030]
# 	(No symbol) [0x00007FF608A3931A]
# 	(No symbol) [0x00007FF608A977A9]
# 	(No symbol) [0x00007FF608A95162]
# 	(No symbol) [0x00007FF608A92201]
# 	(No symbol) [0x00007FF608A91108]
# 	(No symbol) [0x00007FF608A828A4]
# 	(No symbol) [0x00007FF608AB7AAA]
# 	(No symbol) [0x00007FF608A82156]
# 	(No symbol) [0x00007FF608AB7CC0]
# 	(No symbol) [0x00007FF608AE0169]
# 	(No symbol) [0x00007FF608AB7883]
# 	(No symbol) [0x00007FF608A80550]
# 	(No symbol) [0x00007FF608A81803]
# 	GetHandleVerifier [0x00007FF608F972DD+3529853]
# 	GetHandleVerifier [0x00007FF608FADA42+3621858]
# 	GetHandleVerifier [0x00007FF608FA24F3+3575443]
# 	GetHandleVerifier [0x00007FF608D0B79A+860474]
# 	(No symbol) [0x00007FF608BB08AF]
# 	(No symbol) [0x00007FF608BACBE4]
# 	(No symbol) [0x00007FF608BACD86]
# 	(No symbol) [0x00007FF608B9C2E9]
# 	BaseThreadInitThunk [0x00007FF9505EE8D7+23]
# 	RtlUserThreadStart [0x00007FF9514DBF6C+44]
#
# {'route_link': 'https://www.redbus.in/bus-tickets/pune-to-goa', 'title': 'Pune to Goa'}
# {'route_link': 'https://www.redbus.in/bus-tickets/goa-to-pune', 'title': 'Goa to Pune'}
# {'route_link': 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'title': 'Mumbai to Goa'}
# {'route_link': 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'title': 'Bangalore to Goa'}
# {'route_link': 'https://www.redbus.in/bus-tickets/belagavi-to-goa', 'title': 'Belagavi to Goa'}
# {'route_link': 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'title': 'Goa to Bangalore'}
# {'route_link': 'https://www.redbus.in/bus-tickets/goa-to-mumbai', 'title': 'Goa to Mumbai'}
# {'route_link': 'https://www.redbus.in/bus-tickets/goa-to-belagavi', 'title': 'Goa to Belagavi'}
# {'route_link': 'https://www.redbus.in/bus-tickets/pandharpur-to-goa', 'title': 'Pandharpur to Goa'}
# {'route_link': 'https://www.redbus.in/bus-tickets/goa-to-pandharpur', 'title': 'Goa to Pandharpur'}

# %%
route_links=[(item['route_link'],item["title"]) for item in all_data]
route_links
# Out:
# [('https://www.redbus.in/bus-tickets/pune-to-goa', 'Pune to Goa'),
#  ('https://www.redbus.in/bus-tickets/goa-to-pune', 'Goa to Pune'),
#  ('https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Mumbai to Goa'),
#  ('https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Bangalore to Goa'),
#  ('https://www.redbus.in/bus-tickets/belagavi-to-goa', 'Belagavi to Goa'),
#  ('https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Goa to Bangalore'),
#  ('https://www.redbus.in/bus-tickets/goa-to-mumbai', 'Goa to Mumbai'),
#  ('https://www.redbus.in/bus-tickets/goa-to-belagavi', 'Goa to Belagavi'),
#  ('https://www.redbus.in/bus-tickets/pandharpur-to-goa', 'Pandharpur to Goa'),
#  ('https://www.redbus.in/bus-tickets/goa-to-pandharpur', 'Goa to Pandharpur')]

# %%
driver = webdriver.Chrome()
time.sleep(5)

def  scroll():
   x=0
   l=[]
   while True:
        x=x+1
        driver.execute_script('scrollBy(0,100)')
        #time.sleep(5)
        if(x>1000):
         break
bus_data=[]
for i,j in route_links:
    driver.get(i)

    scroll()




    bus_box= driver.find_elements(By.XPATH, '//div[@class="clearfix bus-item  "]')

    for bus in bus_box:
                        
                    reaching_time=bus.find_element(By.XPATH,'//div[@class="bp-time f-19 d-color disp-Inline"]').text
                    duration_time = bus.find_element(By.XPATH,'//div[@class="dur l-color lh-24"]').text

                    seats_available=bus.find_element(By.CLASS_NAME,'seat-left').text


                    bus_type = bus.find_element(By.XPATH, '//div[@class="bus-type f-12 m-top-16 l-color evBus"]').text


                    bus_names = bus.find_element(By.XPATH, '//div[@class="travels lh-24 f-bold d-color"]').text

                    route_times =bus.find_element(By.XPATH,'//div[@class="dp-time f-19 d-color f-bold"]').text

                    star_ratings = bus.find_element(By.XPATH, '//div[@class="rating-sec lh-24"]').text

                    ticket_rates =bus.find_element(By.XPATH, '//div[@class="seat-fare "]').text
                            
                    bus_data.append({'routename':j,'seat':seats_available,'bustypes':bus_type,'busnames':bus_names,'routetimes':route_times,'starratings':star_ratings,'tickets':ticket_rates,
                        "reaching":reaching_time," duration":duration_time,  })

# %%
bus_data
# Out:
# [{'routename': 'Pune to Goa',
#   'seat': '21 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '8 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '17 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '13 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '23 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '25 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '26 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '17 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '19 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '17 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '33 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '18 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '15 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '8 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '12 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '24 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '14 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '12 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '30 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '13 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '9 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '16 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '26 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '14 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '26 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '18 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '22 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '19 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '17 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '21 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '20 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '25 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '15 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '17 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '21 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '22 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '23 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '11 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '24 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '19 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '17 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '31 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '20 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '16 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '15 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '20 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '26 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '16 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '27 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '16 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '45 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Pune to Goa',
#   'seat': '18 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '21:00',
#   'starratings': '4.8',
#   'tickets': 'Starts from\nINR 950',
#   'reaching': '07:30',
#   ' duration': '10h 30m'},
#  {'routename': 'Goa to Pune',
#   'seat': '17 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '12 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '35 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '14 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '17 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '16 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '21 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '11 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '23 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '14 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '13 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '8 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '8 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '17 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '14 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '28 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '20 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '13 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '16 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '16 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '18 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '20 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '7 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '12 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '19 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '20 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '23 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '27 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '22 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '17 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '18 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '21 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '22 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '17 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '13 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '23 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '24 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '17 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '30 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '14 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '25 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '19 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '17 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '27 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '23 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '23 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '20 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '14 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '23 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '28 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '36 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '24 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '24 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '22 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '29 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '21 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '8 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '28 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '8 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '15 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '24 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '30 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '23 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Goa to Pune',
#   'seat': '24 Seats available',
#   'bustypes': 'VE A/C Sleeper (2+1)',
#   'busnames': 'Atmaram Gobus',
#   'routetimes': '22:30',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Mumbai to Goa',
#   'seat': '11 Seats available',
#   'bustypes': 'Volvo AC Seater Pushback 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 97386',
#   'routetimes': '17:05',
#   'starratings': '4.1',
#   'tickets': 'INR 1000',
#   'reaching': '06:00',
#   ' duration': '12h 55m'},
#  {'routename': 'Mumbai to Goa',
#   'seat': '12 Seats available',
#   'bustypes': 'Volvo AC Seater Pushback 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 97386',
#   'routetimes': '17:05',
#   'starratings': '4.1',
#   'tickets': 'INR 1000',
#   'reaching': '06:00',
#   ' duration': '12h 55m'},
#  {'routename': 'Mumbai to Goa',
#   'seat': '14 Seats available',
#   'bustypes': 'Volvo AC Seater Pushback 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 97386',
#   'routetimes': '17:05',
#   'starratings': '4.1',
#   'tickets': 'INR 1000',
#   'reaching': '06:00',
#   ' duration': '12h 55m'},
#  {'routename': 'Mumbai to Goa',
#   'seat': '8 Seats available',
#   'bustypes': 'Volvo AC Seater Pushback 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 97386',
#   'routetimes': '17:05',
#   'starratings': '4.1',
#   'tickets': 'INR 1000',
#   'reaching': '06:00',
#   ' duration': '12h 55m'},
#  {'routename': 'Mumbai to Goa',
#   'seat': '18 Seats available',
#   'bustypes': 'Volvo AC Seater Pushback 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 97386',
#   'routetimes': '17:05',
#   'starratings': '4.1',
#   'tickets': 'INR 1000',
#   'reaching': '06:00',
#   ' duration': '12h 55m'},
#  {'routename': 'Mumbai to Goa',
#   'seat': '',
#   'bustypes': 'Volvo AC Seater Pushback 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 97386',
#   'routetimes': '17:05',
#   'starratings': '4.1',
#   'tickets': 'INR 1000',
#   'reaching': '06:00',
#   ' duration': '12h 55m'},
#  {'routename': 'Mumbai to Goa',
#   'seat': '',
#   'bustypes': 'Volvo AC Seater Pushback 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 97386',
#   'routetimes': '17:05',
#   'starratings': '4.1',
#   'tickets': 'INR 1000',
#   'reaching': '06:00',
#   ' duration': '12h 55m'},
#  {'routename': 'Mumbai to Goa',
#   'seat': '',
#   'bustypes': 'Volvo AC Seater Pushback 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 97386',
#   'routetimes': '17:05',
#   'starratings': '4.1',
#   'tickets': 'INR 1000',
#   'reaching': '06:00',
#   ' duration': '12h 55m'},
#  {'routename': 'Mumbai to Goa',
#   'seat': '',
#   'bustypes': 'Volvo AC Seater Pushback 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 97386',
#   'routetimes': '17:05',
#   'starratings': '4.1',
#   'tickets': 'INR 1000',
#   'reaching': '06:00',
#   ' duration': '12h 55m'},
#  {'routename': 'Mumbai to Goa',
#   'seat': '',
#   'bustypes': 'Volvo AC Seater Pushback 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 97386',
#   'routetimes': '17:05',
#   'starratings': '4.1',
#   'tickets': 'INR 1000',
#   'reaching': '06:00',
#   ' duration': '12h 55m'},
#  {'routename': 'Bangalore to Goa',
#   'seat': '4 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180251',
#   'routetimes': '19:45',
#   'starratings': '3.1',
#   'tickets': 'Starts from\nINR 1400',
#   'reaching': '07:00',
#   ' duration': '11h 15m'},
#  {'routename': 'Bangalore to Goa',
#   'seat': '17 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180251',
#   'routetimes': '19:45',
#   'starratings': '3.1',
#   'tickets': 'Starts from\nINR 1400',
#   'reaching': '07:00',
#   ' duration': '11h 15m'},
#  {'routename': 'Bangalore to Goa',
#   'seat': '17 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180251',
#   'routetimes': '19:45',
#   'starratings': '3.1',
#   'tickets': 'Starts from\nINR 1400',
#   'reaching': '07:00',
#   ' duration': '11h 15m'},
#  {'routename': 'Bangalore to Goa',
#   'seat': '23 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180251',
#   'routetimes': '19:45',
#   'starratings': '3.1',
#   'tickets': 'Starts from\nINR 1400',
#   'reaching': '07:00',
#   ' duration': '11h 15m'},
#  {'routename': 'Bangalore to Goa',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180251',
#   'routetimes': '19:45',
#   'starratings': '3.1',
#   'tickets': 'Starts from\nINR 1400',
#   'reaching': '07:00',
#   ' duration': '11h 15m'},
#  {'routename': 'Bangalore to Goa',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180251',
#   'routetimes': '19:45',
#   'starratings': '3.1',
#   'tickets': 'Starts from\nINR 1400',
#   'reaching': '07:00',
#   ' duration': '11h 15m'},
#  {'routename': 'Bangalore to Goa',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180251',
#   'routetimes': '19:45',
#   'starratings': '3.1',
#   'tickets': 'Starts from\nINR 1400',
#   'reaching': '07:00',
#   ' duration': '11h 15m'},
#  {'routename': 'Bangalore to Goa',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180251',
#   'routetimes': '19:45',
#   'starratings': '3.1',
#   'tickets': 'Starts from\nINR 1400',
#   'reaching': '07:00',
#   ' duration': '11h 15m'},
#  {'routename': 'Bangalore to Goa',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180251',
#   'routetimes': '19:45',
#   'starratings': '3.1',
#   'tickets': 'Starts from\nINR 1400',
#   'reaching': '07:00',
#   ' duration': '11h 15m'},
#  {'routename': 'Bangalore to Goa',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180251',
#   'routetimes': '19:45',
#   'starratings': '3.1',
#   'tickets': 'Starts from\nINR 1400',
#   'reaching': '07:00',
#   ' duration': '11h 15m'},
#  {'routename': 'Belagavi to Goa',
#   'seat': '27 Seats available',
#   'bustypes': 'Non AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 179184',
#   'routetimes': '16:00',
#   'starratings': '3.7',
#   'tickets': 'INR 190',
#   'reaching': '20:05',
#   ' duration': '04h 05m'},
#  {'routename': 'Belagavi to Goa',
#   'seat': '7 Seats available',
#   'bustypes': 'Non AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 179184',
#   'routetimes': '16:00',
#   'starratings': '3.7',
#   'tickets': 'INR 190',
#   'reaching': '20:05',
#   ' duration': '04h 05m'},
#  {'routename': 'Belagavi to Goa',
#   'seat': '12 Seats available',
#   'bustypes': 'Non AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 179184',
#   'routetimes': '16:00',
#   'starratings': '3.7',
#   'tickets': 'INR 190',
#   'reaching': '20:05',
#   ' duration': '04h 05m'},
#  {'routename': 'Goa to Bangalore',
#   'seat': '18 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180243',
#   'routetimes': '18:30',
#   'starratings': '3.6',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:30',
#   ' duration': '13h 00m'},
#  {'routename': 'Goa to Bangalore',
#   'seat': '14 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180243',
#   'routetimes': '18:30',
#   'starratings': '3.6',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:30',
#   ' duration': '13h 00m'},
#  {'routename': 'Goa to Bangalore',
#   'seat': '17 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180243',
#   'routetimes': '18:30',
#   'starratings': '3.6',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:30',
#   ' duration': '13h 00m'},
#  {'routename': 'Goa to Bangalore',
#   'seat': '16 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180243',
#   'routetimes': '18:30',
#   'starratings': '3.6',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:30',
#   ' duration': '13h 00m'},
#  {'routename': 'Goa to Bangalore',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180243',
#   'routetimes': '18:30',
#   'starratings': '3.6',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:30',
#   ' duration': '13h 00m'},
#  {'routename': 'Goa to Bangalore',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180243',
#   'routetimes': '18:30',
#   'starratings': '3.6',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:30',
#   ' duration': '13h 00m'},
#  {'routename': 'Goa to Bangalore',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180243',
#   'routetimes': '18:30',
#   'starratings': '3.6',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:30',
#   ' duration': '13h 00m'},
#  {'routename': 'Goa to Bangalore',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180243',
#   'routetimes': '18:30',
#   'starratings': '3.6',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:30',
#   ' duration': '13h 00m'},
#  {'routename': 'Goa to Bangalore',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180243',
#   'routetimes': '18:30',
#   'starratings': '3.6',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:30',
#   ' duration': '13h 00m'},
#  {'routename': 'Goa to Bangalore',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 180243',
#   'routetimes': '18:30',
#   'starratings': '3.6',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '07:30',
#   ' duration': '13h 00m'},
#  {'routename': 'Goa to Mumbai',
#   'seat': '21 Seats available',
#   'bustypes': 'Volvo AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 116186',
#   'routetimes': '18:30',
#   'starratings': '4.2',
#   'tickets': 'INR 900',
#   'reaching': '08:00',
#   ' duration': '13h 30m'},
#  {'routename': 'Goa to Mumbai',
#   'seat': '12 Seats available',
#   'bustypes': 'Volvo AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 116186',
#   'routetimes': '18:30',
#   'starratings': '4.2',
#   'tickets': 'INR 900',
#   'reaching': '08:00',
#   ' duration': '13h 30m'},
#  {'routename': 'Goa to Mumbai',
#   'seat': '6 Seats available',
#   'bustypes': 'Volvo AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 116186',
#   'routetimes': '18:30',
#   'starratings': '4.2',
#   'tickets': 'INR 900',
#   'reaching': '08:00',
#   ' duration': '13h 30m'},
#  {'routename': 'Goa to Mumbai',
#   'seat': '21 Seats available',
#   'bustypes': 'Volvo AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 116186',
#   'routetimes': '18:30',
#   'starratings': '4.2',
#   'tickets': 'INR 900',
#   'reaching': '08:00',
#   ' duration': '13h 30m'},
#  {'routename': 'Goa to Mumbai',
#   'seat': '8 Seats available',
#   'bustypes': 'Volvo AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 116186',
#   'routetimes': '18:30',
#   'starratings': '4.2',
#   'tickets': 'INR 900',
#   'reaching': '08:00',
#   ' duration': '13h 30m'},
#  {'routename': 'Goa to Mumbai',
#   'seat': '',
#   'bustypes': 'Volvo AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 116186',
#   'routetimes': '18:30',
#   'starratings': '4.2',
#   'tickets': 'INR 900',
#   'reaching': '08:00',
#   ' duration': '13h 30m'},
#  {'routename': 'Goa to Mumbai',
#   'seat': '',
#   'bustypes': 'Volvo AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 116186',
#   'routetimes': '18:30',
#   'starratings': '4.2',
#   'tickets': 'INR 900',
#   'reaching': '08:00',
#   ' duration': '13h 30m'},
#  {'routename': 'Goa to Mumbai',
#   'seat': '',
#   'bustypes': 'Volvo AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 116186',
#   'routetimes': '18:30',
#   'starratings': '4.2',
#   'tickets': 'INR 900',
#   'reaching': '08:00',
#   ' duration': '13h 30m'},
#  {'routename': 'Goa to Mumbai',
#   'seat': '',
#   'bustypes': 'Volvo AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 116186',
#   'routetimes': '18:30',
#   'starratings': '4.2',
#   'tickets': 'INR 900',
#   'reaching': '08:00',
#   ' duration': '13h 30m'},
#  {'routename': 'Goa to Mumbai',
#   'seat': '',
#   'bustypes': 'Volvo AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 116186',
#   'routetimes': '18:30',
#   'starratings': '4.2',
#   'tickets': 'INR 900',
#   'reaching': '08:00',
#   ' duration': '13h 30m'},
#  {'routename': 'Goa to Belagavi',
#   'seat': '16 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'PVS Tours and Travels',
#   'routetimes': '16:00',
#   'starratings': '4.1',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '21:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Goa to Belagavi',
#   'seat': '34 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'PVS Tours and Travels',
#   'routetimes': '16:00',
#   'starratings': '4.1',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '21:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Goa to Belagavi',
#   'seat': '30 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'PVS Tours and Travels',
#   'routetimes': '16:00',
#   'starratings': '4.1',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '21:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Goa to Belagavi',
#   'seat': '29 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'PVS Tours and Travels',
#   'routetimes': '16:00',
#   'starratings': '4.1',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '21:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Goa to Belagavi',
#   'seat': '24 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'PVS Tours and Travels',
#   'routetimes': '16:00',
#   'starratings': '4.1',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '21:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Goa to Belagavi',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'PVS Tours and Travels',
#   'routetimes': '16:00',
#   'starratings': '4.1',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '21:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Goa to Belagavi',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'PVS Tours and Travels',
#   'routetimes': '16:00',
#   'starratings': '4.1',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '21:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Goa to Belagavi',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'PVS Tours and Travels',
#   'routetimes': '16:00',
#   'starratings': '4.1',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '21:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Goa to Belagavi',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'PVS Tours and Travels',
#   'routetimes': '16:00',
#   'starratings': '4.1',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '21:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Goa to Belagavi',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'PVS Tours and Travels',
#   'routetimes': '16:00',
#   'starratings': '4.1',
#   'tickets': 'Starts from\nINR 900',
#   'reaching': '21:00',
#   ' duration': '05h 00m'},
#  {'routename': 'Pandharpur to Goa',
#   'seat': '28 Seats available',
#   'bustypes': 'Non AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 61005',
#   'routetimes': '21:15',
#   'starratings': '3.7',
#   'tickets': 'INR 735',
#   'reaching': '10:00',
#   ' duration': '12h 45m'},
#  {'routename': 'Goa to Pandharpur',
#   'seat': '10 Seats available',
#   'bustypes': 'Non AC Seater 2+2',
#   'busnames': 'Kadamba Transport Corporation Limited (KTCL) - 60996',
#   'routetimes': '19:00',
#   'starratings': '3.7',
#   'tickets': 'INR 735',
#   'reaching': '07:00',
#   ' duration': '12h 00m'}]

# %%
df=pd.DataFrame(bus_data)

# %%
df["STATE"]='kadamba'

# %%
df
# Out:
#              routename                seat              bustypes  \
# 0          Pune to Goa  21 Seats available  VE A/C Sleeper (2+1)
# 1          Pune to Goa   8 Seats available  VE A/C Sleeper (2+1)
# 2          Pune to Goa  17 Seats available  VE A/C Sleeper (2+1)
# 3          Pune to Goa  13 Seats available  VE A/C Sleeper (2+1)
# 4          Pune to Goa  23 Seats available  VE A/C Sleeper (2+1)
# ..                 ...                 ...                   ...
# 166    Goa to Belagavi                         A/C Sleeper (2+1)
# 167    Goa to Belagavi                         A/C Sleeper (2+1)
# 168    Goa to Belagavi                         A/C Sleeper (2+1)
# 169  Pandharpur to Goa  28 Seats available     Non AC Seater 2+2
# 170  Goa to Pandharpur  10 Seats available     Non AC Seater 2+2
#
#                                               busnames routetimes starratings  \
# 0                                        Atmaram Gobus      21:00         4.8
# 1                                        Atmaram Gobus      21:00         4.8
# 2                                        Atmaram Gobus      21:00         4.8
# 3                                        Atmaram Gobus      21:00         4.8
# 4                                        Atmaram Gobus      21:00         4.8
# ..                                                 ...        ...         ...
# 166                              PVS Tours and Travels      16:00         4.1
# 167                              PVS Tours and Travels      16:00         4.1
# 168                              PVS Tours and Travels      16:00         4.1
# 169  Kadamba Transport Corporation Limited (KTCL) -...      21:15         3.7
# 170  Kadamba Transport Corporation Limited (KTCL) -...      19:00         3.7
#
#                   tickets reaching  duration    STATE
# 0    Starts from\nINR 950    07:30   10h 30m  kadamba
# 1    Starts from\nINR 950    07:30   10h 30m  kadamba
# 2    Starts from\nINR 950    07:30   10h 30m  kadamba
# 3    Starts from\nINR 950    07:30   10h 30m  kadamba
# 4    Starts from\nINR 950    07:30   10h 30m  kadamba
# ..                    ...      ...       ...      ...
# 166  Starts from\nINR 900    21:00   05h 00m  kadamba
# 167  Starts from\nINR 900    21:00   05h 00m  kadamba
# 168  Starts from\nINR 900    21:00   05h 00m  kadamba
# 169               INR 735    10:00   12h 45m  kadamba
# 170               INR 735    07:00   12h 00m  kadamba
#
# [171 rows x 10 columns]

# %%
df.to_csv("kadamba.csv",index=False)
