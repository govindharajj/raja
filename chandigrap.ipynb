# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time
import csv
import pandas as pd

# %%
#Full 5 pages- code


driver = webdriver.Chrome()

driver.get("https://www.redbus.in/online-booking/wbtc-ctc/?utm_source=rtchometile")

wait = WebDriverWait(driver, 20)

all_data = []

def scrape_page():
    # Locate elements
    routes = wait.until(EC.presence_of_all_elements_located((By.CLASS_NAME, "route_link")))

    # Loop through each route to extract details
    for route in routes:
        try:
            route_link = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("href")
            title = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("title")

            # Append extracted data to list
            all_data.append({
                "route_link": route_link,
                "title": title,
                
            })
        except Exception as e:
            print(f"An error occurred: {e}")
            continue
# Scrape data from the first 5 pages

for page_number in range(1, 6):
    scrape_page()
    if page_number < 5:  # Don't try to click next on the last page
        try:
            # Locate the pagination container
            pagination_container = wait.until(EC.presence_of_element_located(
                (By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')
            ))

            # Locate the next page button within the container
            next_page_button = pagination_container.find_element(
                By.XPATH, f'.//div[contains(@class, "DC_117_pageTabs") and text()="{page_number + 1}"]'
            )

            # Scroll the next page button into view
            driver.execute_script("arguments[0].scrollIntoView();", next_page_button)
            time.sleep(1)  # Wait for a bit after scrolling

            # Log the action
            print(f"Clicking on page {page_number + 1}")

            # Click the next page button
            next_page_button.click()

            # Wait for the page number to update to the next page
            wait.until(EC.text_to_be_present_in_element(
                (By.XPATH, '//div[contains(@class, "DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))

            # Log the successful page navigation
            print(f"Successfully navigated to page {page_number + 1}")

            # Wait for a short duration to ensure the next page loads completely
            time.sleep(3)
        except Exception as e:
            print(f"An error occurred while navigating to page {page_number + 1}: {e}")
            break

# Print the scraped data
for entry in all_data:
    print(entry)
# Out:
# Clicking on page 2
# An error occurred while navigating to page 2: Message: element click intercepted: Element is not clickable at point (489, 2092)
#   (Session info: chrome=134.0.6998.89)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF608C3FE65+26629]
# 	(No symbol) [0x00007FF608BA6030]
# 	(No symbol) [0x00007FF608A3931A]
# 	(No symbol) [0x00007FF608A977A9]
# 	(No symbol) [0x00007FF608A95162]
# 	(No symbol) [0x00007FF608A92201]
# 	(No symbol) [0x00007FF608A91108]
# 	(No symbol) [0x00007FF608A828A4]
# 	(No symbol) [0x00007FF608AB7AAA]
# 	(No symbol) [0x00007FF608A82156]
# 	(No symbol) [0x00007FF608AB7CC0]
# 	(No symbol) [0x00007FF608AE0169]
# 	(No symbol) [0x00007FF608AB7883]
# 	(No symbol) [0x00007FF608A80550]
# 	(No symbol) [0x00007FF608A81803]
# 	GetHandleVerifier [0x00007FF608F972DD+3529853]
# 	GetHandleVerifier [0x00007FF608FADA42+3621858]
# 	GetHandleVerifier [0x00007FF608FA24F3+3575443]
# 	GetHandleVerifier [0x00007FF608D0B79A+860474]
# 	(No symbol) [0x00007FF608BB08AF]
# 	(No symbol) [0x00007FF608BACBE4]
# 	(No symbol) [0x00007FF608BACD86]
# 	(No symbol) [0x00007FF608B9C2E9]
# 	BaseThreadInitThunk [0x00007FF9505EE8D7+23]
# 	RtlUserThreadStart [0x00007FF9514DBF6C+44]
#
# {'route_link': 'https://www.redbus.in/bus-tickets/kolkata-to-digha', 'title': 'Kolkata to Digha'}
# {'route_link': 'https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal', 'title': 'Digha to Barasat (West Bengal)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'title': 'Digha to Kolkata'}
# {'route_link': 'https://www.redbus.in/bus-tickets/kolkata-to-bolpur-west-bengal', 'title': 'Kolkata to Bolpur (West Bengal)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/midnapore-to-kolkata', 'title': 'Midnapore to Kolkata'}
# {'route_link': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-midnapore', 'title': 'Barasat (West Bengal) to Midnapore'}
# {'route_link': 'https://www.redbus.in/bus-tickets/durgapur-to-kolkata', 'title': 'Durgapur (West Bengal) to Kolkata'}
# {'route_link': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-digha', 'title': 'Barasat (West Bengal) to Digha'}
# {'route_link': 'https://www.redbus.in/bus-tickets/midnapore-to-barasat-west-bengal', 'title': 'Midnapore to Barasat (West Bengal)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/barasat-west-bengal-to-nandakumar', 'title': 'Barasat (West Bengal) to Nandakumar (west bengal)'}

# %%
route_links=[(item['route_link'],item["title"]) for item in all_data]
route_links
# Out:
# [('https://www.redbus.in/bus-tickets/kolkata-to-digha', 'Kolkata to Digha'),
#  ('https://www.redbus.in/bus-tickets/digha-to-barasat-west-bengal',
#   'Digha to Barasat (West Bengal)'),
#  ('https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Digha to Kolkata'),
#  ('https://www.redbus.in/bus-tickets/kolkata-to-bolpur-west-bengal',
#   'Kolkata to Bolpur (West Bengal)'),
#  ('https://www.redbus.in/bus-tickets/midnapore-to-kolkata',
#   'Midnapore to Kolkata'),
#  ('https://www.redbus.in/bus-tickets/barasat-west-bengal-to-midnapore',
#   'Barasat (West Bengal) to Midnapore'),
#  ('https://www.redbus.in/bus-tickets/durgapur-to-kolkata',
#   'Durgapur (West Bengal) to Kolkata'),
#  ('https://www.redbus.in/bus-tickets/barasat-west-bengal-to-digha',
#   'Barasat (West Bengal) to Digha'),
#  ('https://www.redbus.in/bus-tickets/midnapore-to-barasat-west-bengal',
#   'Midnapore to Barasat (West Bengal)'),
#  ('https://www.redbus.in/bus-tickets/barasat-west-bengal-to-nandakumar',
#   'Barasat (West Bengal) to Nandakumar (west bengal)')]

# %%
driver = webdriver.Chrome()
time.sleep(5)

def  scroll():
   x=0
   l=[]
   while True:
        x=x+1
        driver.execute_script('scrollBy(0,100)')
        #time.sleep(5)
        if(x>1000):
         break
bus_data=[]
for i,j in route_links:
    driver.get(i)

    scroll()




    bus_box= driver.find_elements(By.XPATH, '//div[@class="clearfix bus-item  "]')

    for bus in bus_box:
                        
                    reaching_time=bus.find_element(By.XPATH,'//div[@class="bp-time f-19 d-color disp-Inline"]').text
                    duration_time = bus.find_element(By.XPATH,'//div[@class="dur l-color lh-24"]').text

                    seats_available=bus.find_element(By.CLASS_NAME,'seat-left').text


                    bus_type = bus.find_element(By.XPATH, '//div[@class="bus-type f-12 m-top-16 l-color evBus"]').text


                    bus_names = bus.find_element(By.XPATH, '//div[@class="travels lh-24 f-bold d-color"]').text

                    route_times =bus.find_element(By.XPATH,'//div[@class="dp-time f-19 d-color f-bold"]').text
                    try:
                        star_ratings = bus.find_element(By.XPATH, '//div[@class="lh-18 rating rat-green "]').text
                    except:
                          star_ratings="na"
                    try:
                       ticket_rates =bus.find_element(By.XPATH, '//div[@class="seat-fare "]').text
                    except:
                         ticket_rates="na"
                            
                    bus_data.append({'routename':j,'seat':seats_available,'bustypes':bus_type,'busnames':bus_names,'routetimes':route_times,'starratings':star_ratings,'tickets':ticket_rates,
                        "reaching":reaching_time," duration":duration_time,  })

# %%
bus_data
# Out:
# [{'routename': 'Kolkata to Digha',
#   'seat': '18 Seats available',
#   'bustypes': 'VE A/C Seater (2+2)',
#   'busnames': 'Shyamoli Paribahan Pvt Ltd',
#   'routetimes': '23:30',
#   'starratings': '4.6',
#   'tickets': 'INR 500',
#   'reaching': '04:30',
#   ' duration': '05h 00m'},
#  {'routename': 'Kolkata to Digha',
#   'seat': '26 Seats available',
#   'bustypes': 'VE A/C Seater (2+2)',
#   'busnames': 'Shyamoli Paribahan Pvt Ltd',
#   'routetimes': '23:30',
#   'starratings': '4.6',
#   'tickets': 'INR 500',
#   'reaching': '04:30',
#   ' duration': '05h 00m'},
#  {'routename': 'Kolkata to Digha',
#   'seat': '',
#   'bustypes': 'VE A/C Seater (2+2)',
#   'busnames': 'Shyamoli Paribahan Pvt Ltd',
#   'routetimes': '23:30',
#   'starratings': '4.6',
#   'tickets': 'INR 500',
#   'reaching': '04:30',
#   ' duration': '05h 00m'},
#  {'routename': 'Kolkata to Digha',
#   'seat': '',
#   'bustypes': 'VE A/C Seater (2+2)',
#   'busnames': 'Shyamoli Paribahan Pvt Ltd',
#   'routetimes': '23:30',
#   'starratings': '4.6',
#   'tickets': 'INR 500',
#   'reaching': '04:30',
#   ' duration': '05h 00m'},
#  {'routename': 'Kolkata to Digha',
#   'seat': '',
#   'bustypes': 'VE A/C Seater (2+2)',
#   'busnames': 'Shyamoli Paribahan Pvt Ltd',
#   'routetimes': '23:30',
#   'starratings': '4.6',
#   'tickets': 'INR 500',
#   'reaching': '04:30',
#   ' duration': '05h 00m'},
#  {'routename': 'Digha to Barasat (West Bengal)',
#   'seat': '44 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516',
#   'routetimes': '14:20',
#   'starratings': '3.3',
#   'tickets': 'INR 170',
#   'reaching': '19:20',
#   ' duration': '05h 00m'},
#  {'routename': 'Digha to Barasat (West Bengal)',
#   'seat': '9 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516',
#   'routetimes': '14:20',
#   'starratings': '3.3',
#   'tickets': 'INR 170',
#   'reaching': '19:20',
#   ' duration': '05h 00m'},
#  {'routename': 'Digha to Barasat (West Bengal)',
#   'seat': '12 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516',
#   'routetimes': '14:20',
#   'starratings': '3.3',
#   'tickets': 'INR 170',
#   'reaching': '19:20',
#   ' duration': '05h 00m'},
#  {'routename': 'Digha to Barasat (West Bengal)',
#   'seat': '25 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516',
#   'routetimes': '14:20',
#   'starratings': '3.3',
#   'tickets': 'INR 170',
#   'reaching': '19:20',
#   ' duration': '05h 00m'},
#  {'routename': 'Digha to Barasat (West Bengal)',
#   'seat': '21 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516',
#   'routetimes': '14:20',
#   'starratings': '3.3',
#   'tickets': 'INR 170',
#   'reaching': '19:20',
#   ' duration': '05h 00m'},
#  {'routename': 'Digha to Barasat (West Bengal)',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516',
#   'routetimes': '14:20',
#   'starratings': '3.3',
#   'tickets': 'INR 170',
#   'reaching': '19:20',
#   ' duration': '05h 00m'},
#  {'routename': 'Digha to Barasat (West Bengal)',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516',
#   'routetimes': '14:20',
#   'starratings': '3.3',
#   'tickets': 'INR 170',
#   'reaching': '19:20',
#   ' duration': '05h 00m'},
#  {'routename': 'Digha to Barasat (West Bengal)',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516',
#   'routetimes': '14:20',
#   'starratings': '3.3',
#   'tickets': 'INR 170',
#   'reaching': '19:20',
#   ' duration': '05h 00m'},
#  {'routename': 'Digha to Barasat (West Bengal)',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516',
#   'routetimes': '14:20',
#   'starratings': '3.3',
#   'tickets': 'INR 170',
#   'reaching': '19:20',
#   ' duration': '05h 00m'},
#  {'routename': 'Digha to Barasat (West Bengal)',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516',
#   'routetimes': '14:20',
#   'starratings': '3.3',
#   'tickets': 'INR 170',
#   'reaching': '19:20',
#   ' duration': '05h 00m'},
#  {'routename': 'Digha to Kolkata',
#   'seat': '15 Seats available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '13:40',
#   'starratings': '4.4',
#   'tickets': 'INR 300',
#   'reaching': '18:25',
#   ' duration': '04h 45m'},
#  {'routename': 'Digha to Kolkata',
#   'seat': '11 Seats available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '13:40',
#   'starratings': '4.4',
#   'tickets': 'INR 300',
#   'reaching': '18:25',
#   ' duration': '04h 45m'},
#  {'routename': 'Digha to Kolkata',
#   'seat': '12 Seats available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '13:40',
#   'starratings': '4.4',
#   'tickets': 'INR 300',
#   'reaching': '18:25',
#   ' duration': '04h 45m'},
#  {'routename': 'Digha to Kolkata',
#   'seat': '',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '13:40',
#   'starratings': '4.4',
#   'tickets': 'INR 300',
#   'reaching': '18:25',
#   ' duration': '04h 45m'},
#  {'routename': 'Digha to Kolkata',
#   'seat': '',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Greenline',
#   'routetimes': '13:40',
#   'starratings': '4.4',
#   'tickets': 'INR 300',
#   'reaching': '18:25',
#   ' duration': '04h 45m'},
#  {'routename': 'Kolkata to Bolpur (West Bengal)',
#   'seat': '26 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'WBTC (CTC) KOLKATA -BOLPUR - SURI (AC-VOLVO) - 104|14:30',
#   'routetimes': '14:30',
#   'starratings': '4.2',
#   'tickets': 'INR 375',
#   'reaching': '18:15',
#   ' duration': '03h 45m'},
#  {'routename': 'Durgapur (West Bengal) to Kolkata',
#   'seat': '25 Seats available',
#   'bustypes': 'Volvo B11R Multi Axle Seater (2+2)',
#   'busnames': 'SHYAMOLI Pvt. Ltd.(Karunamoyee)',
#   'routetimes': '11:00',
#   'starratings': '4.1',
#   'tickets': 'INR 486',
#   'reaching': '15:00',
#   ' duration': '04h 00m'},
#  {'routename': 'Durgapur (West Bengal) to Kolkata',
#   'seat': '14 Seats available',
#   'bustypes': 'Volvo B11R Multi Axle Seater (2+2)',
#   'busnames': 'SHYAMOLI Pvt. Ltd.(Karunamoyee)',
#   'routetimes': '11:00',
#   'starratings': '4.1',
#   'tickets': 'INR 486',
#   'reaching': '15:00',
#   ' duration': '04h 00m'},
#  {'routename': 'Durgapur (West Bengal) to Kolkata',
#   'seat': '15 Seats available',
#   'bustypes': 'Volvo B11R Multi Axle Seater (2+2)',
#   'busnames': 'SHYAMOLI Pvt. Ltd.(Karunamoyee)',
#   'routetimes': '11:00',
#   'starratings': '4.1',
#   'tickets': 'INR 486',
#   'reaching': '15:00',
#   ' duration': '04h 00m'},
#  {'routename': 'Durgapur (West Bengal) to Kolkata',
#   'seat': '',
#   'bustypes': 'Volvo B11R Multi Axle Seater (2+2)',
#   'busnames': 'SHYAMOLI Pvt. Ltd.(Karunamoyee)',
#   'routetimes': '11:00',
#   'starratings': '4.1',
#   'tickets': 'INR 486',
#   'reaching': '15:00',
#   ' duration': '04h 00m'},
#  {'routename': 'Durgapur (West Bengal) to Kolkata',
#   'seat': '',
#   'bustypes': 'Volvo B11R Multi Axle Seater (2+2)',
#   'busnames': 'SHYAMOLI Pvt. Ltd.(Karunamoyee)',
#   'routetimes': '11:00',
#   'starratings': '4.1',
#   'tickets': 'INR 486',
#   'reaching': '15:00',
#   ' duration': '04h 00m'},
#  {'routename': 'Barasat (West Bengal) to Digha',
#   'seat': '29 Seats available',
#   'bustypes': 'Benz A/C Seater (2+2)',
#   'busnames': 'Lokenath Bus Service',
#   'routetimes': '22:00',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 549 467',
#   'reaching': '05:00',
#   ' duration': '07h 00m'},
#  {'routename': 'Barasat (West Bengal) to Digha',
#   'seat': '47 Seats available',
#   'bustypes': 'Benz A/C Seater (2+2)',
#   'busnames': 'Lokenath Bus Service',
#   'routetimes': '22:00',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 549 467',
#   'reaching': '05:00',
#   ' duration': '07h 00m'},
#  {'routename': 'Barasat (West Bengal) to Digha',
#   'seat': '30 Seats available',
#   'bustypes': 'Benz A/C Seater (2+2)',
#   'busnames': 'Lokenath Bus Service',
#   'routetimes': '22:00',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 549 467',
#   'reaching': '05:00',
#   ' duration': '07h 00m'},
#  {'routename': 'Barasat (West Bengal) to Digha',
#   'seat': '41 Seats available',
#   'bustypes': 'Benz A/C Seater (2+2)',
#   'busnames': 'Lokenath Bus Service',
#   'routetimes': '22:00',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 549 467',
#   'reaching': '05:00',
#   ' duration': '07h 00m'},
#  {'routename': 'Barasat (West Bengal) to Nandakumar (west bengal)',
#   'seat': '54 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'WBTC (CTC) HABRA-DIGHA via Bally - 26|14:00',
#   'routetimes': '14:00',
#   'starratings': '4.6',
#   'tickets': 'INR 90',
#   'reaching': '16:10',
#   ' duration': '02h 10m'},
#  {'routename': 'Barasat (West Bengal) to Nandakumar (west bengal)',
#   'seat': '36 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'WBTC (CTC) HABRA-DIGHA via Bally - 26|14:00',
#   'routetimes': '14:00',
#   'starratings': '4.6',
#   'tickets': 'INR 90',
#   'reaching': '16:10',
#   ' duration': '02h 10m'},
#  {'routename': 'Barasat (West Bengal) to Nandakumar (west bengal)',
#   'seat': '11 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'WBTC (CTC) HABRA-DIGHA via Bally - 26|14:00',
#   'routetimes': '14:00',
#   'starratings': '4.6',
#   'tickets': 'INR 90',
#   'reaching': '16:10',
#   ' duration': '02h 10m'}]

# %%
df=pd.DataFrame(bus_data)

# %%
df["STATE"]="chandigarh"

# %%
df
# Out:
#                                             routename                seat  \
# 0                                    Kolkata to Digha  18 Seats available
# 1                                    Kolkata to Digha  26 Seats available
# 2                                    Kolkata to Digha
# 3                                    Kolkata to Digha
# 4                                    Kolkata to Digha
# 5                      Digha to Barasat (West Bengal)  44 Seats available
# 6                      Digha to Barasat (West Bengal)   9 Seats available
# 7                      Digha to Barasat (West Bengal)  12 Seats available
# 8                      Digha to Barasat (West Bengal)  25 Seats available
# 9                      Digha to Barasat (West Bengal)  21 Seats available
# 10                     Digha to Barasat (West Bengal)
# 11                     Digha to Barasat (West Bengal)
# 12                     Digha to Barasat (West Bengal)
# 13                     Digha to Barasat (West Bengal)
# 14                     Digha to Barasat (West Bengal)
# 15                                   Digha to Kolkata  15 Seats available
# 16                                   Digha to Kolkata  11 Seats available
# 17                                   Digha to Kolkata  12 Seats available
# 18                                   Digha to Kolkata
# 19                                   Digha to Kolkata
# 20                    Kolkata to Bolpur (West Bengal)  26 Seats available
# 21                  Durgapur (West Bengal) to Kolkata  25 Seats available
# 22                  Durgapur (West Bengal) to Kolkata  14 Seats available
# 23                  Durgapur (West Bengal) to Kolkata  15 Seats available
# 24                  Durgapur (West Bengal) to Kolkata
# 25                  Durgapur (West Bengal) to Kolkata
# 26                     Barasat (West Bengal) to Digha  29 Seats available
# 27                     Barasat (West Bengal) to Digha  47 Seats available
# 28                     Barasat (West Bengal) to Digha  30 Seats available
# 29                     Barasat (West Bengal) to Digha  41 Seats available
# 30  Barasat (West Bengal) to Nandakumar (west bengal)  54 Seats available
# 31  Barasat (West Bengal) to Nandakumar (west bengal)  36 Seats available
# 32  Barasat (West Bengal) to Nandakumar (west bengal)  11 Seats available
#
#                               bustypes  \
# 0                  VE A/C Seater (2+2)
# 1                  VE A/C Seater (2+2)
# 2                  VE A/C Seater (2+2)
# 3                  VE A/C Seater (2+2)
# 4                  VE A/C Seater (2+2)
# 5                  Non AC Seater (2+3)
# 6                  Non AC Seater (2+3)
# 7                  Non AC Seater (2+3)
# 8                  Non AC Seater (2+3)
# 9                  Non AC Seater (2+3)
# 10                 Non AC Seater (2+3)
# 11                 Non AC Seater (2+3)
# 12                 Non AC Seater (2+3)
# 13                 Non AC Seater (2+3)
# 14                 Non AC Seater (2+3)
# 15              Volvo A/C Seater (2+2)
# 16              Volvo A/C Seater (2+2)
# 17              Volvo A/C Seater (2+2)
# 18              Volvo A/C Seater (2+2)
# 19              Volvo A/C Seater (2+2)
# 20                    A/C Seater (2+2)
# 21  Volvo B11R Multi Axle Seater (2+2)
# 22  Volvo B11R Multi Axle Seater (2+2)
# 23  Volvo B11R Multi Axle Seater (2+2)
# 24  Volvo B11R Multi Axle Seater (2+2)
# 25  Volvo B11R Multi Axle Seater (2+2)
# 26               Benz A/C Seater (2+2)
# 27               Benz A/C Seater (2+2)
# 28               Benz A/C Seater (2+2)
# 29               Benz A/C Seater (2+2)
# 30                 Non AC Seater (2+3)
# 31                 Non AC Seater (2+3)
# 32                 Non AC Seater (2+3)
#
#                                              busnames routetimes starratings  \
# 0                          Shyamoli Paribahan Pvt Ltd      23:30         4.6
# 1                          Shyamoli Paribahan Pvt Ltd      23:30         4.6
# 2                          Shyamoli Paribahan Pvt Ltd      23:30         4.6
# 3                          Shyamoli Paribahan Pvt Ltd      23:30         4.6
# 4                          Shyamoli Paribahan Pvt Ltd      23:30         4.6
# 5   SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516      14:20         3.3
# 6   SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516      14:20         3.3
# 7   SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516      14:20         3.3
# 8   SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516      14:20         3.3
# 9   SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516      14:20         3.3
# 10  SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516      14:20         3.3
# 11  SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516      14:20         3.3
# 12  SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516      14:20         3.3
# 13  SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516      14:20         3.3
# 14  SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516      14:20         3.3
# 15                                          Greenline      13:40         4.4
# 16                                          Greenline      13:40         4.4
# 17                                          Greenline      13:40         4.4
# 18                                          Greenline      13:40         4.4
# 19                                          Greenline      13:40         4.4
# 20  WBTC (CTC) KOLKATA -BOLPUR - SURI (AC-VOLVO) -...      14:30         4.2
# 21                    SHYAMOLI Pvt. Ltd.(Karunamoyee)      11:00         4.1
# 22                    SHYAMOLI Pvt. Ltd.(Karunamoyee)      11:00         4.1
# 23                    SHYAMOLI Pvt. Ltd.(Karunamoyee)      11:00         4.1
# 24                    SHYAMOLI Pvt. Ltd.(Karunamoyee)      11:00         4.1
# 25                    SHYAMOLI Pvt. Ltd.(Karunamoyee)      11:00         4.1
# 26                               Lokenath Bus Service      22:00         4.3
# 27                               Lokenath Bus Service      22:00         4.3
# 28                               Lokenath Bus Service      22:00         4.3
# 29                               Lokenath Bus Service      22:00         4.3
# 30        WBTC (CTC) HABRA-DIGHA via Bally - 26|14:00      14:00         4.6
# 31        WBTC (CTC) HABRA-DIGHA via Bally - 26|14:00      14:00         4.6
# 32        WBTC (CTC) HABRA-DIGHA via Bally - 26|14:00      14:00         4.6
#
#                      tickets reaching  duration       STATE
# 0                    INR 500    04:30   05h 00m  chandigarh
# 1                    INR 500    04:30   05h 00m  chandigarh
# 2                    INR 500    04:30   05h 00m  chandigarh
# 3                    INR 500    04:30   05h 00m  chandigarh
# 4                    INR 500    04:30   05h 00m  chandigarh
# 5                    INR 170    19:20   05h 00m  chandigarh
# 6                    INR 170    19:20   05h 00m  chandigarh
# 7                    INR 170    19:20   05h 00m  chandigarh
# 8                    INR 170    19:20   05h 00m  chandigarh
# 9                    INR 170    19:20   05h 00m  chandigarh
# 10                   INR 170    19:20   05h 00m  chandigarh
# 11                   INR 170    19:20   05h 00m  chandigarh
# 12                   INR 170    19:20   05h 00m  chandigarh
# 13                   INR 170    19:20   05h 00m  chandigarh
# 14                   INR 170    19:20   05h 00m  chandigarh
# 15                   INR 300    18:25   04h 45m  chandigarh
# 16                   INR 300    18:25   04h 45m  chandigarh
# 17                   INR 300    18:25   04h 45m  chandigarh
# 18                   INR 300    18:25   04h 45m  chandigarh
# 19                   INR 300    18:25   04h 45m  chandigarh
# 20                   INR 375    18:15   03h 45m  chandigarh
# 21                   INR 486    15:00   04h 00m  chandigarh
# 22                   INR 486    15:00   04h 00m  chandigarh
# 23                   INR 486    15:00   04h 00m  chandigarh
# 24                   INR 486    15:00   04h 00m  chandigarh
# 25                   INR 486    15:00   04h 00m  chandigarh
# 26  Starts from\nINR 549 467    05:00   07h 00m  chandigarh
# 27  Starts from\nINR 549 467    05:00   07h 00m  chandigarh
# 28  Starts from\nINR 549 467    05:00   07h 00m  chandigarh
# 29  Starts from\nINR 549 467    05:00   07h 00m  chandigarh
# 30                    INR 90    16:10   02h 10m  chandigarh
# 31                    INR 90    16:10   02h 10m  chandigarh
# 32                    INR 90    16:10   02h 10m  chandigarh

# %%
df.to_csv("chandigarh.csv",index=False)
