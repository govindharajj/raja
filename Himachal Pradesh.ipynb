# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time
import csv
import pandas as pd

# %%
#Full 5 pages- code


driver = webdriver.Chrome()

driver.get("https://www.redbus.in/online-booking/hrtc/?utm_source=rtchometile")

wait = WebDriverWait(driver, 20)

all_data = []

def scrape_page():
    # Locate elements
    routes = wait.until(EC.presence_of_all_elements_located((By.CLASS_NAME, "route_link")))

    # Loop through each route to extract details
    for route in routes:
        try:
            route_link = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("href")
            title = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("title")

            # Append extracted data to list
            all_data.append({
                "route_link": route_link,
                "title": title,
                
            })
        except Exception as e:
            print(f"An error occurred: {e}")
            continue
# Scrape data from the first 5 pages

for page_number in range(1, 6):
    scrape_page()
    if page_number < 5:  # Don't try to click next on the last page
        try:
            # Locate the pagination container
            pagination_container = wait.until(EC.presence_of_element_located(
                (By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')
            ))

            # Locate the next page button within the container
            next_page_button = pagination_container.find_element(
                By.XPATH, f'.//div[contains(@class, "DC_117_pageTabs") and text()="{page_number + 1}"]'
            )

            # Scroll the next page button into view
            driver.execute_script("arguments[0].scrollIntoView();", next_page_button)
            time.sleep(1)  # Wait for a bit after scrolling

            # Log the action
            print(f"Clicking on page {page_number + 1}")

            # Click the next page button
            next_page_button.click()

            # Wait for the page number to update to the next page
            wait.until(EC.text_to_be_present_in_element(
                (By.XPATH, '//div[contains(@class, "DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))

            # Log the successful page navigation
            print(f"Successfully navigated to page {page_number + 1}")

            # Wait for a short duration to ensure the next page loads completely
            time.sleep(3)
        except Exception as e:
            print(f"An error occurred while navigating to page {page_number + 1}: {e}")
            break

# Print the scraped data
for entry in all_data:
    print(entry)
# Out:
# Clicking on page 2
# An error occurred while navigating to page 2: Message: element click intercepted: Element is not clickable at point (489, 2092)
#   (Session info: chrome=134.0.6998.178)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF72D684C25+3179557]
# 	(No symbol) [0x00007FF72D2E88A0]
# 	(No symbol) [0x00007FF72D1791CA]
# 	(No symbol) [0x00007FF72D1D7929]
# 	(No symbol) [0x00007FF72D1D52E2]
# 	(No symbol) [0x00007FF72D1D2381]
# 	(No symbol) [0x00007FF72D1D1281]
# 	(No symbol) [0x00007FF72D1C2A24]
# 	(No symbol) [0x00007FF72D1F7C2A]
# 	(No symbol) [0x00007FF72D1C22D6]
# 	(No symbol) [0x00007FF72D1F7E40]
# 	(No symbol) [0x00007FF72D2202F3]
# 	(No symbol) [0x00007FF72D1F7A03]
# 	(No symbol) [0x00007FF72D1C06D0]
# 	(No symbol) [0x00007FF72D1C1983]
# 	GetHandleVerifier [0x00007FF72D6E67CD+3579853]
# 	GetHandleVerifier [0x00007FF72D6FD1D2+3672530]
# 	GetHandleVerifier [0x00007FF72D6F2153+3627347]
# 	GetHandleVerifier [0x00007FF72D45092A+868650]
# 	(No symbol) [0x00007FF72D2F2FFF]
# 	(No symbol) [0x00007FF72D2EF4A4]
# 	(No symbol) [0x00007FF72D2EF646]
# 	(No symbol) [0x00007FF72D2DEAA9]
# 	BaseThreadInitThunk [0x00007FF842C7E8D7+23]
# 	RtlUserThreadStart [0x00007FF84367BF6C+44]
#
# {'route_link': 'https://www.redbus.in/bus-tickets/delhi-to-shimla', 'title': 'Delhi to Shimla'}
# {'route_link': 'https://www.redbus.in/bus-tickets/shimla-to-delhi', 'title': 'Shimla to Delhi'}
# {'route_link': 'https://www.redbus.in/bus-tickets/chandigarh-to-hamirpur-himachal-pradesh', 'title': 'Chandigarh to Hamirpur (Himachal Pradesh)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/hamirpur-himachal-pradesh-to-chandigarh', 'title': 'Hamirpur (Himachal Pradesh) to Chandigarh'}
# {'route_link': 'https://www.redbus.in/bus-tickets/delhi-to-chandigarh', 'title': 'Delhi to Chandigarh'}
# {'route_link': 'https://www.redbus.in/bus-tickets/manali-to-chandigarh', 'title': 'Manali to Chandigarh'}
# {'route_link': 'https://www.redbus.in/bus-tickets/shimla-to-chandigarh', 'title': 'Shimla to Chandigarh'}
# {'route_link': 'https://www.redbus.in/bus-tickets/chandigarh-to-manali', 'title': 'Chandigarh to Manali'}
# {'route_link': 'https://www.redbus.in/bus-tickets/shimla-to-manali', 'title': 'Shimla to Manali'}
# {'route_link': 'https://www.redbus.in/bus-tickets/dharamshala-to-chandigarh', 'title': 'Dharamshala (Himachal Pradesh) to Chandigarh'}

# %%
route_links=[(item['route_link'],item["title"]) for item in all_data]
route_links
# Out:
# [('https://www.redbus.in/bus-tickets/delhi-to-shimla', 'Delhi to Shimla'),
#  ('https://www.redbus.in/bus-tickets/shimla-to-delhi', 'Shimla to Delhi'),
#  ('https://www.redbus.in/bus-tickets/chandigarh-to-hamirpur-himachal-pradesh',
#   'Chandigarh to Hamirpur (Himachal Pradesh)'),
#  ('https://www.redbus.in/bus-tickets/hamirpur-himachal-pradesh-to-chandigarh',
#   'Hamirpur (Himachal Pradesh) to Chandigarh'),
#  ('https://www.redbus.in/bus-tickets/delhi-to-chandigarh',
#   'Delhi to Chandigarh'),
#  ('https://www.redbus.in/bus-tickets/manali-to-chandigarh',
#   'Manali to Chandigarh'),
#  ('https://www.redbus.in/bus-tickets/shimla-to-chandigarh',
#   'Shimla to Chandigarh'),
#  ('https://www.redbus.in/bus-tickets/chandigarh-to-manali',
#   'Chandigarh to Manali'),
#  ('https://www.redbus.in/bus-tickets/shimla-to-manali', 'Shimla to Manali'),
#  ('https://www.redbus.in/bus-tickets/dharamshala-to-chandigarh',
#   'Dharamshala (Himachal Pradesh) to Chandigarh')]

# %%
driver = webdriver.Chrome()
time.sleep(5)

def  scroll():
   x=0
   l=[]
   while True:
        x=x+1
        driver.execute_script('scrollBy(0,100)')
        #time.sleep(5)
        if(x>1000):
         break
bus_data=[]
for i,j in route_links:
    driver.get(i)

    scroll()




    bus_box= driver.find_elements(By.XPATH, '//div[@class="clearfix bus-item  "]')

    for bus in bus_box:
                        
                    reaching_time=bus.find_element(By.XPATH,'//div[@class="bp-time f-19 d-color disp-Inline"]').text
                    duration_time = bus.find_element(By.XPATH,'//div[@class="dur l-color lh-24"]').text

                    seats_available=bus.find_element(By.CLASS_NAME,'seat-left').text


                    bus_type = bus.find_element(By.XPATH, '//div[@class="bus-type f-12 m-top-16 l-color evBus"]').text


                    bus_names = bus.find_element(By.XPATH, '//div[@class="travels lh-24 f-bold d-color"]').text

                    route_times =bus.find_element(By.XPATH,'//div[@class="dp-time f-19 d-color f-bold"]').text
                    try:
                        star_ratings = bus.find_element(By.XPATH, '//div[@class="lh-18 rating rat-green "]').text
                    except:
                          star_ratings="na"
                    try:
                       ticket_rates =bus.find_element(By.XPATH, '//div[@class="seat-fare "]').text
                    except:
                         ticket_rates="na"
                            
                    bus_data.append({'routemname':j,'seat':seats_available,'bustypes':bus_type,'busnames':bus_names,'routetimes':route_times,'starratings':star_ratings,'tickets':ticket_rates,
                        "reaching":reaching_time," duration":duration_time,  })

# %%
bus_data
# Out:
# [{'routemname': 'Delhi to Shimla',
#   'seat': '26 Seats available',
#   'bustypes': 'Volvo A/C Semi Sleeper (2+2)',
#   'busnames': 'Bedi Travels',
#   'routetimes': '23:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 1159 1043',
#   'reaching': '08:00',
#   ' duration': '09h 00m'},
#  {'routemname': 'Delhi to Shimla',
#   'seat': '32 Seats available',
#   'bustypes': 'Volvo A/C Semi Sleeper (2+2)',
#   'busnames': 'Bedi Travels',
#   'routetimes': '23:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 1159 1043',
#   'reaching': '08:00',
#   ' duration': '09h 00m'},
#  {'routemname': 'Delhi to Shimla',
#   'seat': '29 Seats available',
#   'bustypes': 'Volvo A/C Semi Sleeper (2+2)',
#   'busnames': 'Bedi Travels',
#   'routetimes': '23:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 1159 1043',
#   'reaching': '08:00',
#   ' duration': '09h 00m'},
#  {'routemname': 'Delhi to Shimla',
#   'seat': '',
#   'bustypes': 'Volvo A/C Semi Sleeper (2+2)',
#   'busnames': 'Bedi Travels',
#   'routetimes': '23:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 1159 1043',
#   'reaching': '08:00',
#   ' duration': '09h 00m'},
#  {'routemname': 'Delhi to Shimla',
#   'seat': '',
#   'bustypes': 'Volvo A/C Semi Sleeper (2+2)',
#   'busnames': 'Bedi Travels',
#   'routetimes': '23:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 1159 1043',
#   'reaching': '08:00',
#   ' duration': '09h 00m'},
#  {'routemname': 'Shimla to Delhi',
#   'seat': '32 Seats available',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.8',
#   'tickets': 'INR 1117',
#   'reaching': '02:30',
#   ' duration': '10h 00m'},
#  {'routemname': 'Shimla to Delhi',
#   'seat': '16 Seats available',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.8',
#   'tickets': 'INR 1117',
#   'reaching': '02:30',
#   ' duration': '10h 00m'},
#  {'routemname': 'Shimla to Delhi',
#   'seat': '13 Seats available',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.8',
#   'tickets': 'INR 1117',
#   'reaching': '02:30',
#   ' duration': '10h 00m'},
#  {'routemname': 'Shimla to Delhi',
#   'seat': '',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.8',
#   'tickets': 'INR 1117',
#   'reaching': '02:30',
#   ' duration': '10h 00m'},
#  {'routemname': 'Shimla to Delhi',
#   'seat': '',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.8',
#   'tickets': 'INR 1117',
#   'reaching': '02:30',
#   ' duration': '10h 00m'},
#  {'routemname': 'Shimla to Delhi',
#   'seat': '',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.8',
#   'tickets': 'INR 1117',
#   'reaching': '02:30',
#   ' duration': '10h 00m'},
#  {'routemname': 'Shimla to Delhi',
#   'seat': '',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.8',
#   'tickets': 'INR 1117',
#   'reaching': '02:30',
#   ' duration': '10h 00m'},
#  {'routemname': 'Shimla to Delhi',
#   'seat': '',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.8',
#   'tickets': 'INR 1117',
#   'reaching': '02:30',
#   ' duration': '10h 00m'},
#  {'routemname': 'Shimla to Delhi',
#   'seat': '',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.8',
#   'tickets': 'INR 1117',
#   'reaching': '02:30',
#   ' duration': '10h 00m'},
#  {'routemname': 'Shimla to Delhi',
#   'seat': '',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.8',
#   'tickets': 'INR 1117',
#   'reaching': '02:30',
#   ' duration': '10h 00m'},
#  {'routemname': 'Chandigarh to Hamirpur (Himachal Pradesh)',
#   'seat': '37 Seats available',
#   'bustypes': 'HVAC Seater (2+3)',
#   'busnames': 'Chandigarh Transport Undertaking (CTU) - 165843',
#   'routetimes': '08:50',
#   'starratings': '4.1',
#   'tickets': 'INR 383.85',
#   'reaching': '13:20',
#   ' duration': '04h 30m'},
#  {'routemname': 'Hamirpur (Himachal Pradesh) to Chandigarh',
#   'seat': '16 Seats available',
#   'bustypes': 'Volvo A/C Semi Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '20:20',
#   'starratings': '4.5',
#   'tickets': 'Starts from\nINR 548',
#   'reaching': '00:30',
#   ' duration': '04h 10m'},
#  {'routemname': 'Hamirpur (Himachal Pradesh) to Chandigarh',
#   'seat': '30 Seats available',
#   'bustypes': 'Volvo A/C Semi Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '20:20',
#   'starratings': '4.5',
#   'tickets': 'Starts from\nINR 548',
#   'reaching': '00:30',
#   ' duration': '04h 10m'},
#  {'routemname': 'Hamirpur (Himachal Pradesh) to Chandigarh',
#   'seat': '11 Seats available',
#   'bustypes': 'Volvo A/C Semi Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '20:20',
#   'starratings': '4.5',
#   'tickets': 'Starts from\nINR 548',
#   'reaching': '00:30',
#   ' duration': '04h 10m'},
#  {'routemname': 'Hamirpur (Himachal Pradesh) to Chandigarh',
#   'seat': '',
#   'bustypes': 'Volvo A/C Semi Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '20:20',
#   'starratings': '4.5',
#   'tickets': 'Starts from\nINR 548',
#   'reaching': '00:30',
#   ' duration': '04h 10m'},
#  {'routemname': 'Hamirpur (Himachal Pradesh) to Chandigarh',
#   'seat': '',
#   'bustypes': 'Volvo A/C Semi Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '20:20',
#   'starratings': '4.5',
#   'tickets': 'Starts from\nINR 548',
#   'reaching': '00:30',
#   ' duration': '04h 10m'},
#  {'routemname': 'Hamirpur (Himachal Pradesh) to Chandigarh',
#   'seat': '',
#   'bustypes': 'Volvo A/C Semi Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '20:20',
#   'starratings': '4.5',
#   'tickets': 'Starts from\nINR 548',
#   'reaching': '00:30',
#   ' duration': '04h 10m'},
#  {'routemname': 'Hamirpur (Himachal Pradesh) to Chandigarh',
#   'seat': '',
#   'bustypes': 'Volvo A/C Semi Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '20:20',
#   'starratings': '4.5',
#   'tickets': 'Starts from\nINR 548',
#   'reaching': '00:30',
#   ' duration': '04h 10m'},
#  {'routemname': 'Hamirpur (Himachal Pradesh) to Chandigarh',
#   'seat': '',
#   'bustypes': 'Volvo A/C Semi Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '20:20',
#   'starratings': '4.5',
#   'tickets': 'Starts from\nINR 548',
#   'reaching': '00:30',
#   ' duration': '04h 10m'},
#  {'routemname': 'Delhi to Chandigarh',
#   'seat': '9 Seats available',
#   'bustypes': 'Electric A/C Semi Sleeper (2+2)',
#   'busnames': 'NueGo',
#   'routetimes': '06:15',
#   'starratings': '4.1',
#   'tickets': 'INR 519 493',
#   'reaching': '11:35',
#   ' duration': '05h 20m'},
#  {'routemname': 'Delhi to Chandigarh',
#   'seat': '2 Seats available',
#   'bustypes': 'Electric A/C Semi Sleeper (2+2)',
#   'busnames': 'NueGo',
#   'routetimes': '06:15',
#   'starratings': '4.1',
#   'tickets': 'INR 519 493',
#   'reaching': '11:35',
#   ' duration': '05h 20m'},
#  {'routemname': 'Delhi to Chandigarh',
#   'seat': '7 Seats available',
#   'bustypes': 'Electric A/C Semi Sleeper (2+2)',
#   'busnames': 'NueGo',
#   'routetimes': '06:15',
#   'starratings': '4.1',
#   'tickets': 'INR 519 493',
#   'reaching': '11:35',
#   ' duration': '05h 20m'},
#  {'routemname': 'Delhi to Chandigarh',
#   'seat': '',
#   'bustypes': 'Electric A/C Semi Sleeper (2+2)',
#   'busnames': 'NueGo',
#   'routetimes': '06:15',
#   'starratings': '4.1',
#   'tickets': 'INR 519 493',
#   'reaching': '11:35',
#   ' duration': '05h 20m'},
#  {'routemname': 'Delhi to Chandigarh',
#   'seat': '',
#   'bustypes': 'Electric A/C Semi Sleeper (2+2)',
#   'busnames': 'NueGo',
#   'routetimes': '06:15',
#   'starratings': '4.1',
#   'tickets': 'INR 519 493',
#   'reaching': '11:35',
#   ' duration': '05h 20m'},
#  {'routemname': 'Manali to Chandigarh',
#   'seat': '45 Seats available',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '22:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 944',
#   'reaching': '03:10',
#   ' duration': '05h 10m'},
#  {'routemname': 'Manali to Chandigarh',
#   'seat': '25 Seats available',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '22:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 944',
#   'reaching': '03:10',
#   ' duration': '05h 10m'},
#  {'routemname': 'Manali to Chandigarh',
#   'seat': '11 Seats available',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '22:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 944',
#   'reaching': '03:10',
#   ' duration': '05h 10m'},
#  {'routemname': 'Manali to Chandigarh',
#   'seat': '33 Seats available',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '22:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 944',
#   'reaching': '03:10',
#   ' duration': '05h 10m'},
#  {'routemname': 'Manali to Chandigarh',
#   'seat': '',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '22:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 944',
#   'reaching': '03:10',
#   ' duration': '05h 10m'},
#  {'routemname': 'Manali to Chandigarh',
#   'seat': '',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '22:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 944',
#   'reaching': '03:10',
#   ' duration': '05h 10m'},
#  {'routemname': 'Manali to Chandigarh',
#   'seat': '',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '22:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 944',
#   'reaching': '03:10',
#   ' duration': '05h 10m'},
#  {'routemname': 'Manali to Chandigarh',
#   'seat': '',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '22:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 944',
#   'reaching': '03:10',
#   ' duration': '05h 10m'},
#  {'routemname': 'Manali to Chandigarh',
#   'seat': '',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '22:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 944',
#   'reaching': '03:10',
#   ' duration': '05h 10m'},
#  {'routemname': 'Manali to Chandigarh',
#   'seat': '',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '22:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 944',
#   'reaching': '03:10',
#   ' duration': '05h 10m'},
#  {'routemname': 'Shimla to Chandigarh',
#   'seat': '32 Seats available',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.5',
#   'tickets': 'INR 432',
#   'reaching': '21:15',
#   ' duration': '04h 45m'},
#  {'routemname': 'Shimla to Chandigarh',
#   'seat': '12 Seats available',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.5',
#   'tickets': 'INR 432',
#   'reaching': '21:15',
#   ' duration': '04h 45m'},
#  {'routemname': 'Shimla to Chandigarh',
#   'seat': '27 Seats available',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.5',
#   'tickets': 'INR 432',
#   'reaching': '21:15',
#   ' duration': '04h 45m'},
#  {'routemname': 'Shimla to Chandigarh',
#   'seat': '',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.5',
#   'tickets': 'INR 432',
#   'reaching': '21:15',
#   ' duration': '04h 45m'},
#  {'routemname': 'Shimla to Chandigarh',
#   'seat': '',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.5',
#   'tickets': 'INR 432',
#   'reaching': '21:15',
#   ' duration': '04h 45m'},
#  {'routemname': 'Shimla to Chandigarh',
#   'seat': '',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.5',
#   'tickets': 'INR 432',
#   'reaching': '21:15',
#   ' duration': '04h 45m'},
#  {'routemname': 'Shimla to Chandigarh',
#   'seat': '',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.5',
#   'tickets': 'INR 432',
#   'reaching': '21:15',
#   ' duration': '04h 45m'},
#  {'routemname': 'Shimla to Chandigarh',
#   'seat': '',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.5',
#   'tickets': 'INR 432',
#   'reaching': '21:15',
#   ' duration': '04h 45m'},
#  {'routemname': 'Shimla to Chandigarh',
#   'seat': '',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.5',
#   'tickets': 'INR 432',
#   'reaching': '21:15',
#   ' duration': '04h 45m'},
#  {'routemname': 'Shimla to Chandigarh',
#   'seat': '',
#   'bustypes': 'Super Luxury Volvo AC Seater Pushback 2+2',
#   'busnames': 'RSRTC - 192348',
#   'routetimes': '16:30',
#   'starratings': '4.5',
#   'tickets': 'INR 432',
#   'reaching': '21:15',
#   ' duration': '04h 45m'},
#  {'routemname': 'Chandigarh to Manali',
#   'seat': '42 Seats available',
#   'bustypes': 'HVAC Seater (2+3)',
#   'busnames': 'Chandigarh Transport Undertaking (CTU) - 165851',
#   'routetimes': '08:20',
#   'starratings': '4.6',
#   'tickets': 'INR 714.2',
#   'reaching': '18:20',
#   ' duration': '10h 00m'},
#  {'routemname': 'Chandigarh to Manali',
#   'seat': '22 Seats available',
#   'bustypes': 'HVAC Seater (2+3)',
#   'busnames': 'Chandigarh Transport Undertaking (CTU) - 165851',
#   'routetimes': '08:20',
#   'starratings': '4.6',
#   'tickets': 'INR 714.2',
#   'reaching': '18:20',
#   ' duration': '10h 00m'},
#  {'routemname': 'Chandigarh to Manali',
#   'seat': '28 Seats available',
#   'bustypes': 'HVAC Seater (2+3)',
#   'busnames': 'Chandigarh Transport Undertaking (CTU) - 165851',
#   'routetimes': '08:20',
#   'starratings': '4.6',
#   'tickets': 'INR 714.2',
#   'reaching': '18:20',
#   ' duration': '10h 00m'},
#  {'routemname': 'Chandigarh to Manali',
#   'seat': '22 Seats available',
#   'bustypes': 'HVAC Seater (2+3)',
#   'busnames': 'Chandigarh Transport Undertaking (CTU) - 165851',
#   'routetimes': '08:20',
#   'starratings': '4.6',
#   'tickets': 'INR 714.2',
#   'reaching': '18:20',
#   ' duration': '10h 00m'},
#  {'routemname': 'Chandigarh to Manali',
#   'seat': '',
#   'bustypes': 'HVAC Seater (2+3)',
#   'busnames': 'Chandigarh Transport Undertaking (CTU) - 165851',
#   'routetimes': '08:20',
#   'starratings': '4.6',
#   'tickets': 'INR 714.2',
#   'reaching': '18:20',
#   ' duration': '10h 00m'},
#  {'routemname': 'Shimla to Manali',
#   'seat': '20 Seats available',
#   'bustypes': 'NON A/C Seater Push Back (2+2)',
#   'busnames': 'KRISHNA TRANSPORT SHIMLA',
#   'routetimes': '08:20',
#   'starratings': 'na',
#   'tickets': 'INR 700 595',
#   'reaching': '17:30',
#   ' duration': '09h 10m'},
#  {'routemname': 'Dharamshala (Himachal Pradesh) to Chandigarh',
#   'seat': '12 Seats available',
#   'bustypes': 'Volvo 9600 A/C Semi Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '18:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 999',
#   'reaching': '00:20',
#   ' duration': '06h 20m'},
#  {'routemname': 'Dharamshala (Himachal Pradesh) to Chandigarh',
#   'seat': '30 Seats available',
#   'bustypes': 'Volvo 9600 A/C Semi Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '18:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 999',
#   'reaching': '00:20',
#   ' duration': '06h 20m'},
#  {'routemname': 'Dharamshala (Himachal Pradesh) to Chandigarh',
#   'seat': '37 Seats available',
#   'bustypes': 'Volvo 9600 A/C Semi Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '18:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 999',
#   'reaching': '00:20',
#   ' duration': '06h 20m'},
#  {'routemname': 'Dharamshala (Himachal Pradesh) to Chandigarh',
#   'seat': '34 Seats available',
#   'bustypes': 'Volvo 9600 A/C Semi Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '18:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 999',
#   'reaching': '00:20',
#   ' duration': '06h 20m'},
#  {'routemname': 'Dharamshala (Himachal Pradesh) to Chandigarh',
#   'seat': '',
#   'bustypes': 'Volvo 9600 A/C Semi Sleeper (2+2)',
#   'busnames': 'Laxmi holidays',
#   'routetimes': '18:00',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 999',
#   'reaching': '00:20',
#   ' duration': '06h 20m'}]

# %%
df=pd.DataFrame(bus_data)

# %%
df["STATE"]='Himachal Pradesh'

# %%
df
# Out:
#                                       routemname                seat  \
# 0                                Delhi to Shimla  26 Seats available
# 1                                Delhi to Shimla  32 Seats available
# 2                                Delhi to Shimla  29 Seats available
# 3                                Delhi to Shimla
# 4                                Delhi to Shimla
# 5                                Shimla to Delhi  32 Seats available
# 6                                Shimla to Delhi  16 Seats available
# 7                                Shimla to Delhi  13 Seats available
# 8                                Shimla to Delhi
# 9                                Shimla to Delhi
# 10                               Shimla to Delhi
# 11                               Shimla to Delhi
# 12                               Shimla to Delhi
# 13                               Shimla to Delhi
# 14                               Shimla to Delhi
# 15     Chandigarh to Hamirpur (Himachal Pradesh)  37 Seats available
# 16     Hamirpur (Himachal Pradesh) to Chandigarh  16 Seats available
# 17     Hamirpur (Himachal Pradesh) to Chandigarh  30 Seats available
# 18     Hamirpur (Himachal Pradesh) to Chandigarh  11 Seats available
# 19     Hamirpur (Himachal Pradesh) to Chandigarh
# 20     Hamirpur (Himachal Pradesh) to Chandigarh
# 21     Hamirpur (Himachal Pradesh) to Chandigarh
# 22     Hamirpur (Himachal Pradesh) to Chandigarh
# 23     Hamirpur (Himachal Pradesh) to Chandigarh
# 24                           Delhi to Chandigarh   9 Seats available
# 25                           Delhi to Chandigarh   2 Seats available
# 26                           Delhi to Chandigarh   7 Seats available
# 27                           Delhi to Chandigarh
# 28                           Delhi to Chandigarh
# 29                          Manali to Chandigarh  45 Seats available
# 30                          Manali to Chandigarh  25 Seats available
# 31                          Manali to Chandigarh  11 Seats available
# 32                          Manali to Chandigarh  33 Seats available
# 33                          Manali to Chandigarh
# 34                          Manali to Chandigarh
# 35                          Manali to Chandigarh
# 36                          Manali to Chandigarh
# 37                          Manali to Chandigarh
# 38                          Manali to Chandigarh
# 39                          Shimla to Chandigarh  32 Seats available
# 40                          Shimla to Chandigarh  12 Seats available
# 41                          Shimla to Chandigarh  27 Seats available
# 42                          Shimla to Chandigarh
# 43                          Shimla to Chandigarh
# 44                          Shimla to Chandigarh
# 45                          Shimla to Chandigarh
# 46                          Shimla to Chandigarh
# 47                          Shimla to Chandigarh
# 48                          Shimla to Chandigarh
# 49                          Chandigarh to Manali  42 Seats available
# 50                          Chandigarh to Manali  22 Seats available
# 51                          Chandigarh to Manali  28 Seats available
# 52                          Chandigarh to Manali  22 Seats available
# 53                          Chandigarh to Manali
# 54                              Shimla to Manali  20 Seats available
# 55  Dharamshala (Himachal Pradesh) to Chandigarh  12 Seats available
# 56  Dharamshala (Himachal Pradesh) to Chandigarh  30 Seats available
# 57  Dharamshala (Himachal Pradesh) to Chandigarh  37 Seats available
# 58  Dharamshala (Himachal Pradesh) to Chandigarh  34 Seats available
# 59  Dharamshala (Himachal Pradesh) to Chandigarh
#
#                                      bustypes  \
# 0                Volvo A/C Semi Sleeper (2+2)
# 1                Volvo A/C Semi Sleeper (2+2)
# 2                Volvo A/C Semi Sleeper (2+2)
# 3                Volvo A/C Semi Sleeper (2+2)
# 4                Volvo A/C Semi Sleeper (2+2)
# 5   Super Luxury Volvo AC Seater Pushback 2+2
# 6   Super Luxury Volvo AC Seater Pushback 2+2
# 7   Super Luxury Volvo AC Seater Pushback 2+2
# 8   Super Luxury Volvo AC Seater Pushback 2+2
# 9   Super Luxury Volvo AC Seater Pushback 2+2
# 10  Super Luxury Volvo AC Seater Pushback 2+2
# 11  Super Luxury Volvo AC Seater Pushback 2+2
# 12  Super Luxury Volvo AC Seater Pushback 2+2
# 13  Super Luxury Volvo AC Seater Pushback 2+2
# 14  Super Luxury Volvo AC Seater Pushback 2+2
# 15                          HVAC Seater (2+3)
# 16               Volvo A/C Semi Sleeper (2+2)
# 17               Volvo A/C Semi Sleeper (2+2)
# 18               Volvo A/C Semi Sleeper (2+2)
# 19               Volvo A/C Semi Sleeper (2+2)
# 20               Volvo A/C Semi Sleeper (2+2)
# 21               Volvo A/C Semi Sleeper (2+2)
# 22               Volvo A/C Semi Sleeper (2+2)
# 23               Volvo A/C Semi Sleeper (2+2)
# 24            Electric A/C Semi Sleeper (2+2)
# 25            Electric A/C Semi Sleeper (2+2)
# 26            Electric A/C Semi Sleeper (2+2)
# 27            Electric A/C Semi Sleeper (2+2)
# 28            Electric A/C Semi Sleeper (2+2)
# 29   Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 30   Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 31   Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 32   Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 33   Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 34   Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 35   Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 36   Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 37   Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 38   Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 39  Super Luxury Volvo AC Seater Pushback 2+2
# 40  Super Luxury Volvo AC Seater Pushback 2+2
# 41  Super Luxury Volvo AC Seater Pushback 2+2
# 42  Super Luxury Volvo AC Seater Pushback 2+2
# 43  Super Luxury Volvo AC Seater Pushback 2+2
# 44  Super Luxury Volvo AC Seater Pushback 2+2
# 45  Super Luxury Volvo AC Seater Pushback 2+2
# 46  Super Luxury Volvo AC Seater Pushback 2+2
# 47  Super Luxury Volvo AC Seater Pushback 2+2
# 48  Super Luxury Volvo AC Seater Pushback 2+2
# 49                          HVAC Seater (2+3)
# 50                          HVAC Seater (2+3)
# 51                          HVAC Seater (2+3)
# 52                          HVAC Seater (2+3)
# 53                          HVAC Seater (2+3)
# 54             NON A/C Seater Push Back (2+2)
# 55          Volvo 9600 A/C Semi Sleeper (2+2)
# 56          Volvo 9600 A/C Semi Sleeper (2+2)
# 57          Volvo 9600 A/C Semi Sleeper (2+2)
# 58          Volvo 9600 A/C Semi Sleeper (2+2)
# 59          Volvo 9600 A/C Semi Sleeper (2+2)
#
#                                            busnames routetimes starratings  \
# 0                                      Bedi Travels      23:00         4.7
# 1                                      Bedi Travels      23:00         4.7
# 2                                      Bedi Travels      23:00         4.7
# 3                                      Bedi Travels      23:00         4.7
# 4                                      Bedi Travels      23:00         4.7
# 5                                    RSRTC - 192348      16:30         4.8
# 6                                    RSRTC - 192348      16:30         4.8
# 7                                    RSRTC - 192348      16:30         4.8
# 8                                    RSRTC - 192348      16:30         4.8
# 9                                    RSRTC - 192348      16:30         4.8
# 10                                   RSRTC - 192348      16:30         4.8
# 11                                   RSRTC - 192348      16:30         4.8
# 12                                   RSRTC - 192348      16:30         4.8
# 13                                   RSRTC - 192348      16:30         4.8
# 14                                   RSRTC - 192348      16:30         4.8
# 15  Chandigarh Transport Undertaking (CTU) - 165843      08:50         4.1
# 16                                   Laxmi holidays      20:20         4.5
# 17                                   Laxmi holidays      20:20         4.5
# 18                                   Laxmi holidays      20:20         4.5
# 19                                   Laxmi holidays      20:20         4.5
# 20                                   Laxmi holidays      20:20         4.5
# 21                                   Laxmi holidays      20:20         4.5
# 22                                   Laxmi holidays      20:20         4.5
# 23                                   Laxmi holidays      20:20         4.5
# 24                                            NueGo      06:15         4.1
# 25                                            NueGo      06:15         4.1
# 26                                            NueGo      06:15         4.1
# 27                                            NueGo      06:15         4.1
# 28                                            NueGo      06:15         4.1
# 29                                   Laxmi holidays      22:00         4.7
# 30                                   Laxmi holidays      22:00         4.7
# 31                                   Laxmi holidays      22:00         4.7
# 32                                   Laxmi holidays      22:00         4.7
# 33                                   Laxmi holidays      22:00         4.7
# 34                                   Laxmi holidays      22:00         4.7
# 35                                   Laxmi holidays      22:00         4.7
# 36                                   Laxmi holidays      22:00         4.7
# 37                                   Laxmi holidays      22:00         4.7
# 38                                   Laxmi holidays      22:00         4.7
# 39                                   RSRTC - 192348      16:30         4.5
# 40                                   RSRTC - 192348      16:30         4.5
# 41                                   RSRTC - 192348      16:30         4.5
# 42                                   RSRTC - 192348      16:30         4.5
# 43                                   RSRTC - 192348      16:30         4.5
# 44                                   RSRTC - 192348      16:30         4.5
# 45                                   RSRTC - 192348      16:30         4.5
# 46                                   RSRTC - 192348      16:30         4.5
# 47                                   RSRTC - 192348      16:30         4.5
# 48                                   RSRTC - 192348      16:30         4.5
# 49  Chandigarh Transport Undertaking (CTU) - 165851      08:20         4.6
# 50  Chandigarh Transport Undertaking (CTU) - 165851      08:20         4.6
# 51  Chandigarh Transport Undertaking (CTU) - 165851      08:20         4.6
# 52  Chandigarh Transport Undertaking (CTU) - 165851      08:20         4.6
# 53  Chandigarh Transport Undertaking (CTU) - 165851      08:20         4.6
# 54                         KRISHNA TRANSPORT SHIMLA      08:20          na
# 55                                   Laxmi holidays      18:00         4.7
# 56                                   Laxmi holidays      18:00         4.7
# 57                                   Laxmi holidays      18:00         4.7
# 58                                   Laxmi holidays      18:00         4.7
# 59                                   Laxmi holidays      18:00         4.7
#
#                        tickets reaching  duration             STATE
# 0   Starts from\nINR 1159 1043    08:00   09h 00m  Himachal Pradesh
# 1   Starts from\nINR 1159 1043    08:00   09h 00m  Himachal Pradesh
# 2   Starts from\nINR 1159 1043    08:00   09h 00m  Himachal Pradesh
# 3   Starts from\nINR 1159 1043    08:00   09h 00m  Himachal Pradesh
# 4   Starts from\nINR 1159 1043    08:00   09h 00m  Himachal Pradesh
# 5                     INR 1117    02:30   10h 00m  Himachal Pradesh
# 6                     INR 1117    02:30   10h 00m  Himachal Pradesh
# 7                     INR 1117    02:30   10h 00m  Himachal Pradesh
# 8                     INR 1117    02:30   10h 00m  Himachal Pradesh
# 9                     INR 1117    02:30   10h 00m  Himachal Pradesh
# 10                    INR 1117    02:30   10h 00m  Himachal Pradesh
# 11                    INR 1117    02:30   10h 00m  Himachal Pradesh
# 12                    INR 1117    02:30   10h 00m  Himachal Pradesh
# 13                    INR 1117    02:30   10h 00m  Himachal Pradesh
# 14                    INR 1117    02:30   10h 00m  Himachal Pradesh
# 15                  INR 383.85    13:20   04h 30m  Himachal Pradesh
# 16        Starts from\nINR 548    00:30   04h 10m  Himachal Pradesh
# 17        Starts from\nINR 548    00:30   04h 10m  Himachal Pradesh
# 18        Starts from\nINR 548    00:30   04h 10m  Himachal Pradesh
# 19        Starts from\nINR 548    00:30   04h 10m  Himachal Pradesh
# 20        Starts from\nINR 548    00:30   04h 10m  Himachal Pradesh
# 21        Starts from\nINR 548    00:30   04h 10m  Himachal Pradesh
# 22        Starts from\nINR 548    00:30   04h 10m  Himachal Pradesh
# 23        Starts from\nINR 548    00:30   04h 10m  Himachal Pradesh
# 24                 INR 519 493    11:35   05h 20m  Himachal Pradesh
# 25                 INR 519 493    11:35   05h 20m  Himachal Pradesh
# 26                 INR 519 493    11:35   05h 20m  Himachal Pradesh
# 27                 INR 519 493    11:35   05h 20m  Himachal Pradesh
# 28                 INR 519 493    11:35   05h 20m  Himachal Pradesh
# 29        Starts from\nINR 944    03:10   05h 10m  Himachal Pradesh
# 30        Starts from\nINR 944    03:10   05h 10m  Himachal Pradesh
# 31        Starts from\nINR 944    03:10   05h 10m  Himachal Pradesh
# 32        Starts from\nINR 944    03:10   05h 10m  Himachal Pradesh
# 33        Starts from\nINR 944    03:10   05h 10m  Himachal Pradesh
# 34        Starts from\nINR 944    03:10   05h 10m  Himachal Pradesh
# 35        Starts from\nINR 944    03:10   05h 10m  Himachal Pradesh
# 36        Starts from\nINR 944    03:10   05h 10m  Himachal Pradesh
# 37        Starts from\nINR 944    03:10   05h 10m  Himachal Pradesh
# 38        Starts from\nINR 944    03:10   05h 10m  Himachal Pradesh
# 39                     INR 432    21:15   04h 45m  Himachal Pradesh
# 40                     INR 432    21:15   04h 45m  Himachal Pradesh
# 41                     INR 432    21:15   04h 45m  Himachal Pradesh
# 42                     INR 432    21:15   04h 45m  Himachal Pradesh
# 43                     INR 432    21:15   04h 45m  Himachal Pradesh
# 44                     INR 432    21:15   04h 45m  Himachal Pradesh
# 45                     INR 432    21:15   04h 45m  Himachal Pradesh
# 46                     INR 432    21:15   04h 45m  Himachal Pradesh
# 47                     INR 432    21:15   04h 45m  Himachal Pradesh
# 48                     INR 432    21:15   04h 45m  Himachal Pradesh
# 49                   INR 714.2    18:20   10h 00m  Himachal Pradesh
# 50                   INR 714.2    18:20   10h 00m  Himachal Pradesh
# 51                   INR 714.2    18:20   10h 00m  Himachal Pradesh
# 52                   INR 714.2    18:20   10h 00m  Himachal Pradesh
# 53                   INR 714.2    18:20   10h 00m  Himachal Pradesh
# 54                 INR 700 595    17:30   09h 10m  Himachal Pradesh
# 55        Starts from\nINR 999    00:20   06h 20m  Himachal Pradesh
# 56        Starts from\nINR 999    00:20   06h 20m  Himachal Pradesh
# 57        Starts from\nINR 999    00:20   06h 20m  Himachal Pradesh
# 58        Starts from\nINR 999    00:20   06h 20m  Himachal Pradesh
# 59        Starts from\nINR 999    00:20   06h 20m  Himachal Pradesh

# %%
df.to_csv("himachal pradesh.csv",index=False)
