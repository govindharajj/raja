# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time
import csv
import pandas as pd

# %%
#Full 5 pages- code


driver = webdriver.Chrome()

driver.get("https://www.redbus.in/online-booking/bihar-state-road-transport-corporation-bsrtc/?utm_source=rtchometile")

wait = WebDriverWait(driver, 20)

all_data = []

def scrape_page():
    # Locate elements
    routes = wait.until(EC.presence_of_all_elements_located((By.CLASS_NAME, "route_link")))

    # Loop through each route to extract details
    for route in routes:
        try:
            route_link = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("href")
            title = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("title")

            # Append extracted data to list
            all_data.append({
                "route_link": route_link,
                "title": title,
                
            })
        except Exception as e:
            print(f"An error occurred: {e}")
            continue
# Scrape data from the first 5 pages

for page_number in range(1, 6):
    scrape_page()
    if page_number < 5:  # Don't try to click next on the last page
        try:
            # Locate the pagination container
            pagination_container = wait.until(EC.presence_of_element_located(
                (By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')
            ))

            # Locate the next page button within the container
            next_page_button = pagination_container.find_element(
                By.XPATH, f'.//div[contains(@class, "DC_117_pageTabs") and text()="{page_number + 1}"]'
            )

            # Scroll the next page button into view
            driver.execute_script("arguments[0].scrollIntoView();", next_page_button)
            time.sleep(1)  # Wait for a bit after scrolling

            # Log the action
            print(f"Clicking on page {page_number + 1}")

            # Click the next page button
            next_page_button.click()

            # Wait for the page number to update to the next page
            wait.until(EC.text_to_be_present_in_element(
                (By.XPATH, '//div[contains(@class, "DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))

            # Log the successful page navigation
            print(f"Successfully navigated to page {page_number + 1}")

            # Wait for a short duration to ensure the next page loads completely
            time.sleep(3)
        except Exception as e:
            print(f"An error occurred while navigating to page {page_number + 1}: {e}")
            break

# Print the scraped data
for entry in all_data:
    print(entry)
# Out:
# Clicking on page 2
# An error occurred while navigating to page 2: Message: element click intercepted: Element is not clickable at point (469, 2092)
#   (Session info: chrome=134.0.6998.89)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF608C3FE65+26629]
# 	(No symbol) [0x00007FF608BA6030]
# 	(No symbol) [0x00007FF608A3931A]
# 	(No symbol) [0x00007FF608A977A9]
# 	(No symbol) [0x00007FF608A95162]
# 	(No symbol) [0x00007FF608A92201]
# 	(No symbol) [0x00007FF608A91108]
# 	(No symbol) [0x00007FF608A828A4]
# 	(No symbol) [0x00007FF608AB7AAA]
# 	(No symbol) [0x00007FF608A82156]
# 	(No symbol) [0x00007FF608AB7CC0]
# 	(No symbol) [0x00007FF608AE0169]
# 	(No symbol) [0x00007FF608AB7883]
# 	(No symbol) [0x00007FF608A80550]
# 	(No symbol) [0x00007FF608A81803]
# 	GetHandleVerifier [0x00007FF608F972DD+3529853]
# 	GetHandleVerifier [0x00007FF608FADA42+3621858]
# 	GetHandleVerifier [0x00007FF608FA24F3+3575443]
# 	GetHandleVerifier [0x00007FF608D0B79A+860474]
# 	(No symbol) [0x00007FF608BB08AF]
# 	(No symbol) [0x00007FF608BACBE4]
# 	(No symbol) [0x00007FF608BACD86]
# 	(No symbol) [0x00007FF608B9C2E9]
# 	BaseThreadInitThunk [0x00007FF9505EE8D7+23]
# 	RtlUserThreadStart [0x00007FF9514DBF6C+44]
#
# {'route_link': 'https://www.redbus.in/bus-tickets/patna-to-bettiah', 'title': 'Patna (Bihar) to Bettiah'}
# {'route_link': 'https://www.redbus.in/bus-tickets/patna-to-motihari', 'title': 'Patna (Bihar) to Motihari'}
# {'route_link': 'https://www.redbus.in/bus-tickets/bettiah-to-patna', 'title': 'Bettiah to Patna (Bihar)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/gopalganj-to-delhi', 'title': 'Gopalganj (Bihar) to Delhi'}
# {'route_link': 'https://www.redbus.in/bus-tickets/balmiki-nagar-bihar-to-patna', 'title': 'Balmiki Nagar (bihar) to Patna (Bihar)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/patna-to-balmiki-nagar-bihar', 'title': 'Patna (Bihar) to Balmiki Nagar (bihar)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/patna-to-katihar', 'title': 'Patna (Bihar) to Katihar'}
# {'route_link': 'https://www.redbus.in/bus-tickets/motihari-to-delhi', 'title': 'Motihari to Delhi'}
# {'route_link': 'https://www.redbus.in/bus-tickets/patna-to-purnea', 'title': 'Patna (Bihar) to Purnea'}
# {'route_link': 'https://www.redbus.in/bus-tickets/patna-to-ranchi', 'title': 'Patna (Bihar) to Ranchi'}

# %%
route_links=[(item['route_link'],item["title"]) for item in all_data]
route_links
# Out:
# [('https://www.redbus.in/bus-tickets/patna-to-bettiah',
#   'Patna (Bihar) to Bettiah'),
#  ('https://www.redbus.in/bus-tickets/patna-to-motihari',
#   'Patna (Bihar) to Motihari'),
#  ('https://www.redbus.in/bus-tickets/bettiah-to-patna',
#   'Bettiah to Patna (Bihar)'),
#  ('https://www.redbus.in/bus-tickets/gopalganj-to-delhi',
#   'Gopalganj (Bihar) to Delhi'),
#  ('https://www.redbus.in/bus-tickets/balmiki-nagar-bihar-to-patna',
#   'Balmiki Nagar (bihar) to Patna (Bihar)'),
#  ('https://www.redbus.in/bus-tickets/patna-to-balmiki-nagar-bihar',
#   'Patna (Bihar) to Balmiki Nagar (bihar)'),
#  ('https://www.redbus.in/bus-tickets/patna-to-katihar',
#   'Patna (Bihar) to Katihar'),
#  ('https://www.redbus.in/bus-tickets/motihari-to-delhi', 'Motihari to Delhi'),
#  ('https://www.redbus.in/bus-tickets/patna-to-purnea',
#   'Patna (Bihar) to Purnea'),
#  ('https://www.redbus.in/bus-tickets/patna-to-ranchi',
#   'Patna (Bihar) to Ranchi')]

# %%
driver = webdriver.Chrome()
time.sleep(5)

def  scroll():
   x=0
   l=[]
   while True:
        x=x+1
        driver.execute_script('scrollBy(0,100)')
        #time.sleep(5)
        if(x>1000):
         break
bus_data=[]
for i,j in route_links:
    driver.get(i)

    scroll()




    bus_box= driver.find_elements(By.XPATH, '//div[@class="clearfix bus-item  "]')

    for bus in bus_box:
                        
                    reaching_time=bus.find_element(By.XPATH,'//div[@class="bp-time f-19 d-color disp-Inline"]').text
                    duration_time = bus.find_element(By.XPATH,'//div[@class="dur l-color lh-24"]').text

                    seats_available=bus.find_element(By.CLASS_NAME,'seat-left').text


                    bus_type = bus.find_element(By.XPATH, '//div[@class="bus-type f-12 m-top-16 l-color evBus"]').text


                    bus_names = bus.find_element(By.XPATH, '//div[@class="travels lh-24 f-bold d-color"]').text

                    route_times =bus.find_element(By.XPATH,'//div[@class="dp-time f-19 d-color f-bold"]').text

                    star_ratings = bus.find_element(By.XPATH, '//div[@class="rating-sec lh-24"]').text

                    ticket_rates =bus.find_element(By.XPATH, '//div[@class="seat-fare "]').text
                            
                    bus_data.append({'routename':j,'seat':seats_available,'bustypes':bus_type,'busnames':bus_names,'routetimes':route_times,'starratings':star_ratings,'tickets':ticket_rates,
                        "reaching":reaching_time," duration":duration_time,  })

# %%
bus_data
# Out:
# [{'routename': 'Patna (Bihar) to Bettiah',
#   'seat': '26 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '20:00',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 500 450',
#   'reaching': '02:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Patna (Bihar) to Bettiah',
#   'seat': '33 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '20:00',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 500 450',
#   'reaching': '02:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Patna (Bihar) to Bettiah',
#   'seat': '54 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '20:00',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 500 450',
#   'reaching': '02:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Patna (Bihar) to Bettiah',
#   'seat': '30 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '20:00',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 500 450',
#   'reaching': '02:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Patna (Bihar) to Bettiah',
#   'seat': '41 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '20:00',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 500 450',
#   'reaching': '02:00',
#   ' duration': '06h 00m'},
#  {'routename': 'Patna (Bihar) to Motihari',
#   'seat': '35 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 181063',
#   'routetimes': '21:20',
#   'starratings': '3.8',
#   'tickets': 'INR 230',
#   'reaching': '01:30',
#   ' duration': '04h 10m'},
#  {'routename': 'Patna (Bihar) to Motihari',
#   'seat': '35 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 181063',
#   'routetimes': '21:20',
#   'starratings': '3.8',
#   'tickets': 'INR 230',
#   'reaching': '01:30',
#   ' duration': '04h 10m'},
#  {'routename': 'Patna (Bihar) to Motihari',
#   'seat': '35 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 181063',
#   'routetimes': '21:20',
#   'starratings': '3.8',
#   'tickets': 'INR 230',
#   'reaching': '01:30',
#   ' duration': '04h 10m'},
#  {'routename': 'Patna (Bihar) to Motihari',
#   'seat': '27 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 181063',
#   'routetimes': '21:20',
#   'starratings': '3.8',
#   'tickets': 'INR 230',
#   'reaching': '01:30',
#   ' duration': '04h 10m'},
#  {'routename': 'Patna (Bihar) to Motihari',
#   'seat': '58 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 181063',
#   'routetimes': '21:20',
#   'starratings': '3.8',
#   'tickets': 'INR 230',
#   'reaching': '01:30',
#   ' duration': '04h 10m'},
#  {'routename': 'Patna (Bihar) to Motihari',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 181063',
#   'routetimes': '21:20',
#   'starratings': '3.8',
#   'tickets': 'INR 230',
#   'reaching': '01:30',
#   ' duration': '04h 10m'},
#  {'routename': 'Patna (Bihar) to Motihari',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 181063',
#   'routetimes': '21:20',
#   'starratings': '3.8',
#   'tickets': 'INR 230',
#   'reaching': '01:30',
#   ' duration': '04h 10m'},
#  {'routename': 'Patna (Bihar) to Motihari',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 181063',
#   'routetimes': '21:20',
#   'starratings': '3.8',
#   'tickets': 'INR 230',
#   'reaching': '01:30',
#   ' duration': '04h 10m'},
#  {'routename': 'Patna (Bihar) to Motihari',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 181063',
#   'routetimes': '21:20',
#   'starratings': '3.8',
#   'tickets': 'INR 230',
#   'reaching': '01:30',
#   ' duration': '04h 10m'},
#  {'routename': 'Patna (Bihar) to Motihari',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 181063',
#   'routetimes': '21:20',
#   'starratings': '3.8',
#   'tickets': 'INR 230',
#   'reaching': '01:30',
#   ' duration': '04h 10m'},
#  {'routename': 'Bettiah to Patna (Bihar)',
#   'seat': '17 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '12:17',
#   'starratings': '1.2',
#   'tickets': 'INR 450 405',
#   'reaching': '18:00',
#   ' duration': '05h 43m'},
#  {'routename': 'Bettiah to Patna (Bihar)',
#   'seat': '41 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '12:17',
#   'starratings': '1.2',
#   'tickets': 'INR 450 405',
#   'reaching': '18:00',
#   ' duration': '05h 43m'},
#  {'routename': 'Bettiah to Patna (Bihar)',
#   'seat': '41 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '12:17',
#   'starratings': '1.2',
#   'tickets': 'INR 450 405',
#   'reaching': '18:00',
#   ' duration': '05h 43m'},
#  {'routename': 'Bettiah to Patna (Bihar)',
#   'seat': '41 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '12:17',
#   'starratings': '1.2',
#   'tickets': 'INR 450 405',
#   'reaching': '18:00',
#   ' duration': '05h 43m'},
#  {'routename': 'Bettiah to Patna (Bihar)',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '12:17',
#   'starratings': '1.2',
#   'tickets': 'INR 450 405',
#   'reaching': '18:00',
#   ' duration': '05h 43m'},
#  {'routename': 'Bettiah to Patna (Bihar)',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '12:17',
#   'starratings': '1.2',
#   'tickets': 'INR 450 405',
#   'reaching': '18:00',
#   ' duration': '05h 43m'},
#  {'routename': 'Bettiah to Patna (Bihar)',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '12:17',
#   'starratings': '1.2',
#   'tickets': 'INR 450 405',
#   'reaching': '18:00',
#   ' duration': '05h 43m'},
#  {'routename': 'Bettiah to Patna (Bihar)',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '12:17',
#   'starratings': '1.2',
#   'tickets': 'INR 450 405',
#   'reaching': '18:00',
#   ' duration': '05h 43m'},
#  {'routename': 'Bettiah to Patna (Bihar)',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '12:17',
#   'starratings': '1.2',
#   'tickets': 'INR 450 405',
#   'reaching': '18:00',
#   ' duration': '05h 43m'},
#  {'routename': 'Bettiah to Patna (Bihar)',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '12:17',
#   'starratings': '1.2',
#   'tickets': 'INR 450 405',
#   'reaching': '18:00',
#   ' duration': '05h 43m'},
#  {'routename': 'Gopalganj (Bihar) to Delhi',
#   'seat': '32 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'ROYAL TRAVELS AND CARGO',
#   'routetimes': '17:30',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 1096',
#   'reaching': '08:30',
#   ' duration': '15h 00m'},
#  {'routename': 'Gopalganj (Bihar) to Delhi',
#   'seat': '9 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'ROYAL TRAVELS AND CARGO',
#   'routetimes': '17:30',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 1096',
#   'reaching': '08:30',
#   ' duration': '15h 00m'},
#  {'routename': 'Gopalganj (Bihar) to Delhi',
#   'seat': '28 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'ROYAL TRAVELS AND CARGO',
#   'routetimes': '17:30',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 1096',
#   'reaching': '08:30',
#   ' duration': '15h 00m'},
#  {'routename': 'Gopalganj (Bihar) to Delhi',
#   'seat': '29 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'ROYAL TRAVELS AND CARGO',
#   'routetimes': '17:30',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 1096',
#   'reaching': '08:30',
#   ' duration': '15h 00m'},
#  {'routename': 'Gopalganj (Bihar) to Delhi',
#   'seat': '20 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'ROYAL TRAVELS AND CARGO',
#   'routetimes': '17:30',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 1096',
#   'reaching': '08:30',
#   ' duration': '15h 00m'},
#  {'routename': 'Gopalganj (Bihar) to Delhi',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'ROYAL TRAVELS AND CARGO',
#   'routetimes': '17:30',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 1096',
#   'reaching': '08:30',
#   ' duration': '15h 00m'},
#  {'routename': 'Gopalganj (Bihar) to Delhi',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'ROYAL TRAVELS AND CARGO',
#   'routetimes': '17:30',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 1096',
#   'reaching': '08:30',
#   ' duration': '15h 00m'},
#  {'routename': 'Gopalganj (Bihar) to Delhi',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'ROYAL TRAVELS AND CARGO',
#   'routetimes': '17:30',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 1096',
#   'reaching': '08:30',
#   ' duration': '15h 00m'},
#  {'routename': 'Gopalganj (Bihar) to Delhi',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'ROYAL TRAVELS AND CARGO',
#   'routetimes': '17:30',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 1096',
#   'reaching': '08:30',
#   ' duration': '15h 00m'},
#  {'routename': 'Gopalganj (Bihar) to Delhi',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'ROYAL TRAVELS AND CARGO',
#   'routetimes': '17:30',
#   'starratings': '3.3',
#   'tickets': 'Starts from\nINR 1096',
#   'reaching': '08:30',
#   ' duration': '15h 00m'},
#  {'routename': 'Balmiki Nagar (bihar) to Patna (Bihar)',
#   'seat': '41 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 178820',
#   'routetimes': '13:30',
#   'starratings': '4.0',
#   'tickets': 'INR 403',
#   'reaching': '22:06',
#   ' duration': '32h 36m'},
#  {'routename': 'Balmiki Nagar (bihar) to Patna (Bihar)',
#   'seat': '8 Seats available',
#   'bustypes': 'Non AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 178820',
#   'routetimes': '13:30',
#   'starratings': '4.0',
#   'tickets': 'INR 403',
#   'reaching': '22:06',
#   ' duration': '32h 36m'},
#  {'routename': 'Patna (Bihar) to Balmiki Nagar (bihar)',
#   'seat': '26 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '20:00',
#   'starratings': '1.8',
#   'tickets': 'Starts from\nINR 500 450',
#   'reaching': '06:00',
#   ' duration': '10h 00m'},
#  {'routename': 'Patna (Bihar) to Balmiki Nagar (bihar)',
#   'seat': '30 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'Jai Mata Di Tour and Travels',
#   'routetimes': '20:00',
#   'starratings': '1.8',
#   'tickets': 'Starts from\nINR 500 450',
#   'reaching': '06:00',
#   ' duration': '10h 00m'},
#  {'routename': 'Patna (Bihar) to Katihar',
#   'seat': '33 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 142847',
#   'routetimes': '21:25',
#   'starratings': '3.6',
#   'tickets': 'INR 468',
#   'reaching': '06:30',
#   ' duration': '09h 05m'},
#  {'routename': 'Patna (Bihar) to Katihar',
#   'seat': '20 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 142847',
#   'routetimes': '21:25',
#   'starratings': '3.6',
#   'tickets': 'INR 468',
#   'reaching': '06:30',
#   ' duration': '09h 05m'},
#  {'routename': 'Patna (Bihar) to Katihar',
#   'seat': '28 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 142847',
#   'routetimes': '21:25',
#   'starratings': '3.6',
#   'tickets': 'INR 468',
#   'reaching': '06:30',
#   ' duration': '09h 05m'},
#  {'routename': 'Motihari to Delhi',
#   'seat': '36 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'Travel Point World LLP',
#   'routetimes': '18:20',
#   'starratings': '1.2',
#   'tickets': 'Starts from\nINR 1999',
#   'reaching': '10:50',
#   ' duration': '16h 30m'},
#  {'routename': 'Motihari to Delhi',
#   'seat': '20 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'Travel Point World LLP',
#   'routetimes': '18:20',
#   'starratings': '1.2',
#   'tickets': 'Starts from\nINR 1999',
#   'reaching': '10:50',
#   ' duration': '16h 30m'},
#  {'routename': 'Motihari to Delhi',
#   'seat': '58 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'Travel Point World LLP',
#   'routetimes': '18:20',
#   'starratings': '1.2',
#   'tickets': 'Starts from\nINR 1999',
#   'reaching': '10:50',
#   ' duration': '16h 30m'},
#  {'routename': 'Motihari to Delhi',
#   'seat': '30 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'Travel Point World LLP',
#   'routetimes': '18:20',
#   'starratings': '1.2',
#   'tickets': 'Starts from\nINR 1999',
#   'reaching': '10:50',
#   ' duration': '16h 30m'},
#  {'routename': 'Motihari to Delhi',
#   'seat': '23 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+2)',
#   'busnames': 'Travel Point World LLP',
#   'routetimes': '18:20',
#   'starratings': '1.2',
#   'tickets': 'Starts from\nINR 1999',
#   'reaching': '10:50',
#   ' duration': '16h 30m'},
#  {'routename': 'Patna (Bihar) to Purnea',
#   'seat': '34 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 142847',
#   'routetimes': '21:25',
#   'starratings': '3.5',
#   'tickets': 'INR 468',
#   'reaching': '05:40',
#   ' duration': '08h 15m'},
#  {'routename': 'Patna (Bihar) to Purnea',
#   'seat': '12 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 142847',
#   'routetimes': '21:25',
#   'starratings': '3.5',
#   'tickets': 'INR 468',
#   'reaching': '05:40',
#   ' duration': '08h 15m'},
#  {'routename': 'Patna (Bihar) to Purnea',
#   'seat': '18 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 142847',
#   'routetimes': '21:25',
#   'starratings': '3.5',
#   'tickets': 'INR 468',
#   'reaching': '05:40',
#   ' duration': '08h 15m'},
#  {'routename': 'Patna (Bihar) to Purnea',
#   'seat': '14 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 142847',
#   'routetimes': '21:25',
#   'starratings': '3.5',
#   'tickets': 'INR 468',
#   'reaching': '05:40',
#   ' duration': '08h 15m'},
#  {'routename': 'Patna (Bihar) to Purnea',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 142847',
#   'routetimes': '21:25',
#   'starratings': '3.5',
#   'tickets': 'INR 468',
#   'reaching': '05:40',
#   ' duration': '08h 15m'},
#  {'routename': 'Patna (Bihar) to Purnea',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 142847',
#   'routetimes': '21:25',
#   'starratings': '3.5',
#   'tickets': 'INR 468',
#   'reaching': '05:40',
#   ' duration': '08h 15m'},
#  {'routename': 'Patna (Bihar) to Purnea',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 142847',
#   'routetimes': '21:25',
#   'starratings': '3.5',
#   'tickets': 'INR 468',
#   'reaching': '05:40',
#   ' duration': '08h 15m'},
#  {'routename': 'Patna (Bihar) to Purnea',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 142847',
#   'routetimes': '21:25',
#   'starratings': '3.5',
#   'tickets': 'INR 468',
#   'reaching': '05:40',
#   ' duration': '08h 15m'},
#  {'routename': 'Patna (Bihar) to Purnea',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 142847',
#   'routetimes': '21:25',
#   'starratings': '3.5',
#   'tickets': 'INR 468',
#   'reaching': '05:40',
#   ' duration': '08h 15m'},
#  {'routename': 'Patna (Bihar) to Purnea',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 142847',
#   'routetimes': '21:25',
#   'starratings': '3.5',
#   'tickets': 'INR 468',
#   'reaching': '05:40',
#   ' duration': '08h 15m'},
#  {'routename': 'Patna (Bihar) to Ranchi',
#   'seat': '22 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 153594',
#   'routetimes': '20:41',
#   'starratings': '2.6',
#   'tickets': 'INR 525',
#   'reaching': '06:00',
#   ' duration': '09h 19m'},
#  {'routename': 'Patna (Bihar) to Ranchi',
#   'seat': '14 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 153594',
#   'routetimes': '20:41',
#   'starratings': '2.6',
#   'tickets': 'INR 525',
#   'reaching': '06:00',
#   ' duration': '09h 19m'},
#  {'routename': 'Patna (Bihar) to Ranchi',
#   'seat': '11 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 153594',
#   'routetimes': '20:41',
#   'starratings': '2.6',
#   'tickets': 'INR 525',
#   'reaching': '06:00',
#   ' duration': '09h 19m'},
#  {'routename': 'Patna (Bihar) to Ranchi',
#   'seat': '21 Seats available',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 153594',
#   'routetimes': '20:41',
#   'starratings': '2.6',
#   'tickets': 'INR 525',
#   'reaching': '06:00',
#   ' duration': '09h 19m'},
#  {'routename': 'Patna (Bihar) to Ranchi',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 153594',
#   'routetimes': '20:41',
#   'starratings': '2.6',
#   'tickets': 'INR 525',
#   'reaching': '06:00',
#   ' duration': '09h 19m'},
#  {'routename': 'Patna (Bihar) to Ranchi',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 153594',
#   'routetimes': '20:41',
#   'starratings': '2.6',
#   'tickets': 'INR 525',
#   'reaching': '06:00',
#   ' duration': '09h 19m'},
#  {'routename': 'Patna (Bihar) to Ranchi',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 153594',
#   'routetimes': '20:41',
#   'starratings': '2.6',
#   'tickets': 'INR 525',
#   'reaching': '06:00',
#   ' duration': '09h 19m'},
#  {'routename': 'Patna (Bihar) to Ranchi',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 153594',
#   'routetimes': '20:41',
#   'starratings': '2.6',
#   'tickets': 'INR 525',
#   'reaching': '06:00',
#   ' duration': '09h 19m'},
#  {'routename': 'Patna (Bihar) to Ranchi',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 153594',
#   'routetimes': '20:41',
#   'starratings': '2.6',
#   'tickets': 'INR 525',
#   'reaching': '06:00',
#   ' duration': '09h 19m'},
#  {'routename': 'Patna (Bihar) to Ranchi',
#   'seat': '',
#   'bustypes': 'AC Seater (2+2)',
#   'busnames': 'Bihar state road transport corporation (BSRTC) - 153594',
#   'routetimes': '20:41',
#   'starratings': '2.6',
#   'tickets': 'INR 525',
#   'reaching': '06:00',
#   ' duration': '09h 19m'}]

# %%
df=pd.DataFrame(bus_data)

# %%
df["STATE"]='bhigar'

# %%
df
# Out:
#                    routename                seat                    bustypes  \
# 0   Patna (Bihar) to Bettiah  26 Seats available  A/C Seater / Sleeper (2+2)
# 1   Patna (Bihar) to Bettiah  33 Seats available  A/C Seater / Sleeper (2+2)
# 2   Patna (Bihar) to Bettiah  54 Seats available  A/C Seater / Sleeper (2+2)
# 3   Patna (Bihar) to Bettiah  30 Seats available  A/C Seater / Sleeper (2+2)
# 4   Patna (Bihar) to Bettiah  41 Seats available  A/C Seater / Sleeper (2+2)
# ..                       ...                 ...                         ...
# 62   Patna (Bihar) to Ranchi                                 AC Seater (2+2)
# 63   Patna (Bihar) to Ranchi                                 AC Seater (2+2)
# 64   Patna (Bihar) to Ranchi                                 AC Seater (2+2)
# 65   Patna (Bihar) to Ranchi                                 AC Seater (2+2)
# 66   Patna (Bihar) to Ranchi                                 AC Seater (2+2)
#
#                                              busnames routetimes starratings  \
# 0                        Jai Mata Di Tour and Travels      20:00         3.3
# 1                        Jai Mata Di Tour and Travels      20:00         3.3
# 2                        Jai Mata Di Tour and Travels      20:00         3.3
# 3                        Jai Mata Di Tour and Travels      20:00         3.3
# 4                        Jai Mata Di Tour and Travels      20:00         3.3
# ..                                                ...        ...         ...
# 62  Bihar state road transport corporation (BSRTC)...      20:41         2.6
# 63  Bihar state road transport corporation (BSRTC)...      20:41         2.6
# 64  Bihar state road transport corporation (BSRTC)...      20:41         2.6
# 65  Bihar state road transport corporation (BSRTC)...      20:41         2.6
# 66  Bihar state road transport corporation (BSRTC)...      20:41         2.6
#
#                      tickets reaching  duration   STATE
# 0   Starts from\nINR 500 450    02:00   06h 00m  bhigar
# 1   Starts from\nINR 500 450    02:00   06h 00m  bhigar
# 2   Starts from\nINR 500 450    02:00   06h 00m  bhigar
# 3   Starts from\nINR 500 450    02:00   06h 00m  bhigar
# 4   Starts from\nINR 500 450    02:00   06h 00m  bhigar
# ..                       ...      ...       ...     ...
# 62                   INR 525    06:00   09h 19m  bhigar
# 63                   INR 525    06:00   09h 19m  bhigar
# 64                   INR 525    06:00   09h 19m  bhigar
# 65                   INR 525    06:00   09h 19m  bhigar
# 66                   INR 525    06:00   09h 19m  bhigar
#
# [67 rows x 10 columns]

# %%
df.to_csv("bhigar.csv",index=False)
