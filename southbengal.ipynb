# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time
import csv
import pandas as pd

# %%
#Full 5 pages- code


driver = webdriver.Chrome()

driver.get("https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc/?utm_source=rtchometile")

wait = WebDriverWait(driver, 20)

all_data = []

def scrape_page():
    # Locate elements
    routes = wait.until(EC.presence_of_all_elements_located((By.CLASS_NAME, "route_link")))

    # Loop through each route to extract details
    for route in routes:
        try:
            route_link = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("href")
            title = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("title")

            # Append extracted data to list
            all_data.append({
                "route_link": route_link,
                "title": title,
                
            })
        except Exception as e:
            print(f"An error occurred: {e}")
            continue
# Scrape data from the first 5 pages

for page_number in range(1, 6):
    scrape_page()
    if page_number < 5:  # Don't try to click next on the last page
        try:
            # Locate the pagination container
            pagination_container = wait.until(EC.presence_of_element_located(
                (By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')
            ))

            # Locate the next page button within the container
            next_page_button = pagination_container.find_element(
                By.XPATH, f'.//div[contains(@class, "DC_117_pageTabs") and text()="{page_number + 1}"]'
            )

            # Scroll the next page button into view
            driver.execute_script("arguments[0].scrollIntoView();", next_page_button)
            time.sleep(1)  # Wait for a bit after scrolling

            # Log the action
            print(f"Clicking on page {page_number + 1}")

            # Click the next page button
            next_page_button.click()

            # Wait for the page number to update to the next page
            wait.until(EC.text_to_be_present_in_element(
                (By.XPATH, '//div[contains(@class, "DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))

            # Log the successful page navigation
            print(f"Successfully navigated to page {page_number + 1}")

            # Wait for a short duration to ensure the next page loads completely
            time.sleep(3)
        except Exception as e:
            print(f"An error occurred while navigating to page {page_number + 1}: {e}")
            break

# Print the scraped data
for entry in all_data:
    print(entry)
# Out:
# Clicking on page 2
# An error occurred while navigating to page 2: Message: element click intercepted: Element is not clickable at point (469, 2092)
#   (Session info: chrome=134.0.6998.178)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF72D684C25+3179557]
# 	(No symbol) [0x00007FF72D2E88A0]
# 	(No symbol) [0x00007FF72D1791CA]
# 	(No symbol) [0x00007FF72D1D7929]
# 	(No symbol) [0x00007FF72D1D52E2]
# 	(No symbol) [0x00007FF72D1D2381]
# 	(No symbol) [0x00007FF72D1D1281]
# 	(No symbol) [0x00007FF72D1C2A24]
# 	(No symbol) [0x00007FF72D1F7C2A]
# 	(No symbol) [0x00007FF72D1C22D6]
# 	(No symbol) [0x00007FF72D1F7E40]
# 	(No symbol) [0x00007FF72D2202F3]
# 	(No symbol) [0x00007FF72D1F7A03]
# 	(No symbol) [0x00007FF72D1C06D0]
# 	(No symbol) [0x00007FF72D1C1983]
# 	GetHandleVerifier [0x00007FF72D6E67CD+3579853]
# 	GetHandleVerifier [0x00007FF72D6FD1D2+3672530]
# 	GetHandleVerifier [0x00007FF72D6F2153+3627347]
# 	GetHandleVerifier [0x00007FF72D45092A+868650]
# 	(No symbol) [0x00007FF72D2F2FFF]
# 	(No symbol) [0x00007FF72D2EF4A4]
# 	(No symbol) [0x00007FF72D2EF646]
# 	(No symbol) [0x00007FF72D2DEAA9]
# 	BaseThreadInitThunk [0x00007FF842C7E8D7+23]
# 	RtlUserThreadStart [0x00007FF84367BF6C+44]
#
# {'route_link': 'https://www.redbus.in/bus-tickets/durgapur-to-kolkata', 'title': 'Durgapur (West Bengal) to Kolkata'}
# {'route_link': 'https://www.redbus.in/bus-tickets/kolkata-to-burdwan', 'title': 'Kolkata to Burdwan'}
# {'route_link': 'https://www.redbus.in/bus-tickets/kolkata-to-durgapur', 'title': 'Kolkata to Durgapur (West Bengal)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/haldia-to-kolkata', 'title': 'Haldia to Kolkata'}
# {'route_link': 'https://www.redbus.in/bus-tickets/kolkata-to-haldia', 'title': 'Kolkata to Haldia'}
# {'route_link': 'https://www.redbus.in/bus-tickets/midnapore-to-kolkata', 'title': 'Midnapore to Kolkata'}
# {'route_link': 'https://www.redbus.in/bus-tickets/kolkata-to-arambagh-west-bengal', 'title': 'Kolkata to Arambagh (West Bengal)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/kolkata-to-midnapore', 'title': 'Kolkata to Midnapore'}
# {'route_link': 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'title': 'Digha to Kolkata'}
# {'route_link': 'https://www.redbus.in/bus-tickets/kolkata-to-bankura', 'title': 'Kolkata to Bankura'}

# %%
route_links=[(item['route_link'],item["title"]) for item in all_data]
route_links
# Out:
# [('https://www.redbus.in/bus-tickets/durgapur-to-kolkata',
#   'Durgapur (West Bengal) to Kolkata'),
#  ('https://www.redbus.in/bus-tickets/kolkata-to-burdwan',
#   'Kolkata to Burdwan'),
#  ('https://www.redbus.in/bus-tickets/kolkata-to-durgapur',
#   'Kolkata to Durgapur (West Bengal)'),
#  ('https://www.redbus.in/bus-tickets/haldia-to-kolkata', 'Haldia to Kolkata'),
#  ('https://www.redbus.in/bus-tickets/kolkata-to-haldia', 'Kolkata to Haldia'),
#  ('https://www.redbus.in/bus-tickets/midnapore-to-kolkata',
#   'Midnapore to Kolkata'),
#  ('https://www.redbus.in/bus-tickets/kolkata-to-arambagh-west-bengal',
#   'Kolkata to Arambagh (West Bengal)'),
#  ('https://www.redbus.in/bus-tickets/kolkata-to-midnapore',
#   'Kolkata to Midnapore'),
#  ('https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Digha to Kolkata'),
#  ('https://www.redbus.in/bus-tickets/kolkata-to-bankura',
#   'Kolkata to Bankura')]

# %%
driver = webdriver.Chrome()
time.sleep(5)

def  scroll():
   x=0
   l=[]
   while True:
        x=x+1
        driver.execute_script('scrollBy(0,100)')
        #time.sleep(5)
        if(x>1000):
         break
bus_data=[]
for i,j in route_links:
    driver.get(i)

    scroll()




    bus_box= driver.find_elements(By.XPATH, '//div[@class="clearfix bus-item  "]')

    for bus in bus_box:
                        
                    reaching_time=bus.find_element(By.XPATH,'//div[@class="bp-time f-19 d-color disp-Inline"]').text
                    duration_time = bus.find_element(By.XPATH,'//div[@class="dur l-color lh-24"]').text

                    seats_available=bus.find_element(By.CLASS_NAME,'seat-left').text


                    bus_type = bus.find_element(By.XPATH, '//div[@class="bus-type f-12 m-top-16 l-color evBus"]').text


                    bus_names = bus.find_element(By.XPATH, '//div[@class="travels lh-24 f-bold d-color"]').text

                    route_times =bus.find_element(By.XPATH,'//div[@class="dp-time f-19 d-color f-bold"]').text

                    star_ratings = bus.find_element(By.XPATH, '//div[@class="rating-sec lh-24"]').text

                    ticket_rates =bus.find_element(By.XPATH, '//div[@class="seat-fare "]').text
                            
                    bus_data.append({'routemname':j,'seat':seats_available,'bustypes':bus_type,'busnames':bus_names,'routetimes':route_times,'starratings':star_ratings,'tickets':ticket_rates,
                        "reaching":reaching_time," duration":duration_time,  })

# %%
bus_data
# Out:
# [{'routemname': 'Durgapur (West Bengal) to Kolkata',
#   'seat': '24 Seats available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:10',
#   'starratings': '4.6',
#   'tickets': 'INR 486',
#   'reaching': '09:20',
#   ' duration': '03h 10m'},
#  {'routemname': 'Durgapur (West Bengal) to Kolkata',
#   'seat': '25 Seats available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:10',
#   'starratings': '4.6',
#   'tickets': 'INR 486',
#   'reaching': '09:20',
#   ' duration': '03h 10m'},
#  {'routemname': 'Durgapur (West Bengal) to Kolkata',
#   'seat': '15 Seats available',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:10',
#   'starratings': '4.6',
#   'tickets': 'INR 486',
#   'reaching': '09:20',
#   ' duration': '03h 10m'},
#  {'routemname': 'Durgapur (West Bengal) to Kolkata',
#   'seat': '',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:10',
#   'starratings': '4.6',
#   'tickets': 'INR 486',
#   'reaching': '09:20',
#   ' duration': '03h 10m'},
#  {'routemname': 'Durgapur (West Bengal) to Kolkata',
#   'seat': '',
#   'bustypes': 'Volvo A/C Seater (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:10',
#   'starratings': '4.6',
#   'tickets': 'INR 486',
#   'reaching': '09:20',
#   ' duration': '03h 10m'},
#  {'routemname': 'Kolkata to Burdwan',
#   'seat': '3 Seats available',
#   'bustypes': 'Scania Multi-Axle AC Semi Sleeper (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:30',
#   'starratings': '4.3',
#   'tickets': 'INR 429',
#   'reaching': '08:30',
#   ' duration': '02h 00m'},
#  {'routemname': 'Kolkata to Burdwan',
#   'seat': '3 Seats available',
#   'bustypes': 'Scania Multi-Axle AC Semi Sleeper (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:30',
#   'starratings': '4.3',
#   'tickets': 'INR 429',
#   'reaching': '08:30',
#   ' duration': '02h 00m'},
#  {'routemname': 'Kolkata to Burdwan',
#   'seat': '18 Seats available',
#   'bustypes': 'Scania Multi-Axle AC Semi Sleeper (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:30',
#   'starratings': '4.3',
#   'tickets': 'INR 429',
#   'reaching': '08:30',
#   ' duration': '02h 00m'},
#  {'routemname': 'Kolkata to Burdwan',
#   'seat': '',
#   'bustypes': 'Scania Multi-Axle AC Semi Sleeper (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:30',
#   'starratings': '4.3',
#   'tickets': 'INR 429',
#   'reaching': '08:30',
#   ' duration': '02h 00m'},
#  {'routemname': 'Kolkata to Burdwan',
#   'seat': '',
#   'bustypes': 'Scania Multi-Axle AC Semi Sleeper (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:30',
#   'starratings': '4.3',
#   'tickets': 'INR 429',
#   'reaching': '08:30',
#   ' duration': '02h 00m'},
#  {'routemname': 'Kolkata to Burdwan',
#   'seat': '',
#   'bustypes': 'Scania Multi-Axle AC Semi Sleeper (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:30',
#   'starratings': '4.3',
#   'tickets': 'INR 429',
#   'reaching': '08:30',
#   ' duration': '02h 00m'},
#  {'routemname': 'Kolkata to Burdwan',
#   'seat': '',
#   'bustypes': 'Scania Multi-Axle AC Semi Sleeper (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:30',
#   'starratings': '4.3',
#   'tickets': 'INR 429',
#   'reaching': '08:30',
#   ' duration': '02h 00m'},
#  {'routemname': 'Kolkata to Burdwan',
#   'seat': '',
#   'bustypes': 'Scania Multi-Axle AC Semi Sleeper (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:30',
#   'starratings': '4.3',
#   'tickets': 'INR 429',
#   'reaching': '08:30',
#   ' duration': '02h 00m'},
#  {'routemname': 'Kolkata to Burdwan',
#   'seat': '',
#   'bustypes': 'Scania Multi-Axle AC Semi Sleeper (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:30',
#   'starratings': '4.3',
#   'tickets': 'INR 429',
#   'reaching': '08:30',
#   ' duration': '02h 00m'},
#  {'routemname': 'Kolkata to Burdwan',
#   'seat': '',
#   'bustypes': 'Scania Multi-Axle AC Semi Sleeper (2+2)',
#   'busnames': 'Express Line (Karunamoyee)',
#   'routetimes': '06:30',
#   'starratings': '4.3',
#   'tickets': 'INR 429',
#   'reaching': '08:30',
#   ' duration': '02h 00m'},
#  {'routemname': 'Kolkata to Durgapur (West Bengal)',
#   'seat': '10 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'WBTC (CTC) KOLKATA - ASANSOL - PURULIA (AC VOLVO) Banglashree Express - 133|13:45',
#   'routetimes': '13:45',
#   'starratings': '4.5',
#   'tickets': 'INR 350',
#   'reaching': '16:45',
#   ' duration': '03h 00m'},
#  {'routemname': 'Kolkata to Durgapur (West Bengal)',
#   'seat': '3 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'WBTC (CTC) KOLKATA - ASANSOL - PURULIA (AC VOLVO) Banglashree Express - 133|13:45',
#   'routetimes': '13:45',
#   'starratings': '4.5',
#   'tickets': 'INR 350',
#   'reaching': '16:45',
#   ' duration': '03h 00m'},
#  {'routemname': 'Kolkata to Durgapur (West Bengal)',
#   'seat': '3 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'WBTC (CTC) KOLKATA - ASANSOL - PURULIA (AC VOLVO) Banglashree Express - 133|13:45',
#   'routetimes': '13:45',
#   'starratings': '4.5',
#   'tickets': 'INR 350',
#   'reaching': '16:45',
#   ' duration': '03h 00m'},
#  {'routemname': 'Kolkata to Durgapur (West Bengal)',
#   'seat': '18 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'WBTC (CTC) KOLKATA - ASANSOL - PURULIA (AC VOLVO) Banglashree Express - 133|13:45',
#   'routetimes': '13:45',
#   'starratings': '4.5',
#   'tickets': 'INR 350',
#   'reaching': '16:45',
#   ' duration': '03h 00m'},
#  {'routemname': 'Kolkata to Durgapur (West Bengal)',
#   'seat': '',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'WBTC (CTC) KOLKATA - ASANSOL - PURULIA (AC VOLVO) Banglashree Express - 133|13:45',
#   'routetimes': '13:45',
#   'starratings': '4.5',
#   'tickets': 'INR 350',
#   'reaching': '16:45',
#   ' duration': '03h 00m'},
#  {'routemname': 'Haldia to Kolkata',
#   'seat': '29 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'WBTC (CTC) Habra- Barasat- Haldia - 180|16:45',
#   'routetimes': '16:45',
#   'starratings': '4.1',
#   'tickets': 'INR 97',
#   'reaching': '19:30',
#   ' duration': '02h 45m'},
#  {'routemname': 'Haldia to Kolkata',
#   'seat': '15 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'WBTC (CTC) Habra- Barasat- Haldia - 180|16:45',
#   'routetimes': '16:45',
#   'starratings': '4.1',
#   'tickets': 'INR 97',
#   'reaching': '19:30',
#   ' duration': '02h 45m'},
#  {'routemname': 'Haldia to Kolkata',
#   'seat': '49 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'WBTC (CTC) Habra- Barasat- Haldia - 180|16:45',
#   'routetimes': '16:45',
#   'starratings': '4.1',
#   'tickets': 'INR 97',
#   'reaching': '19:30',
#   ' duration': '02h 45m'},
#  {'routemname': 'Haldia to Kolkata',
#   'seat': '13 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'WBTC (CTC) Habra- Barasat- Haldia - 180|16:45',
#   'routetimes': '16:45',
#   'starratings': '4.1',
#   'tickets': 'INR 97',
#   'reaching': '19:30',
#   ' duration': '02h 45m'},
#  {'routemname': 'Haldia to Kolkata',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'WBTC (CTC) Habra- Barasat- Haldia - 180|16:45',
#   'routetimes': '16:45',
#   'starratings': '4.1',
#   'tickets': 'INR 97',
#   'reaching': '19:30',
#   ' duration': '02h 45m'},
#  {'routemname': 'Haldia to Kolkata',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'WBTC (CTC) Habra- Barasat- Haldia - 180|16:45',
#   'routetimes': '16:45',
#   'starratings': '4.1',
#   'tickets': 'INR 97',
#   'reaching': '19:30',
#   ' duration': '02h 45m'},
#  {'routemname': 'Kolkata to Haldia',
#   'seat': '47 Seats available',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Gogol City Service',
#   'routetimes': '12:50',
#   'starratings': '3.9',
#   'tickets': 'INR 165',
#   'reaching': '15:35',
#   ' duration': '02h 45m'},
#  {'routemname': 'Kolkata to Haldia',
#   'seat': '8 Seats available',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Gogol City Service',
#   'routetimes': '12:50',
#   'starratings': '3.9',
#   'tickets': 'INR 165',
#   'reaching': '15:35',
#   ' duration': '02h 45m'},
#  {'routemname': 'Kolkata to Haldia',
#   'seat': '58 Seats available',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Gogol City Service',
#   'routetimes': '12:50',
#   'starratings': '3.9',
#   'tickets': 'INR 165',
#   'reaching': '15:35',
#   ' duration': '02h 45m'},
#  {'routemname': 'Kolkata to Haldia',
#   'seat': '50 Seats available',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Gogol City Service',
#   'routetimes': '12:50',
#   'starratings': '3.9',
#   'tickets': 'INR 165',
#   'reaching': '15:35',
#   ' duration': '02h 45m'},
#  {'routemname': 'Kolkata to Haldia',
#   'seat': '',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Gogol City Service',
#   'routetimes': '12:50',
#   'starratings': '3.9',
#   'tickets': 'INR 165',
#   'reaching': '15:35',
#   ' duration': '02h 45m'},
#  {'routemname': 'Kolkata to Haldia',
#   'seat': '',
#   'bustypes': 'AC Seater (2+3)',
#   'busnames': 'Gogol City Service',
#   'routetimes': '12:50',
#   'starratings': '3.9',
#   'tickets': 'INR 165',
#   'reaching': '15:35',
#   ' duration': '02h 45m'},
#  {'routemname': 'Midnapore to Kolkata',
#   'seat': '50 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'Maa Bhabani Travels',
#   'routetimes': '07:05',
#   'starratings': '1.0',
#   'tickets': 'INR 130',
#   'reaching': '10:30',
#   ' duration': '03h 25m'},
#  {'routemname': 'Kolkata to Arambagh (West Bengal)',
#   'seat': '22 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574',
#   'routetimes': '07:30',
#   'starratings': '4.0',
#   'tickets': 'INR 95',
#   'reaching': '10:00',
#   ' duration': '02h 30m'},
#  {'routemname': 'Kolkata to Arambagh (West Bengal)',
#   'seat': '23 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574',
#   'routetimes': '07:30',
#   'starratings': '4.0',
#   'tickets': 'INR 95',
#   'reaching': '10:00',
#   ' duration': '02h 30m'},
#  {'routemname': 'Kolkata to Arambagh (West Bengal)',
#   'seat': '46 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574',
#   'routetimes': '07:30',
#   'starratings': '4.0',
#   'tickets': 'INR 95',
#   'reaching': '10:00',
#   ' duration': '02h 30m'},
#  {'routemname': 'Kolkata to Arambagh (West Bengal)',
#   'seat': '48 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574',
#   'routetimes': '07:30',
#   'starratings': '4.0',
#   'tickets': 'INR 95',
#   'reaching': '10:00',
#   ' duration': '02h 30m'},
#  {'routemname': 'Kolkata to Arambagh (West Bengal)',
#   'seat': '52 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574',
#   'routetimes': '07:30',
#   'starratings': '4.0',
#   'tickets': 'INR 95',
#   'reaching': '10:00',
#   ' duration': '02h 30m'},
#  {'routemname': 'Kolkata to Arambagh (West Bengal)',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574',
#   'routetimes': '07:30',
#   'starratings': '4.0',
#   'tickets': 'INR 95',
#   'reaching': '10:00',
#   ' duration': '02h 30m'},
#  {'routemname': 'Kolkata to Arambagh (West Bengal)',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574',
#   'routetimes': '07:30',
#   'starratings': '4.0',
#   'tickets': 'INR 95',
#   'reaching': '10:00',
#   ' duration': '02h 30m'},
#  {'routemname': 'Kolkata to Arambagh (West Bengal)',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574',
#   'routetimes': '07:30',
#   'starratings': '4.0',
#   'tickets': 'INR 95',
#   'reaching': '10:00',
#   ' duration': '02h 30m'},
#  {'routemname': 'Kolkata to Arambagh (West Bengal)',
#   'seat': '',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574',
#   'routetimes': '07:30',
#   'starratings': '4.0',
#   'tickets': 'INR 95',
#   'reaching': '10:00',
#   ' duration': '02h 30m'},
#  {'routemname': 'Kolkata to Midnapore',
#   'seat': '59 Seats available',
#   'bustypes': 'Non AC Seater (2+3)',
#   'busnames': 'Arman Travels',
#   'routetimes': '06:50',
#   'starratings': '2.0',
#   'tickets': 'INR 130',
#   'reaching': '10:45',
#   ' duration': '03h 55m'},
#  {'routemname': 'Digha to Kolkata',
#   'seat': '15 Seats available',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Express Line',
#   'routetimes': '13:45',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 299',
#   'reaching': '18:15',
#   ' duration': '04h 30m'},
#  {'routemname': 'Digha to Kolkata',
#   'seat': '30 Seats available',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Express Line',
#   'routetimes': '13:45',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 299',
#   'reaching': '18:15',
#   ' duration': '04h 30m'},
#  {'routemname': 'Digha to Kolkata',
#   'seat': '',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Express Line',
#   'routetimes': '13:45',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 299',
#   'reaching': '18:15',
#   ' duration': '04h 30m'},
#  {'routemname': 'Digha to Kolkata',
#   'seat': '',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Express Line',
#   'routetimes': '13:45',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 299',
#   'reaching': '18:15',
#   ' duration': '04h 30m'},
#  {'routemname': 'Digha to Kolkata',
#   'seat': '',
#   'bustypes': 'Volvo 9600 Multi Axle Semi-Sleeper (2+2)',
#   'busnames': 'Express Line',
#   'routetimes': '13:45',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 299',
#   'reaching': '18:15',
#   ' duration': '04h 30m'},
#  {'routemname': 'Kolkata to Bankura',
#   'seat': '21 Seats available',
#   'bustypes': 'A/C Seater (2+3)',
#   'busnames': 'PALLY DUTH PARIBAHAN',
#   'routetimes': '15:20',
#   'starratings': '4.1',
#   'tickets': 'INR 331 298',
#   'reaching': '19:45',
#   ' duration': '04h 25m'},
#  {'routemname': 'Kolkata to Bankura',
#   'seat': '8 Seats available',
#   'bustypes': 'A/C Seater (2+3)',
#   'busnames': 'PALLY DUTH PARIBAHAN',
#   'routetimes': '15:20',
#   'starratings': '4.1',
#   'tickets': 'INR 331 298',
#   'reaching': '19:45',
#   ' duration': '04h 25m'},
#  {'routemname': 'Kolkata to Bankura',
#   'seat': '12 Seats available',
#   'bustypes': 'A/C Seater (2+3)',
#   'busnames': 'PALLY DUTH PARIBAHAN',
#   'routetimes': '15:20',
#   'starratings': '4.1',
#   'tickets': 'INR 331 298',
#   'reaching': '19:45',
#   ' duration': '04h 25m'}]

# %%
df=pd.DataFrame(bus_data)

# %%
df['STATE']="southbengal"

# %%
df
# Out:
#                            routemname                seat  \
# 0   Durgapur (West Bengal) to Kolkata  24 Seats available
# 1   Durgapur (West Bengal) to Kolkata  25 Seats available
# 2   Durgapur (West Bengal) to Kolkata  15 Seats available
# 3   Durgapur (West Bengal) to Kolkata
# 4   Durgapur (West Bengal) to Kolkata
# 5                  Kolkata to Burdwan   3 Seats available
# 6                  Kolkata to Burdwan   3 Seats available
# 7                  Kolkata to Burdwan  18 Seats available
# 8                  Kolkata to Burdwan
# 9                  Kolkata to Burdwan
# 10                 Kolkata to Burdwan
# 11                 Kolkata to Burdwan
# 12                 Kolkata to Burdwan
# 13                 Kolkata to Burdwan
# 14                 Kolkata to Burdwan
# 15  Kolkata to Durgapur (West Bengal)  10 Seats available
# 16  Kolkata to Durgapur (West Bengal)   3 Seats available
# 17  Kolkata to Durgapur (West Bengal)   3 Seats available
# 18  Kolkata to Durgapur (West Bengal)  18 Seats available
# 19  Kolkata to Durgapur (West Bengal)
# 20                  Haldia to Kolkata  29 Seats available
# 21                  Haldia to Kolkata  15 Seats available
# 22                  Haldia to Kolkata  49 Seats available
# 23                  Haldia to Kolkata  13 Seats available
# 24                  Haldia to Kolkata
# 25                  Haldia to Kolkata
# 26                  Kolkata to Haldia  47 Seats available
# 27                  Kolkata to Haldia   8 Seats available
# 28                  Kolkata to Haldia  58 Seats available
# 29                  Kolkata to Haldia  50 Seats available
# 30                  Kolkata to Haldia
# 31                  Kolkata to Haldia
# 32               Midnapore to Kolkata  50 Seats available
# 33  Kolkata to Arambagh (West Bengal)  22 Seats available
# 34  Kolkata to Arambagh (West Bengal)  23 Seats available
# 35  Kolkata to Arambagh (West Bengal)  46 Seats available
# 36  Kolkata to Arambagh (West Bengal)  48 Seats available
# 37  Kolkata to Arambagh (West Bengal)  52 Seats available
# 38  Kolkata to Arambagh (West Bengal)
# 39  Kolkata to Arambagh (West Bengal)
# 40  Kolkata to Arambagh (West Bengal)
# 41  Kolkata to Arambagh (West Bengal)
# 42               Kolkata to Midnapore  59 Seats available
# 43                   Digha to Kolkata  15 Seats available
# 44                   Digha to Kolkata  30 Seats available
# 45                   Digha to Kolkata
# 46                   Digha to Kolkata
# 47                   Digha to Kolkata
# 48                 Kolkata to Bankura  21 Seats available
# 49                 Kolkata to Bankura   8 Seats available
# 50                 Kolkata to Bankura  12 Seats available
#
#                                     bustypes  \
# 0                     Volvo A/C Seater (2+2)
# 1                     Volvo A/C Seater (2+2)
# 2                     Volvo A/C Seater (2+2)
# 3                     Volvo A/C Seater (2+2)
# 4                     Volvo A/C Seater (2+2)
# 5    Scania Multi-Axle AC Semi Sleeper (2+2)
# 6    Scania Multi-Axle AC Semi Sleeper (2+2)
# 7    Scania Multi-Axle AC Semi Sleeper (2+2)
# 8    Scania Multi-Axle AC Semi Sleeper (2+2)
# 9    Scania Multi-Axle AC Semi Sleeper (2+2)
# 10   Scania Multi-Axle AC Semi Sleeper (2+2)
# 11   Scania Multi-Axle AC Semi Sleeper (2+2)
# 12   Scania Multi-Axle AC Semi Sleeper (2+2)
# 13   Scania Multi-Axle AC Semi Sleeper (2+2)
# 14   Scania Multi-Axle AC Semi Sleeper (2+2)
# 15                          A/C Seater (2+2)
# 16                          A/C Seater (2+2)
# 17                          A/C Seater (2+2)
# 18                          A/C Seater (2+2)
# 19                          A/C Seater (2+2)
# 20                       Non AC Seater (2+3)
# 21                       Non AC Seater (2+3)
# 22                       Non AC Seater (2+3)
# 23                       Non AC Seater (2+3)
# 24                       Non AC Seater (2+3)
# 25                       Non AC Seater (2+3)
# 26                           AC Seater (2+3)
# 27                           AC Seater (2+3)
# 28                           AC Seater (2+3)
# 29                           AC Seater (2+3)
# 30                           AC Seater (2+3)
# 31                           AC Seater (2+3)
# 32                       Non AC Seater (2+3)
# 33                       Non AC Seater (2+3)
# 34                       Non AC Seater (2+3)
# 35                       Non AC Seater (2+3)
# 36                       Non AC Seater (2+3)
# 37                       Non AC Seater (2+3)
# 38                       Non AC Seater (2+3)
# 39                       Non AC Seater (2+3)
# 40                       Non AC Seater (2+3)
# 41                       Non AC Seater (2+3)
# 42                       Non AC Seater (2+3)
# 43  Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 44  Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 45  Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 46  Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 47  Volvo 9600 Multi Axle Semi-Sleeper (2+2)
# 48                          A/C Seater (2+3)
# 49                          A/C Seater (2+3)
# 50                          A/C Seater (2+3)
#
#                                              busnames routetimes starratings  \
# 0                          Express Line (Karunamoyee)      06:10         4.6
# 1                          Express Line (Karunamoyee)      06:10         4.6
# 2                          Express Line (Karunamoyee)      06:10         4.6
# 3                          Express Line (Karunamoyee)      06:10         4.6
# 4                          Express Line (Karunamoyee)      06:10         4.6
# 5                          Express Line (Karunamoyee)      06:30         4.3
# 6                          Express Line (Karunamoyee)      06:30         4.3
# 7                          Express Line (Karunamoyee)      06:30         4.3
# 8                          Express Line (Karunamoyee)      06:30         4.3
# 9                          Express Line (Karunamoyee)      06:30         4.3
# 10                         Express Line (Karunamoyee)      06:30         4.3
# 11                         Express Line (Karunamoyee)      06:30         4.3
# 12                         Express Line (Karunamoyee)      06:30         4.3
# 13                         Express Line (Karunamoyee)      06:30         4.3
# 14                         Express Line (Karunamoyee)      06:30         4.3
# 15  WBTC (CTC) KOLKATA - ASANSOL - PURULIA (AC VOL...      13:45         4.5
# 16  WBTC (CTC) KOLKATA - ASANSOL - PURULIA (AC VOL...      13:45         4.5
# 17  WBTC (CTC) KOLKATA - ASANSOL - PURULIA (AC VOL...      13:45         4.5
# 18  WBTC (CTC) KOLKATA - ASANSOL - PURULIA (AC VOL...      13:45         4.5
# 19  WBTC (CTC) KOLKATA - ASANSOL - PURULIA (AC VOL...      13:45         4.5
# 20      WBTC (CTC) Habra- Barasat- Haldia - 180|16:45      16:45         4.1
# 21      WBTC (CTC) Habra- Barasat- Haldia - 180|16:45      16:45         4.1
# 22      WBTC (CTC) Habra- Barasat- Haldia - 180|16:45      16:45         4.1
# 23      WBTC (CTC) Habra- Barasat- Haldia - 180|16:45      16:45         4.1
# 24      WBTC (CTC) Habra- Barasat- Haldia - 180|16:45      16:45         4.1
# 25      WBTC (CTC) Habra- Barasat- Haldia - 180|16:45      16:45         4.1
# 26                                 Gogol City Service      12:50         3.9
# 27                                 Gogol City Service      12:50         3.9
# 28                                 Gogol City Service      12:50         3.9
# 29                                 Gogol City Service      12:50         3.9
# 30                                 Gogol City Service      12:50         3.9
# 31                                 Gogol City Service      12:50         3.9
# 32                                Maa Bhabani Travels      07:05         1.0
# 33   SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574      07:30         4.0
# 34   SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574      07:30         4.0
# 35   SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574      07:30         4.0
# 36   SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574      07:30         4.0
# 37   SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574      07:30         4.0
# 38   SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574      07:30         4.0
# 39   SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574      07:30         4.0
# 40   SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574      07:30         4.0
# 41   SBSTC-KOLKATA - ARAMBAG - NON STOP - 07:30 - 574      07:30         4.0
# 42                                      Arman Travels      06:50         2.0
# 43                                       Express Line      13:45         4.4
# 44                                       Express Line      13:45         4.4
# 45                                       Express Line      13:45         4.4
# 46                                       Express Line      13:45         4.4
# 47                                       Express Line      13:45         4.4
# 48                               PALLY DUTH PARIBAHAN      15:20         4.1
# 49                               PALLY DUTH PARIBAHAN      15:20         4.1
# 50                               PALLY DUTH PARIBAHAN      15:20         4.1
#
#                  tickets reaching  duration        STATE
# 0                INR 486    09:20   03h 10m  southbengal
# 1                INR 486    09:20   03h 10m  southbengal
# 2                INR 486    09:20   03h 10m  southbengal
# 3                INR 486    09:20   03h 10m  southbengal
# 4                INR 486    09:20   03h 10m  southbengal
# 5                INR 429    08:30   02h 00m  southbengal
# 6                INR 429    08:30   02h 00m  southbengal
# 7                INR 429    08:30   02h 00m  southbengal
# 8                INR 429    08:30   02h 00m  southbengal
# 9                INR 429    08:30   02h 00m  southbengal
# 10               INR 429    08:30   02h 00m  southbengal
# 11               INR 429    08:30   02h 00m  southbengal
# 12               INR 429    08:30   02h 00m  southbengal
# 13               INR 429    08:30   02h 00m  southbengal
# 14               INR 429    08:30   02h 00m  southbengal
# 15               INR 350    16:45   03h 00m  southbengal
# 16               INR 350    16:45   03h 00m  southbengal
# 17               INR 350    16:45   03h 00m  southbengal
# 18               INR 350    16:45   03h 00m  southbengal
# 19               INR 350    16:45   03h 00m  southbengal
# 20                INR 97    19:30   02h 45m  southbengal
# 21                INR 97    19:30   02h 45m  southbengal
# 22                INR 97    19:30   02h 45m  southbengal
# 23                INR 97    19:30   02h 45m  southbengal
# 24                INR 97    19:30   02h 45m  southbengal
# 25                INR 97    19:30   02h 45m  southbengal
# 26               INR 165    15:35   02h 45m  southbengal
# 27               INR 165    15:35   02h 45m  southbengal
# 28               INR 165    15:35   02h 45m  southbengal
# 29               INR 165    15:35   02h 45m  southbengal
# 30               INR 165    15:35   02h 45m  southbengal
# 31               INR 165    15:35   02h 45m  southbengal
# 32               INR 130    10:30   03h 25m  southbengal
# 33                INR 95    10:00   02h 30m  southbengal
# 34                INR 95    10:00   02h 30m  southbengal
# 35                INR 95    10:00   02h 30m  southbengal
# 36                INR 95    10:00   02h 30m  southbengal
# 37                INR 95    10:00   02h 30m  southbengal
# 38                INR 95    10:00   02h 30m  southbengal
# 39                INR 95    10:00   02h 30m  southbengal
# 40                INR 95    10:00   02h 30m  southbengal
# 41                INR 95    10:00   02h 30m  southbengal
# 42               INR 130    10:45   03h 55m  southbengal
# 43  Starts from\nINR 299    18:15   04h 30m  southbengal
# 44  Starts from\nINR 299    18:15   04h 30m  southbengal
# 45  Starts from\nINR 299    18:15   04h 30m  southbengal
# 46  Starts from\nINR 299    18:15   04h 30m  southbengal
# 47  Starts from\nINR 299    18:15   04h 30m  southbengal
# 48           INR 331 298    19:45   04h 25m  southbengal
# 49           INR 331 298    19:45   04h 25m  southbengal
# 50           INR 331 298    19:45   04h 25m  southbengal

# %%
df.to_csv("southbengal.csv",index=False)
