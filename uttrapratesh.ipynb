# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time
import csv
import pandas as pd

# %%
#Full 5 pages- code


driver = webdriver.Chrome()

driver.get("https://www.redbus.in/online-booking/uttar-pradesh-state-road-transport-corporation-upsrtc/?utm_source=rtchometile")

wait = WebDriverWait(driver, 20)

all_data = []

def scrape_page():
    # Locate elements
    routes = wait.until(EC.presence_of_all_elements_located((By.CLASS_NAME, "route_link")))

    # Loop through each route to extract details
    for route in routes:
        try:
            route_link = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("href")
            title = route.find_element(By.CSS_SELECTOR, ".route_details a").get_attribute("title")

            # Append extracted data to list
            all_data.append({
                "route_link": route_link,
                "title": title,
                
            })
        except Exception as e:
            print(f"An error occurred: {e}")
            continue
# Scrape data from the first 5 pages

for page_number in range(1, 6):
    scrape_page()
    if page_number < 5:  # Don't try to click next on the last page
        try:
            # Locate the pagination container
            pagination_container = wait.until(EC.presence_of_element_located(
                (By.XPATH, '//*[@id="root"]/div/div[4]/div[12]')
            ))

            # Locate the next page button within the container
            next_page_button = pagination_container.find_element(
                By.XPATH, f'.//div[contains(@class, "DC_117_pageTabs") and text()="{page_number + 1}"]'
            )

            # Scroll the next page button into view
            driver.execute_script("arguments[0].scrollIntoView();", next_page_button)
            time.sleep(1)  # Wait for a bit after scrolling

            # Log the action
            print(f"Clicking on page {page_number + 1}")

            # Click the next page button
            next_page_button.click()

            # Wait for the page number to update to the next page
            wait.until(EC.text_to_be_present_in_element(
                (By.XPATH, '//div[contains(@class, "DC_117_pageTabs DC_117_pageActive")]'), str(page_number + 1)))

            # Log the successful page navigation
            print(f"Successfully navigated to page {page_number + 1}")

            # Wait for a short duration to ensure the next page loads completely
            time.sleep(3)
        except Exception as e:
            print(f"An error occurred while navigating to page {page_number + 1}: {e}")
            break

# Print the scraped data
for entry in all_data:
    print(entry)
# Out:
# Clicking on page 2
# An error occurred while navigating to page 2: Message: element click intercepted: Element is not clickable at point (469, 2092)
#   (Session info: chrome=134.0.6998.89)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF608C3FE65+26629]
# 	(No symbol) [0x00007FF608BA6030]
# 	(No symbol) [0x00007FF608A3931A]
# 	(No symbol) [0x00007FF608A977A9]
# 	(No symbol) [0x00007FF608A95162]
# 	(No symbol) [0x00007FF608A92201]
# 	(No symbol) [0x00007FF608A91108]
# 	(No symbol) [0x00007FF608A828A4]
# 	(No symbol) [0x00007FF608AB7AAA]
# 	(No symbol) [0x00007FF608A82156]
# 	(No symbol) [0x00007FF608AB7CC0]
# 	(No symbol) [0x00007FF608AE0169]
# 	(No symbol) [0x00007FF608AB7883]
# 	(No symbol) [0x00007FF608A80550]
# 	(No symbol) [0x00007FF608A81803]
# 	GetHandleVerifier [0x00007FF608F972DD+3529853]
# 	GetHandleVerifier [0x00007FF608FADA42+3621858]
# 	GetHandleVerifier [0x00007FF608FA24F3+3575443]
# 	GetHandleVerifier [0x00007FF608D0B79A+860474]
# 	(No symbol) [0x00007FF608BB08AF]
# 	(No symbol) [0x00007FF608BACBE4]
# 	(No symbol) [0x00007FF608BACD86]
# 	(No symbol) [0x00007FF608B9C2E9]
# 	BaseThreadInitThunk [0x00007FF9505EE8D7+23]
# 	RtlUserThreadStart [0x00007FF9514DBF6C+44]
#
# {'route_link': 'https://www.redbus.in/bus-tickets/bareilly-to-delhi', 'title': 'Bareilly (Uttar Pradesh) to Delhi'}
# {'route_link': 'https://www.redbus.in/bus-tickets/lucknow-to-allahabad', 'title': 'Lucknow to Prayagraj(Uttar Pradesh)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/allahabad-to-lucknow', 'title': 'Prayagraj(Uttar Pradesh) to Lucknow'}
# {'route_link': 'https://www.redbus.in/bus-tickets/delhi-to-bareilly', 'title': 'Delhi to Bareilly (Uttar Pradesh)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/aligarh-uttar-pradesh-to-delhi', 'title': 'Aligarh (uttar pradesh) to Delhi'}
# {'route_link': 'https://www.redbus.in/bus-tickets/lucknow-to-bareilly', 'title': 'Lucknow to Bareilly (Uttar Pradesh)'}
# {'route_link': 'https://www.redbus.in/bus-tickets/lucknow-to-agra', 'title': 'Lucknow to Agra'}
# {'route_link': 'https://www.redbus.in/bus-tickets/ayodhya-to-allahabad', 'title': 'Ayodhya to Allahabad'}
# {'route_link': 'https://www.redbus.in/bus-tickets/allahabad-to-ayodhya', 'title': 'Prayagraj(Uttar Pradesh) to Ayodhya'}
# {'route_link': 'https://www.redbus.in/bus-tickets/bareilly-to-lucknow', 'title': 'Bareilly (Uttar Pradesh) to Lucknow'}

# %%
route_links=[(item['route_link'],item["title"]) for item in all_data]
route_links
# Out:
# [('https://www.redbus.in/bus-tickets/bareilly-to-delhi',
#   'Bareilly (Uttar Pradesh) to Delhi'),
#  ('https://www.redbus.in/bus-tickets/lucknow-to-allahabad',
#   'Lucknow to Prayagraj(Uttar Pradesh)'),
#  ('https://www.redbus.in/bus-tickets/allahabad-to-lucknow',
#   'Prayagraj(Uttar Pradesh) to Lucknow'),
#  ('https://www.redbus.in/bus-tickets/delhi-to-bareilly',
#   'Delhi to Bareilly (Uttar Pradesh)'),
#  ('https://www.redbus.in/bus-tickets/aligarh-uttar-pradesh-to-delhi',
#   'Aligarh (uttar pradesh) to Delhi'),
#  ('https://www.redbus.in/bus-tickets/lucknow-to-bareilly',
#   'Lucknow to Bareilly (Uttar Pradesh)'),
#  ('https://www.redbus.in/bus-tickets/lucknow-to-agra', 'Lucknow to Agra'),
#  ('https://www.redbus.in/bus-tickets/ayodhya-to-allahabad',
#   'Ayodhya to Allahabad'),
#  ('https://www.redbus.in/bus-tickets/allahabad-to-ayodhya',
#   'Prayagraj(Uttar Pradesh) to Ayodhya'),
#  ('https://www.redbus.in/bus-tickets/bareilly-to-lucknow',
#   'Bareilly (Uttar Pradesh) to Lucknow')]

# %%
driver = webdriver.Chrome()
time.sleep(5)

def  scroll():
   x=0
   l=[]
   while True:
        x=x+1
        driver.execute_script('scrollBy(0,100)')
        #time.sleep(5)
        if(x>1000):
         break
bus_data=[]
for i,j in route_links:
    driver.get(i)

    scroll()




    bus_box= driver.find_elements(By.XPATH, '//div[@class="clearfix bus-item  "]')

    for bus in bus_box:
                        
                    reaching_time=bus.find_element(By.XPATH,'//div[@class="bp-time f-19 d-color disp-Inline"]').text
                    duration_time = bus.find_element(By.XPATH,'//div[@class="dur l-color lh-24"]').text

                    seats_available=bus.find_element(By.CLASS_NAME,'seat-left').text


                    bus_type = bus.find_element(By.XPATH, '//div[@class="bus-type f-12 m-top-16 l-color evBus"]').text


                    bus_names = bus.find_element(By.XPATH, '//div[@class="travels lh-24 f-bold d-color"]').text

                    route_times =bus.find_element(By.XPATH,'//div[@class="dp-time f-19 d-color f-bold"]').text

                    star_ratings = bus.find_element(By.XPATH, '//div[@class="rating-sec lh-24"]').text

                    ticket_rates =bus.find_element(By.XPATH, '//div[@class="seat-fare "]').text
                            
                    bus_data.append({'routename':j,'seat':seats_available,'bustypes':bus_type,'busnames':bus_names,'routetimes':route_times,'starratings':star_ratings,'tickets':ticket_rates,
                        "reaching":reaching_time," duration":duration_time,  })

# %%
bus_data
# Out:
# [{'routename': 'Bareilly (Uttar Pradesh) to Delhi',
#   'seat': '34 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:50',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 284.82',
#   'reaching': '05:05',
#   ' duration': '05h 15m'},
#  {'routename': 'Bareilly (Uttar Pradesh) to Delhi',
#   'seat': '33 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:50',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 284.82',
#   'reaching': '05:05',
#   ' duration': '05h 15m'},
#  {'routename': 'Bareilly (Uttar Pradesh) to Delhi',
#   'seat': '30 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:50',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 284.82',
#   'reaching': '05:05',
#   ' duration': '05h 15m'},
#  {'routename': 'Bareilly (Uttar Pradesh) to Delhi',
#   'seat': '34 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:50',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 284.82',
#   'reaching': '05:05',
#   ' duration': '05h 15m'},
#  {'routename': 'Bareilly (Uttar Pradesh) to Delhi',
#   'seat': '',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:50',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 284.82',
#   'reaching': '05:05',
#   ' duration': '05h 15m'},
#  {'routename': 'Lucknow to Prayagraj(Uttar Pradesh)',
#   'seat': '25 Seats available',
#   'bustypes': 'Volvo AC Seater (2+2)',
#   'busnames': 'ARORA TRAVELS',
#   'routetimes': '17:15',
#   'starratings': '3.0',
#   'tickets': 'INR 699',
#   'reaching': '21:59',
#   ' duration': '04h 44m'},
#  {'routename': 'Lucknow to Prayagraj(Uttar Pradesh)',
#   'seat': '27 Seats available',
#   'bustypes': 'Volvo AC Seater (2+2)',
#   'busnames': 'ARORA TRAVELS',
#   'routetimes': '17:15',
#   'starratings': '3.0',
#   'tickets': 'INR 699',
#   'reaching': '21:59',
#   ' duration': '04h 44m'},
#  {'routename': 'Lucknow to Prayagraj(Uttar Pradesh)',
#   'seat': '13 Seats available',
#   'bustypes': 'Volvo AC Seater (2+2)',
#   'busnames': 'ARORA TRAVELS',
#   'routetimes': '17:15',
#   'starratings': '3.0',
#   'tickets': 'INR 699',
#   'reaching': '21:59',
#   ' duration': '04h 44m'},
#  {'routename': 'Lucknow to Prayagraj(Uttar Pradesh)',
#   'seat': '30 Seats available',
#   'bustypes': 'Volvo AC Seater (2+2)',
#   'busnames': 'ARORA TRAVELS',
#   'routetimes': '17:15',
#   'starratings': '3.0',
#   'tickets': 'INR 699',
#   'reaching': '21:59',
#   ' duration': '04h 44m'},
#  {'routename': 'Lucknow to Prayagraj(Uttar Pradesh)',
#   'seat': '',
#   'bustypes': 'Volvo AC Seater (2+2)',
#   'busnames': 'ARORA TRAVELS',
#   'routetimes': '17:15',
#   'starratings': '3.0',
#   'tickets': 'INR 699',
#   'reaching': '21:59',
#   ' duration': '04h 44m'},
#  {'routename': 'Lucknow to Prayagraj(Uttar Pradesh)',
#   'seat': '',
#   'bustypes': 'Volvo AC Seater (2+2)',
#   'busnames': 'ARORA TRAVELS',
#   'routetimes': '17:15',
#   'starratings': '3.0',
#   'tickets': 'INR 699',
#   'reaching': '21:59',
#   ' duration': '04h 44m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Lucknow',
#   'seat': '32 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Maharani Travels',
#   'routetimes': '15:30',
#   'starratings': '3.8',
#   'tickets': 'Starts from\nINR 1001',
#   'reaching': '00:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Lucknow',
#   'seat': '21 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Maharani Travels',
#   'routetimes': '15:30',
#   'starratings': '3.8',
#   'tickets': 'Starts from\nINR 1001',
#   'reaching': '00:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Lucknow',
#   'seat': '31 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Maharani Travels',
#   'routetimes': '15:30',
#   'starratings': '3.8',
#   'tickets': 'Starts from\nINR 1001',
#   'reaching': '00:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Lucknow',
#   'seat': '27 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Maharani Travels',
#   'routetimes': '15:30',
#   'starratings': '3.8',
#   'tickets': 'Starts from\nINR 1001',
#   'reaching': '00:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Lucknow',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Maharani Travels',
#   'routetimes': '15:30',
#   'starratings': '3.8',
#   'tickets': 'Starts from\nINR 1001',
#   'reaching': '00:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Lucknow',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Maharani Travels',
#   'routetimes': '15:30',
#   'starratings': '3.8',
#   'tickets': 'Starts from\nINR 1001',
#   'reaching': '00:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Lucknow',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Maharani Travels',
#   'routetimes': '15:30',
#   'starratings': '3.8',
#   'tickets': 'Starts from\nINR 1001',
#   'reaching': '00:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Lucknow',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Maharani Travels',
#   'routetimes': '15:30',
#   'starratings': '3.8',
#   'tickets': 'Starts from\nINR 1001',
#   'reaching': '00:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Lucknow',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Maharani Travels',
#   'routetimes': '15:30',
#   'starratings': '3.8',
#   'tickets': 'Starts from\nINR 1001',
#   'reaching': '00:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Lucknow',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'Maharani Travels',
#   'routetimes': '15:30',
#   'starratings': '3.8',
#   'tickets': 'Starts from\nINR 1001',
#   'reaching': '00:45',
#   ' duration': '09h 15m'},
#  {'routename': 'Delhi to Bareilly (Uttar Pradesh)',
#   'seat': '16 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:35',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 328.57',
#   'reaching': '04:35',
#   ' duration': '05h 00m'},
#  {'routename': 'Delhi to Bareilly (Uttar Pradesh)',
#   'seat': '30 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:35',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 328.57',
#   'reaching': '04:35',
#   ' duration': '05h 00m'},
#  {'routename': 'Delhi to Bareilly (Uttar Pradesh)',
#   'seat': '34 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:35',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 328.57',
#   'reaching': '04:35',
#   ' duration': '05h 00m'},
#  {'routename': 'Delhi to Bareilly (Uttar Pradesh)',
#   'seat': '36 Seats available',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:35',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 328.57',
#   'reaching': '04:35',
#   ' duration': '05h 00m'},
#  {'routename': 'Delhi to Bareilly (Uttar Pradesh)',
#   'seat': '',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:35',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 328.57',
#   'reaching': '04:35',
#   ' duration': '05h 00m'},
#  {'routename': 'Delhi to Bareilly (Uttar Pradesh)',
#   'seat': '',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:35',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 328.57',
#   'reaching': '04:35',
#   ' duration': '05h 00m'},
#  {'routename': 'Delhi to Bareilly (Uttar Pradesh)',
#   'seat': '',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:35',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 328.57',
#   'reaching': '04:35',
#   ' duration': '05h 00m'},
#  {'routename': 'Delhi to Bareilly (Uttar Pradesh)',
#   'seat': '',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:35',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 328.57',
#   'reaching': '04:35',
#   ' duration': '05h 00m'},
#  {'routename': 'Delhi to Bareilly (Uttar Pradesh)',
#   'seat': '',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:35',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 328.57',
#   'reaching': '04:35',
#   ' duration': '05h 00m'},
#  {'routename': 'Delhi to Bareilly (Uttar Pradesh)',
#   'seat': '',
#   'bustypes': 'A/C Seater (2+2)',
#   'busnames': 'FlixBus',
#   'routetimes': '23:35',
#   'starratings': '4.3',
#   'tickets': 'Starts from\nINR 328.57',
#   'reaching': '04:35',
#   ' duration': '05h 00m'},
#  {'routename': 'Aligarh (uttar pradesh) to Delhi',
#   'seat': '52 Seats available',
#   'bustypes': 'Ordinary Non AC Seater 2+3',
#   'busnames': 'UPSRTC - BDV0098',
#   'routetimes': '12:30',
#   'starratings': '3.3',
#   'tickets': 'INR 204',
#   'reaching': '15:50',
#   ' duration': '03h 20m'},
#  {'routename': 'Aligarh (uttar pradesh) to Delhi',
#   'seat': '36 Seats available',
#   'bustypes': 'Ordinary Non AC Seater 2+3',
#   'busnames': 'UPSRTC - BDV0098',
#   'routetimes': '12:30',
#   'starratings': '3.3',
#   'tickets': 'INR 204',
#   'reaching': '15:50',
#   ' duration': '03h 20m'},
#  {'routename': 'Aligarh (uttar pradesh) to Delhi',
#   'seat': '52 Seats available',
#   'bustypes': 'Ordinary Non AC Seater 2+3',
#   'busnames': 'UPSRTC - BDV0098',
#   'routetimes': '12:30',
#   'starratings': '3.3',
#   'tickets': 'INR 204',
#   'reaching': '15:50',
#   ' duration': '03h 20m'},
#  {'routename': 'Aligarh (uttar pradesh) to Delhi',
#   'seat': '52 Seats available',
#   'bustypes': 'Ordinary Non AC Seater 2+3',
#   'busnames': 'UPSRTC - BDV0098',
#   'routetimes': '12:30',
#   'starratings': '3.3',
#   'tickets': 'INR 204',
#   'reaching': '15:50',
#   ' duration': '03h 20m'},
#  {'routename': 'Aligarh (uttar pradesh) to Delhi',
#   'seat': '52 Seats available',
#   'bustypes': 'Ordinary Non AC Seater 2+3',
#   'busnames': 'UPSRTC - BDV0098',
#   'routetimes': '12:30',
#   'starratings': '3.3',
#   'tickets': 'INR 204',
#   'reaching': '15:50',
#   ' duration': '03h 20m'},
#  {'routename': 'Aligarh (uttar pradesh) to Delhi',
#   'seat': '',
#   'bustypes': 'Ordinary Non AC Seater 2+3',
#   'busnames': 'UPSRTC - BDV0098',
#   'routetimes': '12:30',
#   'starratings': '3.3',
#   'tickets': 'INR 204',
#   'reaching': '15:50',
#   ' duration': '03h 20m'},
#  {'routename': 'Aligarh (uttar pradesh) to Delhi',
#   'seat': '',
#   'bustypes': 'Ordinary Non AC Seater 2+3',
#   'busnames': 'UPSRTC - BDV0098',
#   'routetimes': '12:30',
#   'starratings': '3.3',
#   'tickets': 'INR 204',
#   'reaching': '15:50',
#   ' duration': '03h 20m'},
#  {'routename': 'Aligarh (uttar pradesh) to Delhi',
#   'seat': '',
#   'bustypes': 'Ordinary Non AC Seater 2+3',
#   'busnames': 'UPSRTC - BDV0098',
#   'routetimes': '12:30',
#   'starratings': '3.3',
#   'tickets': 'INR 204',
#   'reaching': '15:50',
#   ' duration': '03h 20m'},
#  {'routename': 'Aligarh (uttar pradesh) to Delhi',
#   'seat': '',
#   'bustypes': 'Ordinary Non AC Seater 2+3',
#   'busnames': 'UPSRTC - BDV0098',
#   'routetimes': '12:30',
#   'starratings': '3.3',
#   'tickets': 'INR 204',
#   'reaching': '15:50',
#   ' duration': '03h 20m'},
#  {'routename': 'Aligarh (uttar pradesh) to Delhi',
#   'seat': '',
#   'bustypes': 'Ordinary Non AC Seater 2+3',
#   'busnames': 'UPSRTC - BDV0098',
#   'routetimes': '12:30',
#   'starratings': '3.3',
#   'tickets': 'INR 204',
#   'reaching': '15:50',
#   ' duration': '03h 20m'},
#  {'routename': 'Lucknow to Bareilly (Uttar Pradesh)',
#   'seat': '9 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:15',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 889',
#   'reaching': '04:20',
#   ' duration': '05h 05m'},
#  {'routename': 'Lucknow to Bareilly (Uttar Pradesh)',
#   'seat': '2 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:15',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 889',
#   'reaching': '04:20',
#   ' duration': '05h 05m'},
#  {'routename': 'Lucknow to Bareilly (Uttar Pradesh)',
#   'seat': '36 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:15',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 889',
#   'reaching': '04:20',
#   ' duration': '05h 05m'},
#  {'routename': 'Lucknow to Bareilly (Uttar Pradesh)',
#   'seat': '45 Seats available',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:15',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 889',
#   'reaching': '04:20',
#   ' duration': '05h 05m'},
#  {'routename': 'Lucknow to Bareilly (Uttar Pradesh)',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:15',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 889',
#   'reaching': '04:20',
#   ' duration': '05h 05m'},
#  {'routename': 'Lucknow to Bareilly (Uttar Pradesh)',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:15',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 889',
#   'reaching': '04:20',
#   ' duration': '05h 05m'},
#  {'routename': 'Lucknow to Bareilly (Uttar Pradesh)',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:15',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 889',
#   'reaching': '04:20',
#   ' duration': '05h 05m'},
#  {'routename': 'Lucknow to Bareilly (Uttar Pradesh)',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:15',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 889',
#   'reaching': '04:20',
#   ' duration': '05h 05m'},
#  {'routename': 'Lucknow to Bareilly (Uttar Pradesh)',
#   'seat': '',
#   'bustypes': 'Bharat Benz A/C Seater /Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:15',
#   'starratings': '4.4',
#   'tickets': 'Starts from\nINR 889',
#   'reaching': '04:20',
#   ' duration': '05h 05m'},
#  {'routename': 'Lucknow to Agra',
#   'seat': '16 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'RSRTC - 177797',
#   'routetimes': '21:00',
#   'starratings': '3.6',
#   'tickets': 'INR 891',
#   'reaching': '02:30',
#   ' duration': '05h 30m'},
#  {'routename': 'Lucknow to Agra',
#   'seat': '11 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'RSRTC - 177797',
#   'routetimes': '21:00',
#   'starratings': '3.6',
#   'tickets': 'INR 891',
#   'reaching': '02:30',
#   ' duration': '05h 30m'},
#  {'routename': 'Lucknow to Agra',
#   'seat': '5 Seats available',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'RSRTC - 177797',
#   'routetimes': '21:00',
#   'starratings': '3.6',
#   'tickets': 'INR 891',
#   'reaching': '02:30',
#   ' duration': '05h 30m'},
#  {'routename': 'Lucknow to Agra',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'RSRTC - 177797',
#   'routetimes': '21:00',
#   'starratings': '3.6',
#   'tickets': 'INR 891',
#   'reaching': '02:30',
#   ' duration': '05h 30m'},
#  {'routename': 'Lucknow to Agra',
#   'seat': '',
#   'bustypes': 'A/C Seater / Sleeper (2+1)',
#   'busnames': 'RSRTC - 177797',
#   'routetimes': '21:00',
#   'starratings': '3.6',
#   'tickets': 'INR 891',
#   'reaching': '02:30',
#   ' duration': '05h 30m'},
#  {'routename': 'Ayodhya to Allahabad',
#   'seat': '20 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Radha Vallabh Travels RamRath',
#   'routetimes': '13:00',
#   'starratings': '3.9',
#   'tickets': 'Starts from\nINR 1100 990',
#   'reaching': '18:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Ayodhya to Allahabad',
#   'seat': '28 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Radha Vallabh Travels RamRath',
#   'routetimes': '13:00',
#   'starratings': '3.9',
#   'tickets': 'Starts from\nINR 1100 990',
#   'reaching': '18:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Ayodhya to Allahabad',
#   'seat': '25 Seats available',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Radha Vallabh Travels RamRath',
#   'routetimes': '13:00',
#   'starratings': '3.9',
#   'tickets': 'Starts from\nINR 1100 990',
#   'reaching': '18:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Ayodhya to Allahabad',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Radha Vallabh Travels RamRath',
#   'routetimes': '13:00',
#   'starratings': '3.9',
#   'tickets': 'Starts from\nINR 1100 990',
#   'reaching': '18:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Ayodhya to Allahabad',
#   'seat': '',
#   'bustypes': 'A/C Sleeper (2+1)',
#   'busnames': 'Radha Vallabh Travels RamRath',
#   'routetimes': '13:00',
#   'starratings': '3.9',
#   'tickets': 'Starts from\nINR 1100 990',
#   'reaching': '18:15',
#   ' duration': '05h 15m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Ayodhya',
#   'seat': '34 Seats available',
#   'bustypes': 'Janrath AC Seater 2+2',
#   'busnames': 'UPSRTC - PYD0194',
#   'routetimes': '12:00',
#   'starratings': '2.2',
#   'tickets': 'INR 415',
#   'reaching': '17:30',
#   ' duration': '05h 30m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Ayodhya',
#   'seat': '34 Seats available',
#   'bustypes': 'Janrath AC Seater 2+2',
#   'busnames': 'UPSRTC - PYD0194',
#   'routetimes': '12:00',
#   'starratings': '2.2',
#   'tickets': 'INR 415',
#   'reaching': '17:30',
#   ' duration': '05h 30m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Ayodhya',
#   'seat': '52 Seats available',
#   'bustypes': 'Janrath AC Seater 2+2',
#   'busnames': 'UPSRTC - PYD0194',
#   'routetimes': '12:00',
#   'starratings': '2.2',
#   'tickets': 'INR 415',
#   'reaching': '17:30',
#   ' duration': '05h 30m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Ayodhya',
#   'seat': '52 Seats available',
#   'bustypes': 'Janrath AC Seater 2+2',
#   'busnames': 'UPSRTC - PYD0194',
#   'routetimes': '12:00',
#   'starratings': '2.2',
#   'tickets': 'INR 415',
#   'reaching': '17:30',
#   ' duration': '05h 30m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Ayodhya',
#   'seat': '48 Seats available',
#   'bustypes': 'Janrath AC Seater 2+2',
#   'busnames': 'UPSRTC - PYD0194',
#   'routetimes': '12:00',
#   'starratings': '2.2',
#   'tickets': 'INR 415',
#   'reaching': '17:30',
#   ' duration': '05h 30m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Ayodhya',
#   'seat': '',
#   'bustypes': 'Janrath AC Seater 2+2',
#   'busnames': 'UPSRTC - PYD0194',
#   'routetimes': '12:00',
#   'starratings': '2.2',
#   'tickets': 'INR 415',
#   'reaching': '17:30',
#   ' duration': '05h 30m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Ayodhya',
#   'seat': '',
#   'bustypes': 'Janrath AC Seater 2+2',
#   'busnames': 'UPSRTC - PYD0194',
#   'routetimes': '12:00',
#   'starratings': '2.2',
#   'tickets': 'INR 415',
#   'reaching': '17:30',
#   ' duration': '05h 30m'},
#  {'routename': 'Prayagraj(Uttar Pradesh) to Ayodhya',
#   'seat': '',
#   'bustypes': 'Janrath AC Seater 2+2',
#   'busnames': 'UPSRTC - PYD0194',
#   'routetimes': '12:00',
#   'starratings': '2.2',
#   'tickets': 'INR 415',
#   'reaching': '17:30',
#   ' duration': '05h 30m'},
#  {'routename': 'Bareilly (Uttar Pradesh) to Lucknow',
#   'seat': '14 Seats available',
#   'bustypes': 'A/C Seater/Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:55',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 600',
#   'reaching': '05:15',
#   ' duration': '05h 20m'},
#  {'routename': 'Bareilly (Uttar Pradesh) to Lucknow',
#   'seat': '29 Seats available',
#   'bustypes': 'A/C Seater/Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:55',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 600',
#   'reaching': '05:15',
#   ' duration': '05h 20m'},
#  {'routename': 'Bareilly (Uttar Pradesh) to Lucknow',
#   'seat': '37 Seats available',
#   'bustypes': 'A/C Seater/Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:55',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 600',
#   'reaching': '05:15',
#   ' duration': '05h 20m'},
#  {'routename': 'Bareilly (Uttar Pradesh) to Lucknow',
#   'seat': '18 Seats available',
#   'bustypes': 'A/C Seater/Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:55',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 600',
#   'reaching': '05:15',
#   ' duration': '05h 20m'},
#  {'routename': 'Bareilly (Uttar Pradesh) to Lucknow',
#   'seat': '',
#   'bustypes': 'A/C Seater/Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:55',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 600',
#   'reaching': '05:15',
#   ' duration': '05h 20m'},
#  {'routename': 'Bareilly (Uttar Pradesh) to Lucknow',
#   'seat': '',
#   'bustypes': 'A/C Seater/Sleeper (2+1)',
#   'busnames': 'PTC-SKYBUS',
#   'routetimes': '23:55',
#   'starratings': '4.7',
#   'tickets': 'Starts from\nINR 600',
#   'reaching': '05:15',
#   ' duration': '05h 20m'}]

# %%
df= pd.DataFrame(bus_data)

# %%
df["STATE"]='uttrapratesh'

# %%
df
# Out:
#                               routename                seat  \
# 0     Bareilly (Uttar Pradesh) to Delhi  34 Seats available
# 1     Bareilly (Uttar Pradesh) to Delhi  33 Seats available
# 2     Bareilly (Uttar Pradesh) to Delhi  30 Seats available
# 3     Bareilly (Uttar Pradesh) to Delhi  34 Seats available
# 4     Bareilly (Uttar Pradesh) to Delhi
# ..                                  ...                 ...
# 69  Bareilly (Uttar Pradesh) to Lucknow  29 Seats available
# 70  Bareilly (Uttar Pradesh) to Lucknow  37 Seats available
# 71  Bareilly (Uttar Pradesh) to Lucknow  18 Seats available
# 72  Bareilly (Uttar Pradesh) to Lucknow
# 73  Bareilly (Uttar Pradesh) to Lucknow
#
#                     bustypes    busnames routetimes starratings  \
# 0           A/C Seater (2+2)     FlixBus      23:50         4.4
# 1           A/C Seater (2+2)     FlixBus      23:50         4.4
# 2           A/C Seater (2+2)     FlixBus      23:50         4.4
# 3           A/C Seater (2+2)     FlixBus      23:50         4.4
# 4           A/C Seater (2+2)     FlixBus      23:50         4.4
# ..                       ...         ...        ...         ...
# 69  A/C Seater/Sleeper (2+1)  PTC-SKYBUS      23:55         4.7
# 70  A/C Seater/Sleeper (2+1)  PTC-SKYBUS      23:55         4.7
# 71  A/C Seater/Sleeper (2+1)  PTC-SKYBUS      23:55         4.7
# 72  A/C Seater/Sleeper (2+1)  PTC-SKYBUS      23:55         4.7
# 73  A/C Seater/Sleeper (2+1)  PTC-SKYBUS      23:55         4.7
#
#                     tickets reaching  duration         STATE
# 0   Starts from\nINR 284.82    05:05   05h 15m  uttrapratesh
# 1   Starts from\nINR 284.82    05:05   05h 15m  uttrapratesh
# 2   Starts from\nINR 284.82    05:05   05h 15m  uttrapratesh
# 3   Starts from\nINR 284.82    05:05   05h 15m  uttrapratesh
# 4   Starts from\nINR 284.82    05:05   05h 15m  uttrapratesh
# ..                      ...      ...       ...           ...
# 69     Starts from\nINR 600    05:15   05h 20m  uttrapratesh
# 70     Starts from\nINR 600    05:15   05h 20m  uttrapratesh
# 71     Starts from\nINR 600    05:15   05h 20m  uttrapratesh
# 72     Starts from\nINR 600    05:15   05h 20m  uttrapratesh
# 73     Starts from\nINR 600    05:15   05h 20m  uttrapratesh
#
# [74 rows x 10 columns]

# %%
df.to_csv("uttrapratesh.csv",index=False)
